# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/vaibhavguglani/anaconda3/lib/python3.6/site-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/vaibhavguglani/anaconda3/lib/python3.6/site-packages (from requests) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vaibhavguglani/anaconda3/lib/python3.6/site-packages (from requests) (2019.11.28)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/vaibhavguglani/anaconda3/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/vaibhavguglani/anaconda3/lib/python3.6/site-packages (from requests) (2.6)

# %%
import requests
import datetime
from urllib.parse import urlencode
import pprint
import base64
import sys
import spotipy
import spotipy.util as util

# %%
# add your details
client_id = ''
client_secret = '' 
redirect_uri = ''
#these are vab's developer account ids 
#plz dont hack his account 
#:)

# %%
#client for spotify api for getting general stuff such 
#as top tracks top artists etc and spotipy api for getting specific song data
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    scope ='user-library-read'
    
    def __init__(self, client_id, client_secret, redirect_uri, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        self.redirect_uri = redirect_uri

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1', extras = ''):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}{extras}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    #personal data
    def spotipy_auth(self):
        if len(sys.argv) > 1:
            username = sys.argv[1]
        else:
            print("Usage: %s username" % (sys.argv[0],))
            sys.exit()

        spotipy_token = util.prompt_for_user_token(username,
                                   scope=self.scope,
                                   client_id=self.client_id,
                                   client_secret= self.client_secret,
                                   redirect_uri=self.redirect_uri)
        return spotipy_token
    
    def get_my_tracks(self):
        spotipy_token = self.spotipy_auth()
        track_list = []
        if spotipy_token:
            sp = spotipy.Spotify(auth=spotipy_token)
            i = 0
            while i < 1000000:
                results = sp.current_user_saved_tracks(1, i)
                if len(results['items']) == 0:
                    break
                else:
                    for item in results['items']:
                        track = item['track']
                        track_list.append(track['name'] + ' - ' + track['artists'][0]['name'])
                i+=1
        else:
            print("Can't get token for", username)
        return track_list
    
    def top_tracks_current(self):
        spotipy_token = self.spotipy_auth()
        track_list = []
        if spotipy_token:
            sp = spotipy.Spotify(auth=spotipy_token)
            sp.trace = False
            results = sp.current_user_top_tracks(time_range='short_term', limit=50)
            for i, item in enumerate(results['items']):
                track_list.append(item['name'] + '-' + item['artists'][0]['name'])
        else:
            print("Can't get token for", username)
        return track_list
    
    
    def get_my_top_artists(self):
        spotipy_token = self.spotipy_auth()
        artists = []
        if spotipy_token:
            sp = spotipy.Spotify(auth=spotipy_token)
            sp.trace = False
            ranges = ['short_term', 'medium_term', 'long_term']
            for r in ranges:
                results = sp.current_user_top_artists(time_range=r, limit=10)
                for i, item in enumerate(results['items']):
                    artists.append(item['name'])

        else:
            print("Can't get token for", username)
        return set(artists)
    
    #get functions
    #albums
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_album_tracks(self, _id):
        return self.get_resource(_id, resource_type='albums', extras = '/tracks')
    
    #artists
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def get_artist_albums(self, _id):
        return self.get_resource(_id, resource_type='artists', extras='/albums')
    
    def get_artist_top_tracks(self, _id):
        endpoint = f"https://api.spotify.com/v1/artists/{_id}/top-tracks?country=US"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        #if r.status_code not in range(200, 299):
            #return {}
        return r.json()
    
    def get_similar_artist(self, _id):
        return self.get_resource(_id, resource_type='artists', extras = '/related-artists')
    
    #tracks
    def get_audio_data(self, _id):
        return self.get_resource(_id, resource_type='audio-features')
    
    def get_audio_analysis(self, _id):
        return self.get_resource(_id, resource_type='audio-analysis')
    
    
    def new_releases(self):
        endpoint = "https://api.spotify.com/v1/browse/new-releases"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
   
    
    #search
    def base_search(self, query_params): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()
    
    def search(self, query = None, operator = None, operator_query = None, search_type='artist'):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == 'or' or operator.lower() == 'not':
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret, redirect_uri)
#instance of client

# %%
my_top_artists = list(spotify.get_my_top_artists())
my_top_artists
# Out:
# ['iann dior',
#  'Ed Sheeran',
#  'Lil Uzi Vert',
#  'Khalid',
#  'Eminem',
#  'Marshmello',
#  'XXXTENTACION',
#  'Juice WRLD',
#  'A Boogie Wit da Hoodie',
#  'Dua Lipa',
#  'Halsey',
#  'The Weeknd',
#  'Loud Luxury',
#  'YNW Melly',
#  'Drake',
#  'NF']

# %%
my_current_top_50 = spotify.top_tracks_current()
my_current_top_50
# Out:
# ['Relationship (feat. Future)-Young Thug',
#  'Eenie Meenie - Radio Version-Sean Kingston',
#  'ily (i love you baby) (feat. Emilee)-Surf Mesa',
#  'Foreplay-Jalen Santoy',
#  'Without Me (with Juice WRLD)-Halsey',
#  'Wassup (feat. Future)-Lil Uzi Vert',
#  'Drinking Problem (feat. 27CLUB)-Arizona Zervas',
#  'Sunny Days-Edward Maya',
#  'Trap - Rompasso Remix-SAINt JHN',
#  'These Days (feat. Jess Glynne, Macklemore & Dan Caplen)-Rudimental',
#  'Feeling-Juice WRLD',
#  'High On Life (feat. Bonn)-Martin Garrix',
#  'Love To Go-Lost Frequencies',
#  'Too Good-Drake',
#  'bad vibes forever-XXXTENTACION',
#  'Tinted Eyes (feat. blackbear & 24kGoldn)-DVBBS',
#  'Paris-Cevith',
#  'King Of My City-A Boogie Wit da Hoodie',
#  'The Hills-The Weeknd',
#  'R.O.D.-A Boogie Wit da Hoodie',
#  'Might Not Give Up (feat. Young Thug)-A Boogie Wit da Hoodie',
#  'Reply (feat. Lil Uzi Vert)-A Boogie Wit da Hoodie',
#  'Skinny Love-Birdy',
#  'Blame (feat. John Newman)-Calvin Harris',
#  'Cold Feet-Loud Luxury',
#  'Godzilla-Aftermath',
#  'Mr. Saxobeat-Alexandra Stan',
#  'Sixteen - Acoustic-Ellie Goulding',
#  'Too Good At Goodbyes-Sam Smith',
#  'everything i wanted-Billie Eilish',
#  'Vossi Bop-Stormzy',
#  'Art School Wannabe-Sorority Noise',
#  'Medium Fries-YNW Melly',
#  'Wasted-Tiësto',
#  'Go Dumb (feat. blackbear, The Kid LAROI and Bankrol Hayden)-Y2K',
#  'Indiana-Just Kiddin',
#  'Reminder-The Weeknd',
#  'Tell Me U Luv Me (with Trippie Redd)-Juice WRLD',
#  'molly-iann dior',
#  'Beautiful Pain (Losin My Mind)-Polo G',
#  'Barking-Ramz',
#  'Money over Everything-A Boogie Wit da Hoodie',
#  'Waveforms-Django Django',
#  'Tu Meri - Jersey Club Remix By Jayhaan-Jayhaan',
#  'Behind Barz - Bonus-Drake',
#  'Falling-Trevor Daniel',
#  'You & I (feat. Tyler Sjöström & Bertrand Lacoste)-Sterkøl',
#  'My Love (feat. Jess Glynne)-Route 94',
#  'Hey Julie! (feat. Lil Yachty) - Absofacto Remix-KYLE',
#  "Won't Fuck Us Over-The Hood Internet"]

# %%
my_library = spotify.get_my_tracks()
my_library
# Out:
# ['Shameless - iann dior',
#  'Cinderella Story - A Boogie Wit da Hoodie',
#  'Gummy - Loud Luxury',
#  'Relationship (feat. Future) - Young Thug',
#  'Close Friends (Lil Baby & Gunna) - Lil Baby',
#  'GO (feat. Juice WRLD) - The Kid LAROI',
#  'Addison Rae - The Kid LAROI',
#  'Trap - Rompasso Remix - SAINt JHN',
#  'VALENTINO - Imanbek Remix - 24kGoldn',
#  'The Bigger Picture - Lil Baby',
#  'Lalala - Ilkan Gunuc Remix - Y2K',
#  'Otherside Of America - Meek Mill',
#  'Alien - Dennis Lloyd',
#  'Tomorrow (feat. 433) - Tiësto',
#  'GO (feat. Juice WRLD) - The Kid LAROI',
#  'You & I (feat. Tyler Sjöström & Bertrand Lacoste) - Sterkøl',
#  'Paris - Cevith',
#  'Godzilla - Aftermath',
#  'Keeps Me High (WHOCARES Remix) - HADES',
#  'I Love My Friends (And My Friends Love Me) - Steve Aoki',
#  'Tinted Eyes (feat. blackbear & 24kGoldn) - DVBBS',
#  'Kiss Me Hard - DJ Antoine vs Mad Mark 2k20 Mix - DJ Antoine',
#  'Best Friend (feat. Tory Lanez) - A Boogie Wit da Hoodie',
#  "F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar) - A$AP Rocky",
#  'Antisocial (with Travis Scott) - Ed Sheeran',
#  'Who Needs Love - Trippie Redd',
#  'Weak When Ur Around - blackbear',
#  'Way Too Fly (feat. DaVido) - A Boogie Wit da Hoodie',
#  'Foreigner (feat. A Boogie Wit da Hoodie) - Pop Smoke',
#  'Satisfaction (Isak Original Extended) - Benny Benassi Presents The Biz - Benny Benassi',
#  "Won't Fuck Us Over - The Hood Internet",
#  'South of the Border (feat. Camila Cabello & Cardi B) - Ed Sheeran',
#  'ily (i love you baby) (feat. Emilee) - Surf Mesa',
#  'Next Round on Me - twoloud',
#  'Roses Remix (feat. Future) - SAINt JHN',
#  'Both Sides (feat. Lil Baby) - Gucci Mane',
#  'Kalinka - Dimitri Vegas & Like Mike Edit - Timmy Trumpet',
#  'A-List - Remix - Speedy',
#  'goosebumps - Skylar Grey',
#  'TKN (feat. Travis Scott) - ROSALÍA',
#  'Oxygen - Winona Oak',
#  'Tell Me U Luv Me (with Trippie Redd) - Juice WRLD',
#  'X - Nicky Jam',
#  'X (feat. Maluma & Ozuna) - Remix - Nicky Jam',
#  'Motto (feat. Lil Uzi Vert, G-Eazy & Mally Mall) - David Guetta',
#  'Sweet & Bitter - Kush Kush',
#  'SnD - Jah Khalib',
#  'Zombie (Zombic & Felix Schorn Remix) - Besomorph',
#  'Down - KALUMA',
#  'Sad (feat. Afrojack) - Chico Rose',
#  'London - DJ Antoine Vs Mad Mark 2k16 Radio Edit - DJ Antoine',
#  'You & I - Bru-C',
#  'In And Out Of Love - Armin van Buuren',
#  'After Hours - The Weeknd',
#  'Need Me - J.I the Prince of N.Y',
#  "Nobody's Better (feat. Fetty Wap) - Z",
#  'Eenie Meenie - Radio Version - Sean Kingston',
#  'Wake Up Dead - T-Pain',
#  "That's A Fact (feat. Fivio Foreign & Mr. Swipey) - Remix - French Montana",
#  'Mazel Tov - IDK',
#  'Prospect (ft. Lil Baby) - iann dior',
#  'Rain On Me (with Ariana Grande) - Lady Gaga',
#  'Hopeless Romantic (feat. Swae Lee) - Wiz Khalifa',
#  'Chicago\u202c\u202c - Vigiland',
#  'Drown (feat. Clinton Kane) - Martin Garrix',
#  'All Around The World (La La La) - Marnik Remix - R3HAB',
#  'My Best Life (feat. Mike Waters) - Club Mix - KSHMR',
#  'SOS (feat. Aloe Blacc) - Avicii',
#  'House Party - Radio Edit - DJ Antoine',
#  'My Love (feat. Jess Glynne) - Route 94',
#  'Right Now (Na Na Na) - Akon',
#  'Summer of Love - Cascada',
#  'Temperature Rising - Tory Lanez',
#  'Daisies - Katy Perry',
#  'Beautiful Pain (Losin My Mind) - Polo G',
#  'Rude Boy - Rihanna',
#  'Tu Meri - Jersey Club Remix By Jayhaan - Jayhaan',
#  'Push It - O.T. Genasis',
#  'I Would Like - Zara Larsson',
#  'Tuesday - NALYRO',
#  'Bad - Don Diablo',
#  'No Church In The Wild - JAY-Z',
#  'Drown (feat. Clinton Kane) - Alle Farben Remix - Martin Garrix',
#  'Mixed Personalities (feat. Kanye West) - YNW Melly',
#  'Right Back - A Boogie Wit da Hoodie',
#  'D.T.B. (Interlude) - A Boogie Wit da Hoodie',
#  'Stalking You - A Boogie Wit da Hoodie',
#  'Ruthless (Nice Guys Always Finish Last) - MarMar Oso',
#  'In Her Eyes - Basshunter',
#  'Summer Air - ItaloBrothers',
#  'Perfect Strangers - Jonas Blue',
#  'Hundred Miles - Yall',
#  'Rude - Fets',
#  'Tusa - KAROL G',
#  'Toosie Slide - Drake',
#  'THE SCOTTS - THE SCOTTS',
#  'Tennis Court - Lorde',
#  'Don’t Need Love (with GRACEY) - Majestic Remix - 220 KID',
#  'No Way Out (feat. Kat Nestel) - Radio Edit - Vicetone',
#  'Don’t Need Love (with GRACEY) - 220 KID',
#  'All In - Lil Baby',
#  'We Should (feat. Young Thug) - Lil Baby',
#  'Emotionally Scarred - Lil Baby',
#  'Vossi Bop - Stormzy',
#  'BEST ON EARTH (feat. BIA) - Bonus - Russ',
#  'Psycho! - MASN',
#  'Sunny Days - Edward Maya',
#  'Drown (feat. Clinton Kane) - Nicky Romero Remix - Martin Garrix',
#  'Physical - Alok Remix - Dua Lipa',
#  'Social Distancing - Lil Baby',
#  'Eleven (feat. Summer Walker) - Khalid',
#  'D4L - Future',
#  'Better Days (feat. Fetty Wap) - Coi Leray',
#  'We Should (feat. Young Thug) - Lil Baby',
#  'Indiana - Just Kiddin',
#  'Pieces - AVAION',
#  'Ai Ai Ai - Felguk & Cat Dealers Remix - Vanessa Da Mata',
#  'In The Middle - Alesso',
#  'Beautiful People (feat. Khalid) - NOTD Remix - Ed Sheeran',
#  'Body Language - M.A.N.D.Y.',
#  'Shadow of the Day - Echos',
#  'Monster - Robin Schulz Remix - LUM!X',
#  'Time For You - Taio Cruz',
#  "I Was Lovin' You (feat. Dots Per Inch & Ayak) - TS7 Remix - James Hype",
#  'Live a Little (Remix) - BONNIE X CLYDE',
#  'Lazy Bones - Otis Big Guitar Mix - Green Day',
#  'My Gang - Quablab',
#  'Stay Away (feat. Machine Gun Kelly & Goody Grace) - MOD SUN',
#  'Righteous - Juice WRLD',
#  'Go Dumb (feat. blackbear, The Kid LAROI and Bankrol Hayden) - Y2K',
#  'Fade Away - The Kid LAROI',
#  'wokeuplikethis* - Playboi Carti',
#  'Art School Wannabe - Sorority Noise',
#  'Get Hyper - Radio Edit - Droideka',
#  'Survivor - Desiigner',
#  'Sick and Tired - iann dior',
#  '1 4 U - Steve Aoki',
#  'Love To Go - Lost Frequencies',
#  'DROP (feat. A Boogie wit da Hoodie & London On Da Track) - DaBaby',
#  'Freedom - Kygo',
#  'ROCKSTAR (feat. Roddy Ricch) - DaBaby',
#  'Roses - Imanbek Remix - SAINt JHN',
#  'Blueberry Faygo - Lil Mosey',
#  'Flex (Ooh, Ooh, Ooh) - Rich Homie Quan',
#  '99 Problems & Messages - A Boogie Wit da Hoodie',
#  'Friend Zone - A Boogie Wit da Hoodie',
#  'Drinking Problem (feat. 27CLUB) - Arizona Zervas',
#  'Stupid Again - Tory Lanez',
#  'Through Da Storm - Polo G',
#  'The Rhythm of the Night - Corona',
#  'Camelot - NLE Choppa',
#  'Shotta Flow (feat. Blueface) [Remix] - NLE Choppa',
#  'IDK - Lil Tecca',
#  "Can't Deny (feat. Lil Tecca) - Nebu Kiniza",
#  'What I Like (feat. Rich The Kid & Tyga) - Famous Dex',
#  'Issues - Westside Tut',
#  'Still Be Friends (feat. Tory Lanez & Tyga) - G-Eazy',
#  'Sunny Days - Extended - Edward Maya',
#  'Slang That Iron - YNW Melly',
#  'Holly Wood Died - Yellowcard',
#  'I Try - Trippie Redd',
#  'Bum Bum Tam Tam - MC Fioti',
#  'Alive - Krewella',
#  'Clarity - Zedd',
#  'Somebody That I Used To Know - Gotye',
#  'One Call Away - Charlie Puth',
#  'Where Did You Go - wrldofjuice',
#  'PTSD - G Herbo',
#  'Monster - LUM!X',
#  'Fiesta - Michael Mind Project Video Edit - Carlprit',
#  'Rhythmus wie ein Tänzer - Culcha Candela',
#  "I'll Wait - Kygo",
#  'Shoota (feat. Lil Uzi Vert) - Playboi Carti',
#  'Stay - Zedd',
#  'Down - Jay Sean',
#  'Say My Name - David Guetta',
#  '6 Kiss - Trippie Redd',
#  'Drinking Problem - Arizona Zervas',
#  'Icon - Jaden',
#  "Don't Mind - Kent Jones",
#  'Now and Later - Sage The Gemini',
#  'Mi Mi Mi - SEREBRO',
#  "C'est La Vie - Khaled",
#  '20 Min - Lil Uzi Vert',
#  'Cut It (feat. Young Dolph) - O.T. Genasis',
#  'CoCo - O.T. Genasis',
#  'Sunny Nights - LeRoyce',
#  'Slow Loud & Bangin - Chamillionaire',
#  "Ain't Nobody (Loves Me Better) (feat. Jasmine Thompson) - Felix Jaehn",
#  'One Take - Lil Tjay',
#  'Pretty Please - Dua Lipa',
#  'Levitating - Dua Lipa',
#  'Ten Talk - YoungBoy Never Broke Again',
#  'Let Her Go - The Kid LAROI',
#  'Aftertaste - Loud Luxury',
#  'One True Love (with Slushii) - Steve Aoki',
#  'Banana Split (with YNW Melly feat. Lil Durk) - Murda Beatz',
#  'Break My Heart - Dua Lipa',
#  'molly - iann dior',
#  'All My Life - Lucas & Steve Edit - Bassjackers',
#  'Lonely - Joel Corry',
#  'Post Malone (feat. RANI) - GATTÜSO Remix - Sam Feldt',
#  'Congratulations - Don Diablo',
#  'What You Want - Belly',
#  'Kryptonite - 3 Doors Down',
#  'Tennis Court - Lorde',
#  'Wife You - Childish Major',
#  'High For This - The Weeknd',
#  'Crew Love - Drake',
#  'Often - The Weeknd',
#  'The Morning - The Weeknd',
#  'Loft Music - The Weeknd',
#  'Lost in the Fire - Gesaffelstein',
#  'Try Me - The Weeknd',
#  'Ordinary Life - The Weeknd',
#  'Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) - Remix - Ty Dolla $ign',
#  'Wicked Games - The Weeknd',
#  '1 Thing - Amerie',
#  'Living In America - DoM',
#  'Gunsmoke - YoungBoy Never Broke Again',
#  'Dior Chain - Solum OG',
#  'Starry Eyed - Russ Chimes Remix - Ellie Goulding',
#  'You should be sad - Acoustic - Halsey',
#  'Save Your Tears - The Weeknd',
#  'In Your Eyes - The Weeknd',
#  'Faith - The Weeknd',
#  'Snowchild - The Weeknd',
#  'Hardest To Love - The Weeknd',
#  'Too Late - The Weeknd',
#  'No Love - Eminem',
#  'Love Game - Eminem',
#  'The Monster - Eminem',
#  'Like I Love You - Lost Frequencies',
#  'Feels Like Home - Radio Edit - The Him',
#  'Show Me Love - EDX Remix / Radio Edit - Sam Feldt',
#  'Often - Kygo Remix - The Weeknd',
#  'Ready For Love - Cascada',
#  'Bagpipes From Baghdad - Eminem',
#  'Tribe (with J. Cole) - Bas',
#  'Sauce It Up - Lil Uzi Vert',
#  'La La Land (feat. YG) - Bryce Vine',
#  "Ghosts 'n' Stuff - deadmau5",
#  'DJ Turn It Up - Yellow Claw',
#  'Strobe - deadmau5',
#  'Demolition 1 + 2 - KEY!',
#  'RIP Harambe - Emo G Records',
#  'Moves Like Jagger - Studio Recording From The Voice Performance - Maroon 5',
#  'Answer To Yourself - The Soft Pack',
#  'Waveforms - Django Django',
#  'Got The Guap (feat. Young Thug) - Lil Uzi Vert',
#  'Moon Relate - Lil Uzi Vert',
#  'Strawberry Peels (feat. Young Thug & Gunna) - Lil Uzi Vert',
#  'Wassup (feat. Future) - Lil Uzi Vert',
#  'Yessirskiii - Lil Uzi Vert',
#  'Bean (Kobe) [feat. Chief Keef] - Lil Uzi Vert',
#  'Lotus - Lil Uzi Vert',
#  'Myron - Lil Uzi Vert',
#  'Fire - KIDS SEE GHOSTS',
#  'Seven Million (feat. Future) - Lil Uzi Vert',
#  'BLUE - Tiësto',
#  'Intentions (feat. Quavo) - Justin Bieber',
#  'Blessings REMIX (feat. French Montana & Davido) - Angel',
#  "Like the Way I Do - Yanou's Candlelight Mix - Cascada",
#  'Gummy - Loud Luxury',
#  'Bad Child - Tones And I',
#  'Worry About Me (feat. blackbear) - Ellie Goulding',
#  'Suicidal (Remix) [feat. Juice WRLD] - YNW Melly',
#  'ROXANNE - Arizona Zervas',
#  'Gold - Kiiara',
#  "I Think I'm OKAY (with YUNGBLUD & Travis Barker) - Machine Gun Kelly",
#  '5:3666 - Machine Gun Kelly',
#  'Hollywood Whore - Machine Gun Kelly',
#  'Outnumbered - Dermot Kennedy',
#  'My Way (feat. Monty) - Fetty Wap',
#  'Secure The Bag - Lil Uzi Vert',
#  'That Way - Lil Uzi Vert',
#  'Lost in the Middle of Nowhere (feat. Becky G) (Spanish Remix) - Kane Brown',
#  'Say It - Crankdat',
#  'Happy Now - Kygo',
#  'Whippin (feat. Felix Snow) - Kiiara',
#  'Nobody - Martin Jensen',
#  'Cheyenne - Jason Derulo',
#  "I'm a Mess - Bebe Rexha",
#  'Rolling in the Deep - Adele',
#  'Complicated - Avril Lavigne',
#  'Sk8er Boi - Avril Lavigne',
#  'Fire (feat. DJ Snake & French Montana) - RUNWAY',
#  'Stand By Me - John Newman',
#  'SUGAR (Remix) [feat. Dua Lipa] - BROCKHAMPTON',
#  'Diva - Desiigner',
#  'P2 - Lil Uzi Vert',
#  'Venetia - Lil Uzi Vert',
#  'Bust Me - Lil Uzi Vert',
#  'Bigger Than Life - Lil Uzi Vert',
#  'Celebration Station - Lil Uzi Vert',
#  "I'm Sorry - Lil Uzi Vert",
#  'Baby Pluto - Lil Uzi Vert',
#  'Pizza - Martin Garrix',
#  'Medium Fries - YNW Melly',
#  "223's (feat. 9lokknine) - YNW Melly",
#  'Virtual (Blue Balenciagas) - YNW Melly',
#  'Miracle - CHVRCHES',
#  'I Wonder - Kanye West',
#  'Mercy - Muse',
#  "Ballin' (with Roddy Ricch) - Mustard",
#  "I'm Not Sorry - Hardwell",
#  'Runaway (U & I) - Galantis',
#  'All We Do - Oh Wonder',
#  'Dark Out - Global Dan',
#  'TAlk tO Me (with Rich The Kid feat. Lil Wayne) - Remix - Tory Lanez',
#  'Tamagotchi (Bonus) - Eldzhey',
#  'Stereo Love - Timmy Trumpet Remix - Edward Maya',
#  'Cruel Intentions - Delacey',
#  'Unforgettable (feat. Swae Lee) - Original remix - French Montana',
#  'Nights Like This - Loud Luxury',
#  'Artist - A Boogie Wit da Hoodie',
#  'Trap House - A Boogie Wit da Hoodie',
#  'Money over Everything - A Boogie Wit da Hoodie',
#  '1hunnit - A Boogie Wit da Hoodie',
#  'No Comparison - A Boogie Wit da Hoodie',
#  "Till It's Gone - Yelawolf",
#  'Uptown / Bustdown (feat. PnB Rock and Lil Durk) - A Boogie Wit da Hoodie',
#  'Skeezers - A Boogie Wit da Hoodie',
#  'Beasty - A Boogie Wit da Hoodie',
#  'Wait (feat. A Boogie Wit da Hoodie) - Maroon 5',
#  "Say A' - A Boogie Wit da Hoodie",
#  'My Shit - A Boogie Wit da Hoodie',
#  'Come Out and Play - The Offspring',
#  'VIBEZ - DaBaby',
#  'Pick Me Up Then Let Me Fall - Lil Rae',
#  'You should be sad - Tiësto Remix - Halsey',
#  'You should be sad - Halsey',
#  'Blood On My Denim - A Boogie Wit da Hoodie',
#  'Runnin (with A$AP Rocky, A$AP Ferg & Nicki Minaj) - Mike WiLL Made-It',
#  'Blueberry Faygo - Lil Mosey',
#  'How I Was Raised - Trippie Redd',
#  'Only One - Carlie Hanson',
#  'Without You (feat. Sandro Cavazza) - Avicii',
#  'Levels - Radio Edit - Avicii',
#  'Wake Me Up - Radio Edit - Avicii',
#  'Give Me Your Love - Chad B',
#  'Let You Go - lor 3leven',
#  'Life Is Good (feat. Drake, DaBaby & Lil Baby) - Remix - Future',
#  'Used To Love - Acoustic Version - Martin Garrix',
#  'After Hours - The Weeknd',
#  'YES! (feat. Rich The Kid & K CAMP) - KYLE',
#  'stevie - Kasabian',
#  'Show U Off (feat. Lil Uzi Vert) - Lud Foe',
#  "Streets Don't Love You - A Boogie Wit da Hoodie",
#  "Hit 'Em Up (feat. Trap Manny) - A Boogie Wit da Hoodie",
#  'Not a Regular Person - A Boogie Wit da Hoodie',
#  'Jungle - A Boogie Wit da Hoodie',
#  'Stain (feat. DaBaby) - A Boogie Wit da Hoodie',
#  'DTB 4 Life - A Boogie Wit da Hoodie',
#  'Good Girls Gone Bad - A Boogie Wit da Hoodie',
#  'Thug Love - A Boogie Wit da Hoodie',
#  'Might Not Give Up (feat. Young Thug) - A Boogie Wit da Hoodie',
#  'Mood Swings - A Boogie Wit da Hoodie',
#  'Me and My Guitar - A Boogie Wit da Hoodie',
#  'Numbers (feat. Roddy Ricch, Gunna and London On Da Track) - A Boogie Wit da Hoodie',
#  'King Of My City - A Boogie Wit da Hoodie',
#  'R.O.D. - A Boogie Wit da Hoodie',
#  'Luv Is Art (feat. Lil Uzi Vert) - A Boogie Wit da Hoodie',
#  'Just For You - Fetty Wap',
#  'LENTO (with Sean Paul & Mozart La Para feat. Cazzu) - Tainy',
#  'Love Is a Drug - YSG Sadboy',
#  'Something Different - Jalen Santoy',
#  'Forever (feat. Post Malone & Clever) - Justin Bieber',
#  'Reasons - Fetty Wap',
#  'Cold Feet - Loud Luxury',
#  'Hide Away - Daya',
#  'Safe And Sound - Capital Cities',
#  'Neon Lights - Demi Lovato',
#  'Rather Be (feat. Jess Glynne) - Clean Bandit',
#  'Rocketeer - Far East Movement',
#  'Leave a Light On - Cheat Codes Remix - Tom Walker',
#  'Sex - Cheat Codes',
#  "Who's Got Your Love - Cheat Codes",
#  'No Promises (feat. Demi Lovato) - Cheat Codes',
#  'In My Head - Jason Derulo',
#  'Cheerleader - Felix Jaehn Remix Radio Edit - OMI',
#  'No Beef ft. Miss Palmer - Vocal Mix - Afrojack',
#  'Mammoth - Dimitri Vegas & Like Mike',
#  'Stay The Night - Featuring Hayley Williams Of Paramore - Zedd',
#  'In The Dark - Tiësto',
#  'Sing La La la (feat. Flo Rida & Dale Saunders) [E-Partment Short Mix] - Carolina Marquez',
#  "Don't Matter - Akon",
#  'Rivers - Thomas Jack',
#  'Calling (Lose My Mind) - Radio Edit - Sebastian Ingrosso',
#  "I Don't Know Why - Viale & Dj Ross Radio Cut - Moony",
#  'Lose Control - MEDUZA',
#  'Party Time - Tiësto',
#  'Still Be Friends (feat. Tory Lanez & Tyga) - G-Eazy',
#  'Trust Nobody (ft. Adam Levine) - Lil Wayne',
#  'Hurricane (with John Newman) - Galantis',
#  'Meet Me on the Roof - Green Day',
#  'Astronomia - Vicetone',
#  'Dancin - Krono Remix - Aaron Smith',
#  'Odd Look - Kavinsky',
#  'Midnight City - Eric Prydz Private Remix - M83',
#  'Old English - Young Thug',
#  'Wishing Well (Lauryn Hill) - Lucas WRLD',
#  'Heads Will Roll - Yeah Yeah Yeahs',
#  'All Girls Are The Same - Juice WRLD',
#  'Little Engine - Eminem',
#  'Let you go - lor 3leven',
#  'No Service In The Hills (feat. Trippie Redd, Blackbear, PRINCE$$ ROSIE) - Cheat Codes',
#  'Diva (feat. Lil Tecca) - The Kid LAROI',
#  'loneliness for love - lovelytheband',
#  'Letter To Nipsey (feat. Roddy Ricch) - Meek Mill',
#  'Explosive - HUNTR',
#  'Physical - Dua Lipa',
#  "Better When You're Gone - David Guetta",
#  '85% - Loote',
#  'King Of My City - A Boogie Wit da Hoodie',
#  'Shots - Lil Tecca',
#  'Where Is The Love? - Black Eyed Peas',
#  'International Love (feat. Chris Brown) - Pitbull',
#  'We Are One (Ole Ola) [The Official 2014 FIFA World Cup Song] (feat. Jennifer Lopez & Claudia Leitte) - Pitbull',
#  'Skinny Love - Birdy',
#  'Reminder - The Weeknd',
#  'DotA - Basshunter',
#  'Idfc - blackbear',
#  '#icanteven (feat. French Montana) - The Neighbourhood',
#  'Only - Nicki Minaj',
#  'Lights Out (Too Drunk) [feat. Hayla] - Extended Mix - DJ Katch',
#  'Bad Things (with Camila Cabello) - Machine Gun Kelly',
#  'Acquainted - The Weeknd',
#  'Forever Yours - Avicii Tribute - Kygo',
#  'You Could Be - R3HAB',
#  'Look Back at It - Tiësto and SWACQ Remix - A Boogie Wit da Hoodie',
#  'Glorious (feat. Skylar Grey) - Macklemore',
#  'All the Pretty Girls - KALEO',
#  'Godzilla (feat. Juice WRLD) - Eminem',
#  'Do What I Want - Lil Uzi Vert',
#  'Two® - Lil Uzi Vert',
#  '7AM - Lil Uzi Vert',
#  'Goyard Bag - Fabolous',
#  'Self Control - YoungBoy Never Broke Again',
#  'Marvelous Day (feat. Lil Uzi Vert & Gunna) - Kap G',
#  '6 Feet Under - Miles Wesley',
#  'Ante Up (Robbin Hoodz Theory) - M.O.P.',
#  '3am - Halsey',
#  'All I Know - Time',
#  'Still Learning - Halsey',
#  'Be Free - Edward Maya',
#  'Me Gusta - Shakira',
#  'Feel Alone - Boostee',
#  'Ma Chérie - DJ Antoine & Mad Mark 2K12 Radio Edit - DJ Antoine',
#  'Elinor - Basshunter',
#  'La Vie en Rose - DJ Antoine & Mad Mark 2k17 Mix - DJ Antoine',
#  "You're Ma Cherie - DJ Antoine vs Mad Mark 2k13 Radio Edit - DJ Antoine",
#  'Ok Without You - Klaas',
#  'Mambo No. 5 (a Little Bit of...) - Lou Bega',
#  'Rhythm Is A Dancer - 7" Edit - SNAP!',
#  'Everytime We Touch - Radio Edit - Cascada',
#  'Coco Jamboo - Mr. President',
#  "Now You're Gone (feat. DJ Mental Theo's Bazzheadz) - Radio Edit - Basshunter",
#  'Around the World (La La La La La) - Radio Version - A Touch Of Class',
#  'Better Off Alone - Alice DJ',
#  'everything i wanted - Billie Eilish',
#  'Dance Monkey - Tones And I',
#  'Candy (feat. Trippie Redd) - Machine Gun Kelly',
#  'Sky Is the Limit - DJ Antoine',
#  'My Life Is a Party - Club Mix - ItaloBrothers',
#  'This is My Life - Radio Version - Edward Maya',
#  'Forever - NLE Choppa',
#  'Fine China - Future',
#  'Let Me Hold You (Turn Me On) - Cheat Codes',
#  'Delirious (Boneless) (feat. Kid Ink) - Steve Aoki',
#  'El Camino - Black Caviar',
#  'Dragostea Din Tei - Original Italian Version - O-Zone',
#  'All I Ever Wanted - Radio Edit - Basshunter',
#  'The Sound - The 1975',
#  'Can You Hold Me - NF',
#  'Malfunction - Lil Uzi Vert',
#  'VALENTINO (feat. Lil Tjay) - Remix - 24kGoldn',
#  'Life Is Good (feat. Drake) - Future',
#  'Piece Of Your Heart - MEDUZA',
#  'No Heart - YNW Melly',
#  'Blue (Da Ba Dee) - Gabry Ponte Ice Pop Radio - Eiffel 65',
#  "Stacy's Mom - Fountains Of Wayne",
#  'Feel So Close - Radio Edit - Calvin Harris',
#  'Bones (feat. OneRepublic) - Galantis',
#  'Summer - Marshmello',
#  'Dying for You - YNW BSlime',
#  'Suicidal - YNW Melly',
#  'Ride It - Regard',
#  'Pop Out (feat. Lil Tjay) - Polo G',
#  'Dark Queen - Lil Uzi Vert',
#  'Balada - Ao Vivo - Gusttavo Lima',
#  'Sun Is Up - Play & Win Radio Edit - INNA',
#  'Say Something - A Great Big World',
#  '700 Main Street - DAT ADAM',
#  'Big Love - Havana',
#  'I Need A Doctor - Dr. Dre',
#  'Lalala - Remix - [feat. Enrique Iglesias & Carly Rae Jepsen] - Y2K',
#  'Hotel Room Service - Pitbull',
#  'Flowers - iann dior',
#  'Hit It - American Authors',
#  "What's the Move (feat. Lil Uzi Vert) - Young Thug",
#  'What About Us - P!nk',
#  'Too Many Gods - A$AP Rocky',
#  'I Mean It (feat. Remo) - G-Eazy',
#  'My Way - Calvin Harris',
#  'Salt - Ava Max',
#  'Future Nostalgia - Dua Lipa',
#  'NRG - Chase & Status',
#  'ADHD - Joyner Lucas',
#  'Erase Your Social - Lil Uzi Vert',
#  'Reply (feat. Lil Uzi Vert) - A Boogie Wit da Hoodie',
#  'Futsal Shuffle 2020 - Lil Uzi Vert',
#  'Wanted You (feat. Lil Uzi Vert) - NAV',
#  'Calabria 2008 (feat. Natasja) - Enur',
#  'iSpy (feat. Lil Yachty) - KYLE',
#  'Feel Good Inc. - Gorillaz',
#  'Redbone - Childish Gambino',
#  'Let Me Know (I Wonder Why Freestyle) - Juice WRLD',
#  'Big Stepper - Roddy Ricch',
#  'Enemies (feat. DaBaby) - Post Malone',
#  'My Oh My (feat. DaBaby) - Camila Cabello',
#  'Comfortable (feat. X Ambassadors) - The Knocks',
#  "SUGA's Interlude - Halsey",
#  'Waste It On Me - Steve Aoki',
#  'Hot Gyal - XXXTENTACION',
#  'Kill My Vibe - XXXTENTACION',
#  'Ecstasy - XXXTENTACION',
#  'LIMBO - XXXTENTACION',
#  'Triumph - XXXTENTACION',
#  'I Changed Her Life - XXXTENTACION',
#  'Ex Bitch - XXXTENTACION',
#  '100 Thousand - Navvy',
#  'A Milli - Lil Wayne',
#  'Cigarette Daydreams - Cage The Elephant',
#  'Scared to Be Happy - Navvy',
#  'Waiting For Love - Carnage & Headhunterz Remix - Avicii',
#  'Monica Lewinsky - SAINt JHN',
#  'Another You - Radio Edit - Armin van Buuren',
#  'This Is What It Feels Like - Armin van Buuren',
#  'No Way Out - Radio Edit - Vicetone',
#  'In My Mind - Dynoro',
#  'Teach Me How to Dougie - Cali Swag District',
#  'Talk with Your Body - Jason Derulo',
#  'Only Girl (In The World) - Rihanna',
#  'I Like It - Enrique Iglesias',
#  'Blinding Lights - The Weeknd',
#  'Needed - iann dior',
#  'Graveyard - Acoustic - Halsey',
#  'Tip Toe (feat. A Boogie Wit da Hoodie) - Roddy Ricch',
#  'About You (feat. blackbear) - Mike Shinoda',
#  'Waiting For Tomorrow (feat. Mike Shinoda) - Martin Garrix',
#  'King Wizard - Kid Cudi',
#  'No Excuses - NF',
#  'Heartless - The Weeknd',
#  'Fast Lane - Bad Meets Evil',
#  'Hello World - Kid Ink',
#  'We Had Love - Extended - Monoir',
#  'Song About You (Digital Farm Animals & Franklin Remix) - Mike Posner',
#  'Dessert - Dawin',
#  'Desert Rain (feat. Vika Jigulina) - Edward Maya',
#  'Mr. Saxobeat - Alexandra Stan',
#  'Feel (feat. Sena Sener) - Radio Edit - Mahmut Orhan',
#  "Wavin' Flag - K'NAAN",
#  'Tuesday (feat. Danelle Sandoval) - Burak Yeter',
#  'Song About You - Mike Posner',
#  'So Close - NOTD',
#  'Riptide - Vance Joy',
#  'Did It Again - Lil Tecca',
#  'Dreams - NF',
#  'the remedy for a broken heart (why am I so in love) - XXXTENTACION',
#  'Holy Ghost - Desiigner',
#  'Alors on danse - Stromae',
#  'LOYAL (feat. Drake) - PARTYNEXTDOOR',
#  'Own It (feat. Ed Sheeran & Burna Boy) - Stormzy',
#  'Talk About Us (feat. Stefflon Don) - Jason Derulo',
#  'NUMB - Acoustic - XXXTENTACION',
#  'Quite Miss Home - Steve Void Remix - James Arthur',
#  'bad vibes forever - XXXTENTACION',
#  'Goodbye - Glenn Morrison',
#  'Rolex - Ayo & Teo',
#  'Still D.R.E. - Dr. Dre',
#  'Canvas Bags - Tim Minchin',
#  'LONER - JUMEX',
#  'Heartbreaker (feat. John Legend) - MSTRKRFT',
#  'Gospel - Rich Brian',
#  'Reality (feat. Janieck Devy) - Radio Edit - Lost Frequencies',
#  'King - Years & Years',
#  'Dance Til Your Dead - Lil Memer',
#  'Coming Home - Part II / Bonus Track - Skylar Grey',
#  'Stuck In A Dream (feat. Gunna) - Lil Mosey',
#  'Oh Mama - Milky Chance',
#  "Drop It Like It's Hot - Snoop Dogg",
#  'Rather Be Alone (feat. Nick Martin) - Madison Mars Remix - Robin Schulz',
#  'CASH COW - NGHTMRE',
#  'Fangirl - Lil Peep',
#  'Live Before I Die - Naughty Boy x Mike Posner - Naughty Boy',
#  'Tongue Tied (with YUNGBLUD & blackbear) - Marshmello',
#  'Mai Tais (feat. Skylar Grey) - Train',
#  'Bankroll (feat. AJ Tracey) - Lil Mosey',
#  'Youngblood - 5 Seconds of Summer',
#  'Up All Night - Beck',
#  'Sunday Morning - Maroon 5',
#  'Roses (with Juice WRLD feat. Brendon Urie) - benny blanco',
#  'Live This Wild - Lil Mosey',
#  'Bring Me Back to Life - Ht Bristol',
#  "Ain't Nobody - Skylar Grey",
#  'Man Down (feat. AlunaGeorge) - KREAM Remix - Shakka',
#  'Airplanes, Pt. II (feat. Eminem & Hayley Williams of Paramore) - B.o.B',
#  'Believer - Imagine Dragons',
#  'Love Me More - Trippie Redd',
#  'Graduation (with Juice WRLD) - benny blanco',
#  'Mansion - NF',
#  'Falling - Trevor Daniel',
#  'Dream Boy - Beach Bunny',
#  'Wastelands - Linkin Park',
#  'Guilty All the Same (feat. Rakim) - Linkin Park',
#  'ROADS UNTRAVELED - Linkin Park',
#  'BURN IT DOWN - Linkin Park',
#  'One More Light - Linkin Park',
#  'Heavy (feat. Kiiara) - Linkin Park',
#  'Given Up - Linkin Park',
#  'In the End - Linkin Park',
#  'Purple Lamborghini (with Rick Ross) - Skrillex',
#  'Holding Out for a Hero - From "Footloose" Soundtrack - Bonnie Tyler',
#  "Say You Won't Let Go - James Arthur",
#  'Add It Up - Violent Femmes',
#  'Smack That - Akon',
#  'Ante Up (feat. Busta Rhymes, Teflon & Remi Martin) - Remix - M.O.P.',
#  'No Lie - Sean Paul',
#  'My Love (feat. Major Lazer, WizKid, Dua Lipa) - Major Lazer VIP Remix - Wale',
#  'Ultimate - Denzel Curry',
#  'Light It Up - Ritviz Diwali Edition - Major Lazer',
#  "Don't Start Now - Dua Lipa",
#  'VOICES (feat. XXXTENTACION) - Skye',
#  'Disco Pogo - Die Atzen',
#  'Glad You Came - The Wanted',
#  'Payphone - Maroon 5',
#  'Homecoming - (Explicit) - Kanye West',
#  'Know Me - Marshmello',
#  'Never Gonna Give You Up - Rick Astley',
#  'She Will Be Loved - Maroon 5',
#  'Let Me Love You - DJ Snake',
#  'Just Dance - Lady Gaga',
#  'Hymn for the Weekend - Seeb Remix - Coldplay',
#  'Mrs. Robinson - The Lemonheads',
#  'romance361 - iann dior',
#  'Sleepwalking - The Chain Gang Of 1974',
#  'Stfu - Pink Guy',
#  'Nuketown (feat. Juice WRLD) - Ski Mask The Slump God',
#  'Closed On Sunday - Kanye West',
#  'Follow God - Kanye West',
#  'Use This Gospel - Kanye West',
#  'HEARTEATER - XXXTENTACION',
#  'Young Grizzley World (feat. A Boogie Wit Da Hoodie & YNW Melly) - Tee Grizzley',
#  'Let Me Down Slowly - Alec Benjamin',
#  'gone girl - iann dior',
#  'chateau - blackbear',
#  'I Got Love - MiyaGi & Endspiel',
#  'На дне - Mot',
#  'Love Me - Lil Tecca',
#  'One Minute (feat. Kanye West & Travis Barker) - XXXTENTACION',
#  'Baila Conmigo - Jennifer Lopez',
#  'Torn - Ava Max',
#  'Hurts 2B Human (feat. Khalid) - Frank Pole Remix - P!nk',
#  'Barking - Ramz',
#  'Magic (feat. Rivers Cuomo) - B.o.B',
#  "That's Not Me - Skepta",
#  'Numb / Encore - JAY-Z',
#  '3500 (feat. Future & 2 Chainz) - Travis Scott',
#  'Barking - Ramz',
#  'hot girl bummer - blackbear',
#  'Last Resort - Papa Roach',
#  'Run Boy Run - Woodkid',
#  'Iron - Woodkid',
#  'The Setup - GTA V Finale Version - Favored Nations',
#  'Back from the Edge - James Arthur',
#  'I Love - Joyner Lucas',
#  'Ransom (with Juice WRLD) - Remix - Lil Tecca',
#  'Attention - Charlie Puth',
#  'What Is Love - Haddaway',
#  'Panini - Lil Nas X',
#  'Malibu - Tiësto Remix - Miley Cyrus',
#  'Happy Mama Day - Pitbull',
#  'You (feat. Travis Barker) - James Arthur',
#  'Walking (feat. Swae Lee & Major Lazer) - 88rising',
#  'Somebody - Internet Money',
#  'Pretty Fly (For A White Guy) - The Offspring',
#  "The Kids Aren't Alright - The Offspring",
#  'Waiting For Love - Avicii',
#  'A Little More - Machine Gun Kelly',
#  'Soy Peor - Mambo Remix - Omega',
#  "She's Out Of Her Mind - blink-182",
#  'Bored To Death - blink-182',
#  'Tokyo Drift (Fast & Furious) - From "The Fast And The Furious: Tokyo Drift" Soundtrack - Teriyaki Boyz',
#  'Smells Like Teen Spirit - Nirvana',
#  'Bonfire - Childish Gambino',
#  'All My Friends - Dermot Kennedy',
#  'I Don’t Wanna Live Forever (Fifty Shades Darker) - ZAYN',
#  "There's Nothing Holdin' Me Back - Shawn Mendes",
#  'Party (feat. A Boogie Wit da Hoodie) - Paulo Londra',
#  'Beat Of My Heart - Lost Frequencies',
#  'Bandit (with YoungBoy Never Broke Again) - Juice WRLD',
#  'Everything I Need - Skylar Grey',
#  'what is real - iann dior',
#  '18 - iann dior',
#  'Hate Myself - NF',
#  'How Could You Leave Us - NF',
#  'My Stress - NF',
#  'I Took A Pill In Ibiza - Mike Posner',
#  "Please Don't Go - Mike Posner",
#  'Wasted - Tiësto',
#  "She's On My Mind - JP Cooper",
#  'Best Day Of My Life - American Authors',
#  'Best Day Ever - Mac Miller',
#  'Feeling - Juice WRLD',
#  '1400 / 999 Freestyle - Trippie Redd',
#  'Demons and Angels (feat. Juice WRLD) - A Boogie Wit da Hoodie',
#  'Run with Wrld - Lil Revenge',
#  "Where'd You Go (feat. Holly Brook & Jonah Matranga) - Fort Minor",
#  'I Gotta Feeling - Black Eyed Peas',
#  'Starboy - The Weeknd',
#  'South of the Border (feat. Camila Cabello & Cardi B) - Cheat Codes Remix - Ed Sheeran',
#  'Writing on the Wall (feat. Post Malone & Cardi B) - French Montana',
#  'Angel with Tattoos - Skylar Grey',
#  'Watch Me (Whip / Nae Nae) - Silentó',
#  'I Miss You - blink-182',
#  'I Hate Everything About You - Three Days Grace',
#  '...To Be Loved - Papa Roach',
#  'Pompeii - Bastille',
#  'See You Again (feat. Charlie Puth) - Wiz Khalifa',
#  'We Own It (Fast & Furious) - 2 Chainz',
#  'DONTTRUSTME - 3OH!3',
#  'Candy Paint - Post Malone',
#  'Welcome to the Party (with French Montana & Lil Pump, feat. Zhavia Ward) - from Deadpool 2 - Diplo',
#  'Famous Last Words - My Chemical Romance',
#  'Lions - Skip Marley',
#  'Fake Love - Drake',
#  'Takeaway (feat. Lennon Stella) - The Chainsmokers',
#  'Start Again (feat. Logic) - OneRepublic',
#  'September - Earth, Wind & Fire',
#  "I'm Not Alright - Loud Luxury",
#  "I'm Not Alright - EDX's Dubai Skyline Remix - Loud Luxury",
#  'Behind Barz - Bonus - Drake',
#  'Suit Suit - Guru Randhawa',
#  'Milo Na Tum - Lata Mangeshkar',
#  'Torn - Hook N Sling Remix - Ava Max',
#  'Thing For You (Don Diablo Remix) - Extended - David Guetta',
#  'The Power - Jesse Perez Remix - Duke Dumont',
#  'Slow It Down - Mike Posner',
#  'Stuck In A Dream (feat. Gunna) - Lil Mosey',
#  'The Last Time - The Script',
#  'Welcome to St. Tropez - DJ Antoine vs Mad Mark Radio Edit - DJ Antoine',
#  'Warriors - Imagine Dragons',
#  'Tiptoe - Imagine Dragons',
#  'Take What You Want (feat. Ozzy Osbourne & Travis Scott) - Post Malone',
#  'emotions - iann dior',
#  'Bring Me To Life - Evanescence',
#  'Shotgun - George Ezra',
#  'Dear Future Self (Hands Up) [feat. Wyclef Jean] - Fall Out Boy',
#  'Graveyard - Halsey',
#  'Breathe - 88rising',
#  'Stay With Me - Sam Smith',
#  'Take What You Want (feat. Ozzy Osbourne & Travis Scott) - Post Malone',
#  'Truth Hurts - Lizzo',
#  'Alone - Halsey',
#  'Yeah! (feat. Lil Jon & Ludacris) - Usher',
#  'Crazy In Love (feat. Jay-Z) - Beyoncé',
#  'Ransom (with Juice WRLD) - Remix - Lil Tecca',
#  'Make It Hot - Dee Mad & Sky Remix - Major Lazer',
#  'Nails, Hair, Hips, Heels - Remix - Todrick Hall',
#  'OPTIMISTIC - X Ambassadors',
#  'Pose (feat. Lil Uzi Vert) - Yo Gotti',
#  '#PROUDCATOWNERREMIX - XXXTENTACION',
#  'Boy Back (feat. NAV) - Young Thug',
#  'Lil Baby - Young Thug',
#  'Bad Bad Bad (feat. Lil Baby) - Young Thug',
#  'Time - NF',
#  'Like the Way I Do - Cascada',
#  'Lordly (feat. Alex Aiono) - Feder',
#  'Alive - Pegboard Nerds Remix - Krewella',
#  'Rich Love (with Seeb) - OneRepublic',
#  "If I Can't Have You - Shawn Mendes",
#  'Starboy - The Weeknd',
#  'Replay - Iyaz',
#  'Kiss Me Thru The Phone - Soulja Boy',
#  'Needed Me - Rihanna',
#  'Call on Me - Ryan Riback Remix - Starley',
#  'HEY CHILD - X Ambassadors',
#  'Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha) - Machine Gun Kelly',
#  'Mirrors - Justin Timberlake',
#  'CAN\'T STOP THE FEELING! (Original Song from DreamWorks Animation\'s "TROLLS") - Justin Timberlake',
#  'Locked Away (feat. Adam Levine) - R. City',
#  'Thinking out Loud - Ed Sheeran',
#  'Take Care - Drake',
#  'Tonight Tonight - Hot Chelle Rae',
#  'Under Control (feat. Hurts) - Calvin Harris',
#  'Kissing Strangers - DNCE',
#  'Heart Attack - Demi Lovato',
#  'Cooler Than Me - Single Mix - Mike Posner',
#  'No Money - Galantis',
#  'Hey, Soul Sister - Train',
#  'How Deep Is Your Love - Calvin Harris',
#  "DJ Got Us Fallin' In Love (feat. Pitbull) - Usher",
#  'Unsteady - X Ambassadors',
#  "Say You Won't Let Go - James Arthur",
#  'Work from Home (feat. Ty Dolla $ign) - Fifth Harmony',
#  'Ocean Drive - Duke Dumont',
#  'IF YOU PRAY RIGHT - BROCKHAMPTON',
#  'Sun Is Shining - Lost Frequencies',
#  'Mama - Acoustic - John Newman',
#  'Malt Liquor - Lewis Del Mar',
#  'Cake By The Ocean - DNCE',
#  'Liquor Locker - Vic Mensa',
#  'Blame VS Love Me Again - Acoustic Mashup - Matt Johnson',
#  'Break Your Heart - Taio Cruz',
#  "i hate u, i love u (feat. olivia o'brien) - gnash",
#  'Airplanes (feat. Hayley Williams) - B.o.B',
#  'Time Of Our Lives - Ne-Yo & Pitbull',
#  'Paris - The Chainsmokers',
#  'Where Are Ü Now (with Justin Bieber) - Skrillex',
#  'Summer - Calvin Harris',
#  'Centuries - Fall Out Boy',
#  'Light It Up (feat. Nyla & Fuse ODG) - Remix - Major Lazer',
#  'Ay Ay Ay (feat. Pitbull) - Kim Viera',
#  'Cocoa Butter Kisses - Chance the Rapper',
#  'U Mad - Vic Mensa',
#  'Les Champs-Elysées - Joe Dassin',
#  'The Road - Flying Decibels',
#  'The Hardest Word Is Goodbye - Acoustic - John Newman',
#  'Scrawny - Wallows',
#  'Ritual - Acoustic - Tiësto',
#  'Fuego (with Sean Paul & Anitta, feat. Tainy) - DJ Snake',
#  'Leave Me Alone - NF',
#  'Slayerr - Tm88',
#  'BAD! - XXXTENTACION',
#  'Stay A While - Dimitri Vegas & Like Mike',
#  'TiK ToK - Kesha',
#  '4 Chords - The Axis of Awesome',
#  'The Scientist - Coldplay',
#  'Like a Rodeo - Kane Brown',
#  'bad guy (with Justin Bieber) - Billie Eilish',
#  "Lips Don't Lie (feat. A Boogie Wit da Hoodie) - R3HAB Remix - Ally Brooke",
#  'Pegasus Seiya - The Struts',
#  'Royalty (feat. Ky-Mani Marley, Stefflon Don & Vybz Kartel) - XXXTENTACION',
#  'Stay Frosty Royal Milk Tea - Fall Out Boy',
#  'I Got You - Bebe Rexha',
#  'Issues - Julia Michaels',
#  'Power Over Me - Dermot Kennedy',
#  'Wild Ones (feat. Sia) - Flo Rida',
#  'Too Good At Goodbyes - Edit - Sam Smith',
#  'Drag Me Down - One Direction',
#  'Party Monster - The Weeknd',
#  'Shape Of My Heart - Sting',
#  'Way To Break My Heart (feat. Skrillex) - Ed Sheeran',
#  '1000 Nights (feat. Meek Mill & A Boogie Wit da Hoodie) - Ed Sheeran',
#  "I Don't Want Your Money (feat. H.E.R.) - Ed Sheeran",
#  'Put It All on Me (feat. Ella Mai) - Ed Sheeran',
#  'Best Part of Me (feat. YEBBA) - Ed Sheeran',
#  'Take Me Back to London (feat. Stormzy) - Ed Sheeran',
#  'South of the Border (feat. Camila Cabello & Cardi B) - Ed Sheeran',
#  'Remember The Name (feat. Eminem & 50 Cent) - Ed Sheeran',
#  'Antisocial (with Travis Scott) - Ed Sheeran',
#  'Oh Mama - Naïka',
#  'Тает лёд - Грибы',
#  'Whenever, Wherever - Shakira',
#  'Work Hard, Play Hard - Wiz Khalifa',
#  'Ni**as In Paris - JAY-Z',
#  'Aries (YuGo) Part 2 (with Rae Sremmurd & Big Sean feat. Quavo & Pharrell) - Mike WiLL Made-It',
#  'Party (feat. Usher & Gucci Mane) - Chris Brown',
#  'BOOM - Tiësto',
#  '100 - French Montana',
#  'Body On My - Loud Luxury',
#  'Feel This Moment (feat. Christina Aguilera) - Pitbull',
#  'American Boy - Estelle',
#  'Jeffery (Freestyle) - Fox Paradox',
#  'G Walk (with Chris Brown) - Lil Mosey',
#  '100 Bands (feat. Quavo, YG & Meek Mill) - Mustard',
#  'F9mily (You & Me) - Lil Nas X',
#  'Sayonara детка - Eldzhey',
#  'Proud - Marshmello',
#  'Instagram - Dimitri Vegas & Like Mike',
#  'The Boys Are Back In Town - Thin Lizzy',
#  'Sad (Freestyle) - Fox Paradox',
#  'Savage - Doscompac',
#  'Starstruck (Freestyle) - Fox Paradox',
#  "'Till I Collapse - Eminem",
#  "X Gon' Give It To Ya - DMX",
#  'First Off (feat. Travis Scott) - Future',
#  "Bossin' Up (feat. A$AP Ferg & French Montana) - Kid Ink",
#  'Southside - Lil Baby',
#  'Energy - Drake',
#  'Nascar - Roddy Ricch',
#  'Never Recover (Lil Baby & Gunna, Drake) - Lil Baby',
#  'Sanguine Paradise - Lil Uzi Vert',
#  'Adventure of a Lifetime - Live from Spotify London - Coldplay',
#  'Viva La Vida - Live from Spotify London - Coldplay',
#  'Birds - Coldplay',
#  'Violet Hill - Coldplay',
#  'Hypnotised - EP Mix - Coldplay',
#  'Old English - Young Thug',
#  'Let It Bang (feat. ScHoolboy Q) - A$AP Ferg',
#  'This Is Not A Game - The Chemical Brothers',
#  "Runnin' - David Dallas",
#  'Señorita - Vince Staples',
#  'I Knew You Were Trouble. - Taylor Swift',
#  'Clocks - Coldplay',
#  'On GOD (with YG & Tyga feat. A$AP Ferg & A$AP Rocky) - Mustard',
#  'Body Talks (feat. Kesha) - The Struts',
#  'Hate Me (with Juice WRLD) - Ellie Goulding',
#  'fast (Remix) [feat. Offset & A Boogie Wit da Hoodie] - Sueco the Child',
#  'One Of Us - Joan Osborne',
#  'Waves - Dean Lewis',
#  'Broken - Seether',
#  'No Favors - Big Sean',
#  'Bounce Back - Big Sean',
#  'Tunnel Vision - Kodak Black',
#  'West Coast - G-Eazy',
#  'Falling Like The Stars - Madism Remix - James Arthur',
#  'Sixteen - Acoustic - Ellie Goulding',
#  "Pa' Lante - Alex Sensation",
#  'Make It Hot - Major Lazer',
#  'One Thing Right - Marshmello',
#  'Panini - Lil Nas X',
#  "Saved - Joseph O'brien",
#  'Señorita - Shawn Mendes',
#  'How Can I Forget - MKTO',
#  'Classic - MKTO',
#  "Say It Ain't So - Weezer",
#  'Done with Love (feat. Herizen) - Absofacto',
#  'Tap (feat. Meek Mill) - NAV',
#  'Starstruck - Axtrecius',
#  'One Hundred - NF',
#  'Bad Blood - Bastille',
#  'Loco Contigo (with J. Balvin & Tyga) - DJ Snake',
#  'Wildside - Justice Skolnik',
#  'Shoulda Known Better - MKTO',
#  'HOLD YOU DOWN - X Ambassadors',
#  'Never Go Back - Robin Schulz Remix - Dennis Lloyd',
#  'Prayer in C - Robin Schulz Radio Edit - Lilly Wood and The Prick',
#  'Prayer in C - 5th Anniversary Remix - Lilly Wood and The Prick',
#  'If You Want Love - NF',
#  'Remember This - NF',
#  'Remember the Name (feat. Styles of Beyond) - Fort Minor',
#  'I don’t even speak spanish lol - feat. Rio Santana, Judah, Andrez Babii - XXXTENTACION',
#  'ONCE UPON A TIME (FREESTYLE) - IDK',
#  'La La Land (feat. YG) - Bryce Vine',
#  'Disrespectin - 88rising',
#  "L'amour Toujours (Small Mix) - Gigi D'Agostino",
#  'Skinny Love - Bon Iver',
#  'Unconsolable - X Ambassadors',
#  'Without Me (with Juice WRLD) - Halsey',
#  'Eastside (with Halsey & Khalid) - benny blanco',
#  'Purple Yellow Red and Blue - Portugal. The Man',
#  'Hey Ya! - OutKast',
#  "That's My N**** (with Meek Mill, YG & Snoop Dogg) - Meek Mill",
#  'Out Of Sight - Logic',
#  'Vai Amor - Gilli',
#  'Spicy (with Diplo & Charli XCX) - Herve Pagez',
#  'crash my whip - iann dior',
#  'No Effect - Hooligan Hefs',
#  'The London (feat. J. Cole & Travis Scott) - Young Thug',
#  'HOLD YOU DOWN - X Ambassadors',
#  'The Search - NF',
#  'Ho Hey - The Lumineers',
#  'I THINK - Tyler, The Creator',
#  'Long Time - Intro - Playboi Carti',
#  'Shutdown - Skepta',
#  'Live Sheck Wes - Sheck Wes',
#  'NEW MAGIC WAND - Tyler, The Creator',
#  'Just Like Me (feat. Young Thug) - A Boogie Wit da Hoodie',
#  'Put You On (feat. A Boogie Wit da Hoodie) - PnB Rock',
#  'Nonchalant (feat. Alkaline) - A Boogie Wit da Hoodie',
#  '(I Just) Died In Your Arms - Cutting Crew',
#  'No Promises - A Boogie Wit da Hoodie',
#  'Timeless (feat. DJ SPINKING) - A Boogie Wit da Hoodie',
#  'Fall in Love - A Boogie Wit da Hoodie',
#  'Undefeated (feat. 21 Savage) - A Boogie Wit da Hoodie',
#  'Love Drugs and Sex - A Boogie Wit da Hoodie',
#  'Come Closer (feat. Queen Naija) - A Boogie Wit da Hoodie',
#  'Still Think About You - A Boogie Wit da Hoodie',
#  'Déjà Vu (feat. J Alvarez) - A Boogie Wit da Hoodie',
#  'Blessed (with Tyga) - Shenseea',
#  'Hey Julie! (feat. Lil Yachty) - Absofacto Remix - KYLE',
#  'Love Hurts (feat. Travis Scott) - Playboi Carti',
#  'Portland - Drake',
#  'Hymn for the Weekend - Coldplay',
#  'In the Jungle - Rilès',
#  'Pesetas - Rilès',
#  'Lost In The Echo - Guitar Tribute Players',
#  'LOST IN THE ECHO - Linkin Park',
#  'Escape (The Pina Colada Song) - Rupert Holmes',
#  'Holiday - DJ Antoine Vs Mad Mark 2K15 Radio Edit - DJ Antoine',
#  'Ole Ole - DJ Antoine & Mad Mark 2k18 Mix - DJ Antoine',
#  'Sexy Bitch (feat. Akon) - David Guetta',
#  'Trap Queen - Fetty Wap',
#  'Lean Wit Me - Juice WRLD',
#  'Dirty Dancer - Enrique Iglesias',
#  'Undo (with Calum Scott & Shenseea) - Shaan Remix - Naughty Boy',
#  'Pups (feat. A$AP Rocky) - A$AP Ferg',
#  'Na Na - Ciara',
#  ...]

# %% [markdown]
# The following cells are for data cleaning and data collecting so that it is easier to put into MongoDB

# %%
#takes in track and artist from my_library to put it in search method
def make_query(s):
    delimeter = ' - '
    delimeter_index = s.find(delimeter)
    track = s[0 : delimeter_index]
    artist = s[delimeter_index :]
    query_dict = {"track" : track, "artist" : artist}
    return query_dict

# %%
#function to take in query result and cleanly obtain basic ids and names
def basic_song_data(query):
    try:
        artist_ids.append(query['tracks']['items'][0]['artists'][0]['id'])
        artist_names.append(query['tracks']['items'][0]['artists'][0]['name'])
        song_ids.append(query['tracks']['items'][0]['id'])
        song_names.append(query['tracks']['items'][0]['name'])
        song_popularities.append(query['tracks']['items'][0]['popularity'])
        album_ids.append(query['tracks']['items'][0]['album']['id'])
        album_names.append(query['tracks']['items'][0]['album']['name'])
    except IndexError:
        artist_ids.append(None)
        artist_names.append(None)
        song_ids.append(None)
        song_names.append(None)
        song_popularities.append(None)
        album_ids.append(None)
        album_names.append(None)

# %%
#loops through my entire library, retrieves names and ids
artist_ids = []
artist_names = []
song_ids = []
song_names = []
song_popularities = []
album_ids = []
album_names = []

def clean_library():
    for song in my_library:
        search_query = make_query(song)
        resultset = spotify.search(search_query, search_type = "track")
        basic_song_data(resultset)
            
clean_library()

# %%
#gets rid of None values
while artist_ids.count(None) > 0:
    artist_ids.remove(None)
    artist_names.remove(None)
    song_ids.remove(None)
    song_names.remove(None)
    song_popularities.remove(None)
    album_ids.remove(None)
    album_names.remove(None)

# %%
#new library without queries that were faulting
new_library = []
for i in range (0, len(artist_names)):
    new_track = song_names[i] + ' - ' + artist_names[i]
    new_library.append(new_track)

# %%
#songs and artists
song_artist_album = {}
#maps track name and artist to all the things retrived above fro easy entry to document store
for i in range(0, len(song_ids)):
    lil_dicty = {}
    lil_dicty['artist_id'] = artist_ids[i]
    lil_dicty['artist_name'] = artist_names[i]
    lil_dicty['song_id'] = song_ids[i]
    lil_dicty['song_name'] = song_names[i]
    lil_dicty['song_popularity'] = song_popularities[i]
    lil_dicty['album_id'] = album_ids[i]
    lil_dicty['album_name'] = album_names[i]
    song_artist_album[new_library[i]] = lil_dicty

# %%
#get audio features
songdata_dict = {}

for i in range(0, len(song_ids)):
    songdata_dict[new_library[i]] = spotify.get_audio_data(song_ids[i])

# %%
songdata_dict
# Out:
# {'Shameless - iann dior': {'acousticness': 0.186,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VZFXDtx8NnXWeJHOMzEan',
#   'danceability': 0.709,
#   'duration_ms': 106012,
#   'energy': 0.76,
#   'id': '4VZFXDtx8NnXWeJHOMzEan',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.164,
#   'loudness': -7.583,
#   'mode': 1,
#   'speechiness': 0.148,
#   'tempo': 81.495,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4VZFXDtx8NnXWeJHOMzEan',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4VZFXDtx8NnXWeJHOMzEan',
#   'valence': 0.709},
#  'Cinderella Story - A Boogie Wit da Hoodie': {'acousticness': 0.272,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18AIesWCXvIbXu8RqQw1E1',
#   'danceability': 0.639,
#   'duration_ms': 185455,
#   'energy': 0.571,
#   'id': '18AIesWCXvIbXu8RqQw1E1',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.144,
#   'loudness': -7.332,
#   'mode': 1,
#   'speechiness': 0.511,
#   'tempo': 88.047,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/18AIesWCXvIbXu8RqQw1E1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:18AIesWCXvIbXu8RqQw1E1',
#   'valence': 0.569},
#  'Gummy - Loud Luxury': {'acousticness': 0.0159,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7rWUy2a3j1QmvkcQfI3tPY',
#   'danceability': 0.803,
#   'duration_ms': 179688,
#   'energy': 0.785,
#   'id': '7rWUy2a3j1QmvkcQfI3tPY',
#   'instrumentalness': 2.82e-05,
#   'key': 0,
#   'liveness': 0.112,
#   'loudness': -5.481,
#   'mode': 0,
#   'speechiness': 0.0397,
#   'tempo': 118.985,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7rWUy2a3j1QmvkcQfI3tPY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7rWUy2a3j1QmvkcQfI3tPY',
#   'valence': 0.567},
#  'Relationship (feat. Future) - Young Thug': {'acousticness': 0.00252,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25oOaleife6E2MIKmFkPvg',
#   'danceability': 0.842,
#   'duration_ms': 215307,
#   'energy': 0.597,
#   'id': '25oOaleife6E2MIKmFkPvg',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.124,
#   'loudness': -6.336,
#   'mode': 1,
#   'speechiness': 0.0627,
#   'tempo': 145.992,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/25oOaleife6E2MIKmFkPvg',
#   'type': 'audio_features',
#   'uri': 'spotify:track:25oOaleife6E2MIKmFkPvg',
#   'valence': 0.298},
#  'Close Friends (Lil Baby & Gunna) - Lil Baby': {'acousticness': 0.0509,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nzhL67GpF9szXWg5y509A',
#   'danceability': 0.676,
#   'duration_ms': 203881,
#   'energy': 0.578,
#   'id': '5nzhL67GpF9szXWg5y509A',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.0796,
#   'loudness': -4.669,
#   'mode': 0,
#   'speechiness': 0.375,
#   'tempo': 158.896,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5nzhL67GpF9szXWg5y509A',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5nzhL67GpF9szXWg5y509A',
#   'valence': 0.698},
#  'GO (feat. Juice WRLD) - The Kid LAROI': {'acousticness': 0.185,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2t7D3y0jvYjR8IP9Bosyew',
#   'danceability': 0.544,
#   'duration_ms': 183947,
#   'energy': 0.744,
#   'id': '2t7D3y0jvYjR8IP9Bosyew',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.336,
#   'loudness': -5.007,
#   'mode': 1,
#   'speechiness': 0.0889,
#   'tempo': 73.699,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2t7D3y0jvYjR8IP9Bosyew',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2t7D3y0jvYjR8IP9Bosyew',
#   'valence': 0.572},
#  'Addison Rae - The Kid LAROI': {'acousticness': 0.0155,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ImaJZH7XqxrzbQZpYDmol',
#   'danceability': 0.901,
#   'duration_ms': 163574,
#   'energy': 0.49,
#   'id': '2ImaJZH7XqxrzbQZpYDmol',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.109,
#   'loudness': -9.099,
#   'mode': 0,
#   'speechiness': 0.129,
#   'tempo': 135.015,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ImaJZH7XqxrzbQZpYDmol',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ImaJZH7XqxrzbQZpYDmol',
#   'valence': 0.397},
#  'Trap - Rompasso Remix - SAINt JHN': {'acousticness': 0.0225,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GfdYJsR3ZZuNBVH9l2nHj',
#   'danceability': 0.694,
#   'duration_ms': 168750,
#   'energy': 0.739,
#   'id': '5GfdYJsR3ZZuNBVH9l2nHj',
#   'instrumentalness': 9.11e-06,
#   'key': 5,
#   'liveness': 0.507,
#   'loudness': -5.457,
#   'mode': 1,
#   'speechiness': 0.185,
#   'tempo': 128.049,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5GfdYJsR3ZZuNBVH9l2nHj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5GfdYJsR3ZZuNBVH9l2nHj',
#   'valence': 0.222},
#  'VALENTINO - Imanbek Remix - 24kGoldn': {'acousticness': 0.0161,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/660BgHpKo1jhR9MMSFn7CF',
#   'danceability': 0.791,
#   'duration_ms': 177975,
#   'energy': 0.795,
#   'id': '660BgHpKo1jhR9MMSFn7CF',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.362,
#   'loudness': -4.854,
#   'mode': 1,
#   'speechiness': 0.0415,
#   'tempo': 124.007,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/660BgHpKo1jhR9MMSFn7CF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:660BgHpKo1jhR9MMSFn7CF',
#   'valence': 0.963},
#  'The Bigger Picture - Lil Baby': {'acousticness': 0.0127,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44gRhRi2OhEf7moAUj6MD1',
#   'danceability': 0.59,
#   'duration_ms': 252729,
#   'energy': 0.618,
#   'id': '44gRhRi2OhEf7moAUj6MD1',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.244,
#   'loudness': -5.756,
#   'mode': 1,
#   'speechiness': 0.334,
#   'tempo': 96.459,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/44gRhRi2OhEf7moAUj6MD1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:44gRhRi2OhEf7moAUj6MD1',
#   'valence': 0.153},
#  'Lalala - Ilkan Gunuc Remix - Y2K': {'acousticness': 0.0701,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1D9kLvE4SBX6EOG8uJa7Vy',
#   'danceability': 0.774,
#   'duration_ms': 178408,
#   'energy': 0.831,
#   'id': '1D9kLvE4SBX6EOG8uJa7Vy',
#   'instrumentalness': 2.21e-06,
#   'key': 8,
#   'liveness': 0.0825,
#   'loudness': -4.672,
#   'mode': 1,
#   'speechiness': 0.0514,
#   'tempo': 124.035,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1D9kLvE4SBX6EOG8uJa7Vy',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1D9kLvE4SBX6EOG8uJa7Vy',
#   'valence': 0.333},
#  'Otherside Of America - Meek Mill': {'acousticness': 0.0878,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JBvJ9PwrYA1oeUzI3FMRI',
#   'danceability': 0.73,
#   'duration_ms': 218103,
#   'energy': 0.772,
#   'id': '3JBvJ9PwrYA1oeUzI3FMRI',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.401,
#   'loudness': -3.883,
#   'mode': 0,
#   'speechiness': 0.316,
#   'tempo': 147.053,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3JBvJ9PwrYA1oeUzI3FMRI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3JBvJ9PwrYA1oeUzI3FMRI',
#   'valence': 0.403},
#  'Alien - Dennis Lloyd': {'acousticness': 0.00813,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Tqshmc0rnQPaIGJfRp2Da',
#   'danceability': 0.71,
#   'duration_ms': 138639,
#   'energy': 0.768,
#   'id': '1Tqshmc0rnQPaIGJfRp2Da',
#   'instrumentalness': 3.66e-05,
#   'key': 0,
#   'liveness': 0.0791,
#   'loudness': -4.772,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'tempo': 118.085,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1Tqshmc0rnQPaIGJfRp2Da',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1Tqshmc0rnQPaIGJfRp2Da',
#   'valence': 0.419},
#  'Tomorrow (feat. 433) - Tiësto': {'acousticness': 0.00607,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0uH5ORp6Ai5PP0SUofxoc7',
#   'danceability': 0.661,
#   'duration_ms': 165000,
#   'energy': 0.942,
#   'id': '0uH5ORp6Ai5PP0SUofxoc7',
#   'instrumentalness': 0.44,
#   'key': 10,
#   'liveness': 0.0778,
#   'loudness': -3.75,
#   'mode': 0,
#   'speechiness': 0.282,
#   'tempo': 127.947,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0uH5ORp6Ai5PP0SUofxoc7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0uH5ORp6Ai5PP0SUofxoc7',
#   'valence': 0.203},
#  'You & I (feat. Tyler Sjöström & Bertrand Lacoste) - VINIL Remix - Sterkøl': {'acousticness': 0.156,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Xd66AmcJ4bjRJYOAAliMS',
#   'danceability': 0.578,
#   'duration_ms': 219193,
#   'energy': 0.801,
#   'id': '1Xd66AmcJ4bjRJYOAAliMS',
#   'instrumentalness': 0.0013,
#   'key': 5,
#   'liveness': 0.146,
#   'loudness': -4.412,
#   'mode': 1,
#   'speechiness': 0.099,
#   'tempo': 115.055,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1Xd66AmcJ4bjRJYOAAliMS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1Xd66AmcJ4bjRJYOAAliMS',
#   'valence': 0.373},
#  'Paris - Cevith': {'acousticness': 0.00643,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sevsHttEKM5eQdpibYbUA',
#   'danceability': 0.692,
#   'duration_ms': 179032,
#   'energy': 0.788,
#   'id': '1sevsHttEKM5eQdpibYbUA',
#   'instrumentalness': 0.00293,
#   'key': 9,
#   'liveness': 0.227,
#   'loudness': -7.077,
#   'mode': 0,
#   'speechiness': 0.0477,
#   'tempo': 124.04,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1sevsHttEKM5eQdpibYbUA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1sevsHttEKM5eQdpibYbUA',
#   'valence': 0.637},
#  'Godzilla - Aftermath': {'acousticness': 0.0714,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eyyjiGgRWpDJqq3HCuexl',
#   'danceability': 0.705,
#   'duration_ms': 194199,
#   'energy': 0.862,
#   'id': '0eyyjiGgRWpDJqq3HCuexl',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.875,
#   'loudness': -5.671,
#   'mode': 0,
#   'speechiness': 0.385,
#   'tempo': 124.043,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0eyyjiGgRWpDJqq3HCuexl',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0eyyjiGgRWpDJqq3HCuexl',
#   'valence': 0.579},
#  'Keeps Me High (WHOCARES Remix) - HADES': {'acousticness': 0.0279,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18ktwdSdzDaW7gt6KPgrwW',
#   'danceability': 0.715,
#   'duration_ms': 158095,
#   'energy': 0.951,
#   'id': '18ktwdSdzDaW7gt6KPgrwW',
#   'instrumentalness': 0.0107,
#   'key': 8,
#   'liveness': 0.071,
#   'loudness': -3.337,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'tempo': 126.012,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/18ktwdSdzDaW7gt6KPgrwW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:18ktwdSdzDaW7gt6KPgrwW',
#   'valence': 0.525},
#  'I Love My Friends (And My Friends Love Me) - Steve Aoki': {'acousticness': 0.112,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GiQyNKidWwzHkgDs03dwN',
#   'danceability': 0.757,
#   'duration_ms': 181428,
#   'energy': 0.927,
#   'id': '2GiQyNKidWwzHkgDs03dwN',
#   'instrumentalness': 1.53e-05,
#   'key': 4,
#   'liveness': 0.507,
#   'loudness': -3.462,
#   'mode': 1,
#   'speechiness': 0.088,
#   'tempo': 124.056,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2GiQyNKidWwzHkgDs03dwN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2GiQyNKidWwzHkgDs03dwN',
#   'valence': 0.758},
#  'Tinted Eyes (feat. blackbear & 24kGoldn) - DVBBS': {'acousticness': 0.00598,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/68UW3plyDDNg1dkNIZRezJ',
#   'danceability': 0.743,
#   'duration_ms': 175082,
#   'energy': 0.801,
#   'id': '68UW3plyDDNg1dkNIZRezJ',
#   'instrumentalness': 2.46e-05,
#   'key': 5,
#   'liveness': 0.178,
#   'loudness': -4.097,
#   'mode': 0,
#   'speechiness': 0.0343,
#   'tempo': 121.965,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/68UW3plyDDNg1dkNIZRezJ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:68UW3plyDDNg1dkNIZRezJ',
#   'valence': 0.381},
#  'Kiss Me Hard - DJ Antoine vs Mad Mark 2k20 Mix - DJ Antoine': {'acousticness': 0.0755,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0b59Hg9erJyJeCgX2d8xSt',
#   'danceability': 0.728,
#   'duration_ms': 158247,
#   'energy': 0.827,
#   'id': '0b59Hg9erJyJeCgX2d8xSt',
#   'instrumentalness': 9.87e-05,
#   'key': 0,
#   'liveness': 0.0908,
#   'loudness': -5.526,
#   'mode': 0,
#   'speechiness': 0.0562,
#   'tempo': 124.957,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0b59Hg9erJyJeCgX2d8xSt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0b59Hg9erJyJeCgX2d8xSt',
#   'valence': 0.786},
#  'Best Friend (feat. Tory Lanez) - A Boogie Wit da Hoodie': {'acousticness': 0.211,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GNKDhpJtw7G7nodKz4NOH',
#   'danceability': 0.839,
#   'duration_ms': 260497,
#   'energy': 0.525,
#   'id': '7GNKDhpJtw7G7nodKz4NOH',
#   'instrumentalness': 0.000153,
#   'key': 9,
#   'liveness': 0.0701,
#   'loudness': -7.446,
#   'mode': 0,
#   'speechiness': 0.35,
#   'tempo': 149.863,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7GNKDhpJtw7G7nodKz4NOH',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7GNKDhpJtw7G7nodKz4NOH',
#   'valence': 0.541},
#  "F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar) - A$AP Rocky": {},
#  'Antisocial (with Travis Scott) - Ed Sheeran': {'acousticness': 0.133,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DhRbox3xkceP64k3JeYfW',
#   'danceability': 0.715,
#   'duration_ms': 161747,
#   'energy': 0.823,
#   'id': '1DhRbox3xkceP64k3JeYfW',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.361,
#   'loudness': -5.313,
#   'mode': 0,
#   'speechiness': 0.0495,
#   'tempo': 151.956,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1DhRbox3xkceP64k3JeYfW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1DhRbox3xkceP64k3JeYfW',
#   'valence': 0.91},
#  'Who Needs Love - Trippie Redd': {'acousticness': 0.763,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ktxr00GpTtbMNeBjNeY8D',
#   'danceability': 0.85,
#   'duration_ms': 158532,
#   'energy': 0.516,
#   'id': '2ktxr00GpTtbMNeBjNeY8D',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0896,
#   'loudness': -7.664,
#   'mode': 0,
#   'speechiness': 0.0714,
#   'tempo': 108.963,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ktxr00GpTtbMNeBjNeY8D',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ktxr00GpTtbMNeBjNeY8D',
#   'valence': 0.874},
#  'Weak When Ur Around - blackbear': {'acousticness': 0.678,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UWkbO4emEOu9YUeOGq3vU',
#   'danceability': 0.769,
#   'duration_ms': 169500,
#   'energy': 0.323,
#   'id': '3UWkbO4emEOu9YUeOGq3vU',
#   'instrumentalness': 0,
#   'key': 3,
#   'liveness': 0.116,
#   'loudness': -12.887,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'tempo': 94.977,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3UWkbO4emEOu9YUeOGq3vU',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3UWkbO4emEOu9YUeOGq3vU',
#   'valence': 0.574},
#  'Way Too Fly (feat. DaVido) - A Boogie Wit da Hoodie': {'acousticness': 0.125,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1NAR2XeNMp6SegDBp0NlRy',
#   'danceability': 0.602,
#   'duration_ms': 172708,
#   'energy': 0.771,
#   'id': '1NAR2XeNMp6SegDBp0NlRy',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.254,
#   'loudness': -4.799,
#   'mode': 0,
#   'speechiness': 0.261,
#   'tempo': 216.115,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1NAR2XeNMp6SegDBp0NlRy',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1NAR2XeNMp6SegDBp0NlRy',
#   'valence': 0.864},
#  'Foreigner (feat. A Boogie Wit da Hoodie) - Pop Smoke': {'acousticness': 0.471,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iBKCNKl5UjxfOgyxnQ6q6',
#   'danceability': 0.484,
#   'duration_ms': 161120,
#   'energy': 0.553,
#   'id': '7iBKCNKl5UjxfOgyxnQ6q6',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.276,
#   'loudness': -7.914,
#   'mode': 0,
#   'speechiness': 0.353,
#   'tempo': 103.772,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/7iBKCNKl5UjxfOgyxnQ6q6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7iBKCNKl5UjxfOgyxnQ6q6',
#   'valence': 0.598},
#  'Satisfaction (Isak Original Extended) - Benny Benassi Presents The Biz - Benny Benassi': {'acousticness': 0.163,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1n7omixiROWs5q6xpWiQuL',
#   'danceability': 0.793,
#   'duration_ms': 285571,
#   'energy': 0.698,
#   'id': '1n7omixiROWs5q6xpWiQuL',
#   'instrumentalness': 0.145,
#   'key': 11,
#   'liveness': 0.0745,
#   'loudness': -3.626,
#   'mode': 1,
#   'speechiness': 0.104,
#   'tempo': 130.017,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1n7omixiROWs5q6xpWiQuL',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1n7omixiROWs5q6xpWiQuL',
#   'valence': 0.339},
#  'South of the Border (feat. Camila Cabello & Cardi B) - Ed Sheeran': {'acousticness': 0.148,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vUmTMuQqjdnvlZmAH61Qk',
#   'danceability': 0.857,
#   'duration_ms': 204467,
#   'energy': 0.621,
#   'id': '4vUmTMuQqjdnvlZmAH61Qk',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0865,
#   'loudness': -6.376,
#   'mode': 0,
#   'speechiness': 0.0824,
#   'tempo': 97.986,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4vUmTMuQqjdnvlZmAH61Qk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4vUmTMuQqjdnvlZmAH61Qk',
#   'valence': 0.668},
#  'ily (i love you baby) (feat. Emilee) - Surf Mesa': {'acousticness': 0.0686,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62aP9fBQKYKxi7PDXwcUAS',
#   'danceability': 0.674,
#   'duration_ms': 176547,
#   'energy': 0.774,
#   'id': '62aP9fBQKYKxi7PDXwcUAS',
#   'instrumentalness': 0.00188,
#   'key': 11,
#   'liveness': 0.393,
#   'loudness': -7.567,
#   'mode': 0,
#   'speechiness': 0.0892,
#   'tempo': 112.05,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/62aP9fBQKYKxi7PDXwcUAS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:62aP9fBQKYKxi7PDXwcUAS',
#   'valence': 0.33},
#  'Next Round on Me - twoloud': {'acousticness': 0.000866,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GcrvqKcQ3ew9nQQHcT6tz',
#   'danceability': 0.858,
#   'duration_ms': 157117,
#   'energy': 0.707,
#   'id': '1GcrvqKcQ3ew9nQQHcT6tz',
#   'instrumentalness': 0.00117,
#   'key': 1,
#   'liveness': 0.266,
#   'loudness': -5.518,
#   'mode': 1,
#   'speechiness': 0.0491,
#   'tempo': 123.966,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1GcrvqKcQ3ew9nQQHcT6tz',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1GcrvqKcQ3ew9nQQHcT6tz',
#   'valence': 0.461},
#  'Roses Remix (feat. Future) - SAINt JHN': {'acousticness': 0.0247,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1KyZ4rUiW2lkqGNLQYKpcC',
#   'danceability': 0.941,
#   'duration_ms': 187898,
#   'energy': 0.463,
#   'id': '1KyZ4rUiW2lkqGNLQYKpcC',
#   'instrumentalness': 5.53e-05,
#   'key': 8,
#   'liveness': 0.192,
#   'loudness': -5.993,
#   'mode': 1,
#   'speechiness': 0.113,
#   'tempo': 127.003,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1KyZ4rUiW2lkqGNLQYKpcC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1KyZ4rUiW2lkqGNLQYKpcC',
#   'valence': 0.312},
#  'Both Sides (feat. Lil Baby) - Gucci Mane': {'acousticness': 0.0084,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34xlXbZ4Ws3GGpUKeimDu5',
#   'danceability': 0.844,
#   'duration_ms': 180753,
#   'energy': 0.616,
#   'id': '34xlXbZ4Ws3GGpUKeimDu5',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.121,
#   'loudness': -5.2,
#   'mode': 1,
#   'speechiness': 0.161,
#   'tempo': 160.024,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/34xlXbZ4Ws3GGpUKeimDu5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:34xlXbZ4Ws3GGpUKeimDu5',
#   'valence': 0.188},
#  'Kalinka - Dimitri Vegas & Like Mike Edit - Timmy Trumpet': {'acousticness': 0.0065,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DByxA4MRvkBR8DPEFnrgr',
#   'danceability': 0.514,
#   'duration_ms': 160669,
#   'energy': 0.936,
#   'id': '3DByxA4MRvkBR8DPEFnrgr',
#   'instrumentalness': 0.0297,
#   'key': 1,
#   'liveness': 0.0728,
#   'loudness': -3.517,
#   'mode': 0,
#   'speechiness': 0.23,
#   'tempo': 127.914,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3DByxA4MRvkBR8DPEFnrgr',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3DByxA4MRvkBR8DPEFnrgr',
#   'valence': 0.201},
#  'A-List - Remix - Speedy': {'acousticness': 0.013,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12QEaxiZzdz27r1Xz7dTHV',
#   'danceability': 0.679,
#   'duration_ms': 236000,
#   'energy': 0.72,
#   'id': '12QEaxiZzdz27r1Xz7dTHV',
#   'instrumentalness': 5.12e-06,
#   'key': 5,
#   'liveness': 0.132,
#   'loudness': -6.42,
#   'mode': 1,
#   'speechiness': 0.08,
#   'tempo': 142.067,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/12QEaxiZzdz27r1Xz7dTHV',
#   'type': 'audio_features',
#   'uri': 'spotify:track:12QEaxiZzdz27r1Xz7dTHV',
#   'valence': 0.668},
#  'goosebumps - Skylar Grey': {'acousticness': 0.281,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7alhwlGsBjxMg1tlhfNSi8',
#   'danceability': 0.696,
#   'duration_ms': 266667,
#   'energy': 0.638,
#   'id': '7alhwlGsBjxMg1tlhfNSi8',
#   'instrumentalness': 8.91e-05,
#   'key': 8,
#   'liveness': 0.105,
#   'loudness': -5.211,
#   'mode': 0,
#   'speechiness': 0.119,
#   'tempo': 108.042,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7alhwlGsBjxMg1tlhfNSi8',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7alhwlGsBjxMg1tlhfNSi8',
#   'valence': 0.262},
#  'TKN (feat. Travis Scott) - ROSALÍA': {'acousticness': 0.192,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4w47S36wQGBhGg073q3nt7',
#   'danceability': 0.776,
#   'duration_ms': 129371,
#   'energy': 0.509,
#   'id': '4w47S36wQGBhGg073q3nt7',
#   'instrumentalness': 1.49e-06,
#   'key': 0,
#   'liveness': 0.115,
#   'loudness': -6.266,
#   'mode': 0,
#   'speechiness': 0.467,
#   'tempo': 94.634,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4w47S36wQGBhGg073q3nt7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4w47S36wQGBhGg073q3nt7',
#   'valence': 0.485},
#  'Oxygen - Winona Oak': {'acousticness': 0.162,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64ouROglsBxfd84TpVlPQZ',
#   'danceability': 0.639,
#   'duration_ms': 192080,
#   'energy': 0.601,
#   'id': '64ouROglsBxfd84TpVlPQZ',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.0791,
#   'loudness': -5.839,
#   'mode': 0,
#   'speechiness': 0.0519,
#   'tempo': 116.045,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/64ouROglsBxfd84TpVlPQZ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:64ouROglsBxfd84TpVlPQZ',
#   'valence': 0.292},
#  'Tell Me U Luv Me (with Trippie Redd) - Juice WRLD': {'acousticness': 0.299,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CNcRgjGw1v9VQaTaytdnD',
#   'danceability': 0.609,
#   'duration_ms': 180129,
#   'energy': 0.757,
#   'id': '4CNcRgjGw1v9VQaTaytdnD',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.63,
#   'loudness': -5.605,
#   'mode': 1,
#   'speechiness': 0.119,
#   'tempo': 128.022,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4CNcRgjGw1v9VQaTaytdnD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4CNcRgjGw1v9VQaTaytdnD',
#   'valence': 0.379},
#  'X - Nicky Jam': {'acousticness': 0.0338,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YUyW9opqNsMSEzzecZih1',
#   'danceability': 0.594,
#   'duration_ms': 172854,
#   'energy': 0.749,
#   'id': '5YUyW9opqNsMSEzzecZih1',
#   'instrumentalness': 0.00106,
#   'key': 9,
#   'liveness': 0.3,
#   'loudness': -5.298,
#   'mode': 0,
#   'speechiness': 0.056,
#   'tempo': 179.968,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5YUyW9opqNsMSEzzecZih1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5YUyW9opqNsMSEzzecZih1',
#   'valence': 0.694},
#  'X (feat. Maluma & Ozuna) - Remix - Nicky Jam': {'acousticness': 0.0561,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JjPBQfI2Y8nIjnm65X6Pw',
#   'danceability': 0.663,
#   'duration_ms': 235747,
#   'energy': 0.696,
#   'id': '6JjPBQfI2Y8nIjnm65X6Pw',
#   'instrumentalness': 3.77e-05,
#   'key': 9,
#   'liveness': 0.0778,
#   'loudness': -4.957,
#   'mode': 0,
#   'speechiness': 0.103,
#   'tempo': 180.113,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6JjPBQfI2Y8nIjnm65X6Pw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6JjPBQfI2Y8nIjnm65X6Pw',
#   'valence': 0.738},
#  'Motto (feat. Lil Uzi Vert, G-Eazy & Mally Mall) - David Guetta': {'acousticness': 0.052,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LvXQDy62I5MD6JEBZcDXS',
#   'danceability': 0.742,
#   'duration_ms': 149520,
#   'energy': 0.827,
#   'id': '4LvXQDy62I5MD6JEBZcDXS',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.263,
#   'loudness': -5.067,
#   'mode': 1,
#   'speechiness': 0.0584,
#   'tempo': 85.014,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4LvXQDy62I5MD6JEBZcDXS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4LvXQDy62I5MD6JEBZcDXS',
#   'valence': 0.654},
#  'Sweet & Bitter - Kush Kush': {'acousticness': 0.262,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54IXM88EcHuLHkTlRHamKw',
#   'danceability': 0.776,
#   'duration_ms': 181270,
#   'energy': 0.605,
#   'id': '54IXM88EcHuLHkTlRHamKw',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0642,
#   'loudness': -5.916,
#   'mode': 1,
#   'speechiness': 0.0545,
#   'tempo': 98.966,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/54IXM88EcHuLHkTlRHamKw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:54IXM88EcHuLHkTlRHamKw',
#   'valence': 0.617},
#  'SnD - Jah Khalib': {'acousticness': 0.375,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34ttji2fIHtqipyVsda1E5',
#   'danceability': 0.8,
#   'duration_ms': 250540,
#   'energy': 0.6,
#   'id': '34ttji2fIHtqipyVsda1E5',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.0893,
#   'loudness': -5.953,
#   'mode': 0,
#   'speechiness': 0.0475,
#   'tempo': 139.967,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/34ttji2fIHtqipyVsda1E5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:34ttji2fIHtqipyVsda1E5',
#   'valence': 0.505},
#  'Zombie (Zombic & Felix Schorn Remix) - Besomorph': {'acousticness': 0.0158,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3p07oZZpSNdVtN93M5yIY5',
#   'danceability': 0.608,
#   'duration_ms': 160000,
#   'energy': 0.828,
#   'id': '3p07oZZpSNdVtN93M5yIY5',
#   'instrumentalness': 0.00465,
#   'key': 8,
#   'liveness': 0.247,
#   'loudness': -7.841,
#   'mode': 1,
#   'speechiness': 0.125,
#   'tempo': 125.857,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3p07oZZpSNdVtN93M5yIY5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3p07oZZpSNdVtN93M5yIY5',
#   'valence': 0.398},
#  'Down - KALUMA': {'acousticness': 0.0249,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0oMoHEZPRd2DnD3EErXYpG',
#   'danceability': 0.717,
#   'duration_ms': 207000,
#   'energy': 0.661,
#   'id': '0oMoHEZPRd2DnD3EErXYpG',
#   'instrumentalness': 1.56e-06,
#   'key': 11,
#   'liveness': 0.128,
#   'loudness': -7.602,
#   'mode': 0,
#   'speechiness': 0.0408,
#   'tempo': 128.051,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0oMoHEZPRd2DnD3EErXYpG',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0oMoHEZPRd2DnD3EErXYpG',
#   'valence': 0.344},
#  'Sad (feat. Afrojack) - Chico Rose': {'acousticness': 0.0421,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ESPuOrSsRcBISzcMlzmY5',
#   'danceability': 0.717,
#   'duration_ms': 161280,
#   'energy': 0.716,
#   'id': '4ESPuOrSsRcBISzcMlzmY5',
#   'instrumentalness': 0.000467,
#   'key': 3,
#   'liveness': 0.0699,
#   'loudness': -5.485,
#   'mode': 0,
#   'speechiness': 0.0432,
#   'tempo': 125.064,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4ESPuOrSsRcBISzcMlzmY5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4ESPuOrSsRcBISzcMlzmY5',
#   'valence': 0.206},
#  'London - DJ Antoine Vs Mad Mark 2k16 Radio Edit - DJ Antoine': {'acousticness': 0.0272,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MGC8lKkD3wNdr7KjFRa3C',
#   'danceability': 0.771,
#   'duration_ms': 213432,
#   'energy': 0.841,
#   'id': '0MGC8lKkD3wNdr7KjFRa3C',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.228,
#   'loudness': -5.545,
#   'mode': 1,
#   'speechiness': 0.113,
#   'tempo': 125.979,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0MGC8lKkD3wNdr7KjFRa3C',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0MGC8lKkD3wNdr7KjFRa3C',
#   'valence': 0.856},
#  'You & I - Bru-C': {'acousticness': 0.087,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PX9O7QzWYClP6PPuIaomj',
#   'danceability': 0.646,
#   'duration_ms': 264000,
#   'energy': 0.864,
#   'id': '0PX9O7QzWYClP6PPuIaomj',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0923,
#   'loudness': -3.727,
#   'mode': 1,
#   'speechiness': 0.0718,
#   'tempo': 87.419,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0PX9O7QzWYClP6PPuIaomj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0PX9O7QzWYClP6PPuIaomj',
#   'valence': 0.082},
#  'In And Out Of Love - Armin van Buuren': {'acousticness': 0.067,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57nKL06bKwjaM5Y0aMtY9v',
#   'danceability': 0.528,
#   'duration_ms': 181680,
#   'energy': 0.705,
#   'id': '57nKL06bKwjaM5Y0aMtY9v',
#   'instrumentalness': 6.4e-05,
#   'key': 1,
#   'liveness': 0.125,
#   'loudness': -6.777,
#   'mode': 1,
#   'speechiness': 0.029,
#   'tempo': 134.983,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/57nKL06bKwjaM5Y0aMtY9v',
#   'type': 'audio_features',
#   'uri': 'spotify:track:57nKL06bKwjaM5Y0aMtY9v',
#   'valence': 0.418},
#  'After Hours - The Weeknd': {'acousticness': 0.0811,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2p8IUWQDrpjuFltbdgLOag',
#   'danceability': 0.664,
#   'duration_ms': 361027,
#   'energy': 0.572,
#   'id': '2p8IUWQDrpjuFltbdgLOag',
#   'instrumentalness': 0.00604,
#   'key': 5,
#   'liveness': 0.121,
#   'loudness': -6.099,
#   'mode': 0,
#   'speechiness': 0.0305,
#   'tempo': 108.959,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2p8IUWQDrpjuFltbdgLOag',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2p8IUWQDrpjuFltbdgLOag',
#   'valence': 0.143},
#  'Need Me - J.I the Prince of N.Y': {'acousticness': 0.156,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dzja72gQodveSpguIQGJl',
#   'danceability': 0.815,
#   'duration_ms': 151641,
#   'energy': 0.567,
#   'id': '2dzja72gQodveSpguIQGJl',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.0884,
#   'loudness': -4.653,
#   'mode': 0,
#   'speechiness': 0.135,
#   'tempo': 95.034,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2dzja72gQodveSpguIQGJl',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2dzja72gQodveSpguIQGJl',
#   'valence': 0.732},
#  "Nobody's Better (feat. Fetty Wap) - Z": {'acousticness': 0.0134,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XKm1z5lYIq486iWMLnSFY',
#   'danceability': 0.357,
#   'duration_ms': 209591,
#   'energy': 0.661,
#   'id': '6XKm1z5lYIq486iWMLnSFY',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.166,
#   'loudness': -7.259,
#   'mode': 0,
#   'speechiness': 0.106,
#   'tempo': 101.038,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6XKm1z5lYIq486iWMLnSFY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6XKm1z5lYIq486iWMLnSFY',
#   'valence': 0.541},
#  'Eenie Meenie - Radio Version - Sean Kingston': {'acousticness': 0.0412,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Yaw2PmyOETOnEM3TCf98I',
#   'danceability': 0.718,
#   'duration_ms': 201973,
#   'energy': 0.638,
#   'id': '4Yaw2PmyOETOnEM3TCf98I',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.169,
#   'loudness': -3.479,
#   'mode': 1,
#   'speechiness': 0.031,
#   'tempo': 121.242,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4Yaw2PmyOETOnEM3TCf98I',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4Yaw2PmyOETOnEM3TCf98I',
#   'valence': 0.835},
#  'Wake Up Dead - T-Pain': {'acousticness': 0.0787,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13KcxQJSvNbTFRB1pNf9DZ',
#   'danceability': 0.469,
#   'duration_ms': 271464,
#   'energy': 0.413,
#   'id': '13KcxQJSvNbTFRB1pNf9DZ',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.119,
#   'loudness': -7.573,
#   'mode': 0,
#   'speechiness': 0.0575,
#   'tempo': 100.959,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/13KcxQJSvNbTFRB1pNf9DZ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:13KcxQJSvNbTFRB1pNf9DZ',
#   'valence': 0.442},
#  "That's A Fact (feat. Fivio Foreign & Mr. Swipey) - Remix - French Montana": {'acousticness': 0.00791,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4bEqx2oD0GUgs3bICkrJ1l',
#   'danceability': 0.75,
#   'duration_ms': 244163,
#   'energy': 0.677,
#   'id': '4bEqx2oD0GUgs3bICkrJ1l',
#   'instrumentalness': 6.47e-05,
#   'key': 5,
#   'liveness': 0.292,
#   'loudness': -5.762,
#   'mode': 0,
#   'speechiness': 0.286,
#   'tempo': 150.322,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4bEqx2oD0GUgs3bICkrJ1l',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4bEqx2oD0GUgs3bICkrJ1l',
#   'valence': 0.393},
#  'Mazel Tov - IDK': {'acousticness': 0.000467,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2q0nvnoM52HGglPqzRxD5P',
#   'danceability': 0.837,
#   'duration_ms': 140308,
#   'energy': 0.371,
#   'id': '2q0nvnoM52HGglPqzRxD5P',
#   'instrumentalness': 1.2e-05,
#   'key': 1,
#   'liveness': 0.125,
#   'loudness': -7.94,
#   'mode': 1,
#   'speechiness': 0.131,
#   'tempo': 129.994,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2q0nvnoM52HGglPqzRxD5P',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2q0nvnoM52HGglPqzRxD5P',
#   'valence': 0.228},
#  'Prospect (ft. Lil Baby) - iann dior': {'acousticness': 0.203,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Zjdzxx0dsavsr7Ehr8fGE',
#   'danceability': 0.816,
#   'duration_ms': 226314,
#   'energy': 0.579,
#   'id': '4Zjdzxx0dsavsr7Ehr8fGE',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.127,
#   'loudness': -6.097,
#   'mode': 1,
#   'speechiness': 0.0867,
#   'tempo': 120.078,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4Zjdzxx0dsavsr7Ehr8fGE',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4Zjdzxx0dsavsr7Ehr8fGE',
#   'valence': 0.43},
#  'Rain On Me (with Ariana Grande) - Lady Gaga': {'acousticness': 0.021,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24ySl2hOPGCDcxBxFIqWBu',
#   'danceability': 0.672,
#   'duration_ms': 182200,
#   'energy': 0.855,
#   'id': '24ySl2hOPGCDcxBxFIqWBu',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.323,
#   'loudness': -3.764,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'tempo': 123.056,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/24ySl2hOPGCDcxBxFIqWBu',
#   'type': 'audio_features',
#   'uri': 'spotify:track:24ySl2hOPGCDcxBxFIqWBu',
#   'valence': 0.646},
#  'Hopeless Romantic (feat. Swae Lee) - Wiz Khalifa': {'acousticness': 0.307,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7IBSffWIu7P2MC7kMwy2FM',
#   'danceability': 0.877,
#   'duration_ms': 226743,
#   'energy': 0.477,
#   'id': '7IBSffWIu7P2MC7kMwy2FM',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0929,
#   'loudness': -7.379,
#   'mode': 0,
#   'speechiness': 0.0587,
#   'tempo': 127.023,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7IBSffWIu7P2MC7kMwy2FM',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7IBSffWIu7P2MC7kMwy2FM',
#   'valence': 0.552},
#  'Chicago\u202c\u202c - Vigiland': {'acousticness': 0.00362,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22eSlcMUCvdx126aiXbces',
#   'danceability': 0.961,
#   'duration_ms': 141113,
#   'energy': 0.491,
#   'id': '22eSlcMUCvdx126aiXbces',
#   'instrumentalness': 0.0159,
#   'key': 9,
#   'liveness': 0.119,
#   'loudness': -6.264,
#   'mode': 0,
#   'speechiness': 0.0644,
#   'tempo': 124.074,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/22eSlcMUCvdx126aiXbces',
#   'type': 'audio_features',
#   'uri': 'spotify:track:22eSlcMUCvdx126aiXbces',
#   'valence': 0.586},
#  'Drown (feat. Clinton Kane) - Martin Garrix': {'acousticness': 0.212,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RVtBlHFKj51Ipvpfv5ER4',
#   'danceability': 0.573,
#   'duration_ms': 174062,
#   'energy': 0.739,
#   'id': '4RVtBlHFKj51Ipvpfv5ER4',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.175,
#   'loudness': -5.455,
#   'mode': 1,
#   'speechiness': 0.0581,
#   'tempo': 120.077,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4RVtBlHFKj51Ipvpfv5ER4',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4RVtBlHFKj51Ipvpfv5ER4',
#   'valence': 0.363},
#  'All Around The World (La La La) - Marnik Remix - R3HAB': {'acousticness': 0.0882,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ALOVWJZcJO70uojmNHtb6',
#   'danceability': 0.707,
#   'duration_ms': 170693,
#   'energy': 0.914,
#   'id': '6ALOVWJZcJO70uojmNHtb6',
#   'instrumentalness': 0.0833,
#   'key': 9,
#   'liveness': 0.112,
#   'loudness': -4.329,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'tempo': 135.015,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6ALOVWJZcJO70uojmNHtb6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6ALOVWJZcJO70uojmNHtb6',
#   'valence': 0.706},
#  'My Best Life (feat. Mike Waters) - Club Mix - KSHMR': {'acousticness': 0.018,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78XfOXpUShe7mFwhjBEd94',
#   'danceability': 0.603,
#   'duration_ms': 198533,
#   'energy': 0.921,
#   'id': '78XfOXpUShe7mFwhjBEd94',
#   'instrumentalness': 9.2e-05,
#   'key': 8,
#   'liveness': 0.183,
#   'loudness': -3.693,
#   'mode': 0,
#   'speechiness': 0.391,
#   'tempo': 120.201,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/78XfOXpUShe7mFwhjBEd94',
#   'type': 'audio_features',
#   'uri': 'spotify:track:78XfOXpUShe7mFwhjBEd94',
#   'valence': 0.675},
#  'SOS (feat. Aloe Blacc) - Avicii': {'acousticness': 0.272,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2x0RZdkZcD8QRI53XT4GI5',
#   'danceability': 0.802,
#   'duration_ms': 157202,
#   'energy': 0.645,
#   'id': '2x0RZdkZcD8QRI53XT4GI5',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.119,
#   'loudness': -6.181,
#   'mode': 0,
#   'speechiness': 0.0715,
#   'tempo': 100.001,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2x0RZdkZcD8QRI53XT4GI5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2x0RZdkZcD8QRI53XT4GI5',
#   'valence': 0.376},
#  'House Party - Radio Edit - DJ Antoine': {'acousticness': 0.0693,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wm8SCfjMXhHXGtraWwGw9',
#   'danceability': 0.699,
#   'duration_ms': 206800,
#   'energy': 0.916,
#   'id': '1wm8SCfjMXhHXGtraWwGw9',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.159,
#   'loudness': -3.382,
#   'mode': 0,
#   'speechiness': 0.0558,
#   'tempo': 127.968,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1wm8SCfjMXhHXGtraWwGw9',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1wm8SCfjMXhHXGtraWwGw9',
#   'valence': 0.773},
#  'My Love (feat. Jess Glynne) - Route 94': {'acousticness': 0.000132,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61UQzeiIluhpzpMdY4ag3q',
#   'danceability': 0.814,
#   'duration_ms': 259934,
#   'energy': 0.622,
#   'id': '61UQzeiIluhpzpMdY4ag3q',
#   'instrumentalness': 0.72,
#   'key': 8,
#   'liveness': 0.0658,
#   'loudness': -7.573,
#   'mode': 1,
#   'speechiness': 0.0492,
#   'tempo': 119.976,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/61UQzeiIluhpzpMdY4ag3q',
#   'type': 'audio_features',
#   'uri': 'spotify:track:61UQzeiIluhpzpMdY4ag3q',
#   'valence': 0.726},
#  'Right Now (Na Na Na) - Akon': {'acousticness': 0.267,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ARJhjuI6TNYZCxYygFQ4F',
#   'danceability': 0.832,
#   'duration_ms': 240747,
#   'energy': 0.87,
#   'id': '1ARJhjuI6TNYZCxYygFQ4F',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.412,
#   'loudness': -4.2,
#   'mode': 0,
#   'speechiness': 0.167,
#   'tempo': 138.003,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1ARJhjuI6TNYZCxYygFQ4F',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1ARJhjuI6TNYZCxYygFQ4F',
#   'valence': 0.566},
#  'Summer of Love - Cascada': {'acousticness': 0.00273,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AzuRUQBFH1xtxZlUtT0VJ',
#   'danceability': 0.569,
#   'duration_ms': 215735,
#   'energy': 0.747,
#   'id': '5AzuRUQBFH1xtxZlUtT0VJ',
#   'instrumentalness': 1.31e-05,
#   'key': 8,
#   'liveness': 0.247,
#   'loudness': -5.634,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'tempo': 127.94,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5AzuRUQBFH1xtxZlUtT0VJ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5AzuRUQBFH1xtxZlUtT0VJ',
#   'valence': 0.549},
#  'Temperature Rising - Tory Lanez': {'acousticness': 0.00756,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FKFLWFa7fVoftc7UmYhDC',
#   'danceability': 0.569,
#   'duration_ms': 136333,
#   'energy': 0.519,
#   'id': '1FKFLWFa7fVoftc7UmYhDC',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0809,
#   'loudness': -5.44,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'tempo': 131.91,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/1FKFLWFa7fVoftc7UmYhDC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1FKFLWFa7fVoftc7UmYhDC',
#   'valence': 0.0769},
#  'Daisies - Katy Perry': {'acousticness': 0.0837,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uqh9bualXNHXXwO2wPorc',
#   'danceability': 0.639,
#   'duration_ms': 173124,
#   'energy': 0.546,
#   'id': '4uqh9bualXNHXXwO2wPorc',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.122,
#   'loudness': -5.382,
#   'mode': 1,
#   'speechiness': 0.0407,
#   'tempo': 122.179,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4uqh9bualXNHXXwO2wPorc',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4uqh9bualXNHXXwO2wPorc',
#   'valence': 0.149},
#  'Beautiful Pain (Losin My Mind) - Polo G': {'acousticness': 0.137,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SIB2yxKoFOrbkjA4zfQbB',
#   'danceability': 0.597,
#   'duration_ms': 171442,
#   'energy': 0.477,
#   'id': '4SIB2yxKoFOrbkjA4zfQbB',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.113,
#   'loudness': -9.638,
#   'mode': 0,
#   'speechiness': 0.642,
#   'tempo': 80.382,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4SIB2yxKoFOrbkjA4zfQbB',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4SIB2yxKoFOrbkjA4zfQbB',
#   'valence': 0.512},
#  'Rude Boy - Rihanna': {'acousticness': 0.113,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60jzFy6Nn4M0iD1d94oteF',
#   'danceability': 0.563,
#   'duration_ms': 222920,
#   'energy': 0.75,
#   'id': '60jzFy6Nn4M0iD1d94oteF',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.0788,
#   'loudness': -4.496,
#   'mode': 1,
#   'speechiness': 0.127,
#   'tempo': 173.906,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/60jzFy6Nn4M0iD1d94oteF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:60jzFy6Nn4M0iD1d94oteF',
#   'valence': 0.812},
#  'Tu Meri - Jersey Club Remix By Jayhaan - Jayhaan': {'acousticness': 0.017,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/39u5UghSExp8XeJlxcHEeG',
#   'danceability': 0.767,
#   'duration_ms': 101052,
#   'energy': 0.934,
#   'id': '39u5UghSExp8XeJlxcHEeG',
#   'instrumentalness': 0.0112,
#   'key': 5,
#   'liveness': 0.0936,
#   'loudness': -7.248,
#   'mode': 0,
#   'speechiness': 0.0442,
#   'tempo': 145.044,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/39u5UghSExp8XeJlxcHEeG',
#   'type': 'audio_features',
#   'uri': 'spotify:track:39u5UghSExp8XeJlxcHEeG',
#   'valence': 0.51},
#  'Push It - O.T. Genasis': {'acousticness': 0.143,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/448hNuS6TH90bjpIHIJqH3',
#   'danceability': 0.971,
#   'duration_ms': 172609,
#   'energy': 0.621,
#   'id': '448hNuS6TH90bjpIHIJqH3',
#   'instrumentalness': 3.22e-06,
#   'key': 11,
#   'liveness': 0.108,
#   'loudness': -5.447,
#   'mode': 1,
#   'speechiness': 0.237,
#   'tempo': 128.053,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/448hNuS6TH90bjpIHIJqH3',
#   'type': 'audio_features',
#   'uri': 'spotify:track:448hNuS6TH90bjpIHIJqH3',
#   'valence': 0.445},
#  'I Would Like - Zara Larsson': {'acousticness': 0.0853,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Q4jmPHwu0wrJvqrld0FQ6',
#   'danceability': 0.486,
#   'duration_ms': 226720,
#   'energy': 0.713,
#   'id': '4Q4jmPHwu0wrJvqrld0FQ6',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.0839,
#   'loudness': -3.949,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'tempo': 121.028,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4Q4jmPHwu0wrJvqrld0FQ6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4Q4jmPHwu0wrJvqrld0FQ6',
#   'valence': 0.297},
#  'Tuesday - NALYRO': {'acousticness': 0.212,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/06MBCHXj4MAWJhiB4qGWXA',
#   'danceability': 0.867,
#   'duration_ms': 143609,
#   'energy': 0.831,
#   'id': '06MBCHXj4MAWJhiB4qGWXA',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.11,
#   'loudness': -3.665,
#   'mode': 1,
#   'speechiness': 0.112,
#   'tempo': 128.116,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/06MBCHXj4MAWJhiB4qGWXA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:06MBCHXj4MAWJhiB4qGWXA',
#   'valence': 0.19},
#  'Bad - Don Diablo': {'acousticness': 0.406,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1T4U8Q2DRfs6OUg8DEsRZf',
#   'danceability': 0.791,
#   'duration_ms': 169911,
#   'energy': 0.738,
#   'id': '1T4U8Q2DRfs6OUg8DEsRZf',
#   'instrumentalness': 0.00826,
#   'key': 0,
#   'liveness': 0.159,
#   'loudness': -5.197,
#   'mode': 1,
#   'speechiness': 0.0732,
#   'tempo': 123.927,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1T4U8Q2DRfs6OUg8DEsRZf',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1T4U8Q2DRfs6OUg8DEsRZf',
#   'valence': 0.666},
#  'No Church In The Wild - JAY-Z': {'acousticness': 0.246,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Osd3Yf8K73aj4ySn6LrvK',
#   'danceability': 0.654,
#   'duration_ms': 272507,
#   'energy': 0.751,
#   'id': '3Osd3Yf8K73aj4ySn6LrvK',
#   'instrumentalness': 0.0179,
#   'key': 8,
#   'liveness': 0.167,
#   'loudness': -7.508,
#   'mode': 0,
#   'speechiness': 0.105,
#   'tempo': 92.781,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3Osd3Yf8K73aj4ySn6LrvK',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3Osd3Yf8K73aj4ySn6LrvK',
#   'valence': 0.568},
#  'Drown (feat. Clinton Kane) - Alle Farben Remix - Martin Garrix': {'acousticness': 0.0972,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3L3s97R0738xGQ2VqB12qo',
#   'danceability': 0.679,
#   'duration_ms': 169270,
#   'energy': 0.852,
#   'id': '3L3s97R0738xGQ2VqB12qo',
#   'instrumentalness': 6.59e-05,
#   'key': 6,
#   'liveness': 0.0978,
#   'loudness': -5.007,
#   'mode': 0,
#   'speechiness': 0.0501,
#   'tempo': 123.889,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3L3s97R0738xGQ2VqB12qo',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3L3s97R0738xGQ2VqB12qo',
#   'valence': 0.393},
#  'Mixed Personalities (feat. Kanye West) - YNW Melly': {'acousticness': 0.457,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6vWEAOUSxohKxhp0K1BsxL',
#   'danceability': 0.661,
#   'duration_ms': 230400,
#   'energy': 0.44,
#   'id': '6vWEAOUSxohKxhp0K1BsxL',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.128,
#   'loudness': -9.104,
#   'mode': 1,
#   'speechiness': 0.0803,
#   'tempo': 149.937,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6vWEAOUSxohKxhp0K1BsxL',
# ...
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5w8wL9IpVlOerzOzOvkjvG',
#   'danceability': 0.785,
#   'duration_ms': 248053,
#   'energy': 0.726,
#   'id': '5w8wL9IpVlOerzOzOvkjvG',
#   'instrumentalness': 4.01e-06,
#   'key': 2,
#   'liveness': 0.316,
#   'loudness': -4.209,
#   'mode': 1,
#   'speechiness': 0.0387,
#   'tempo': 119.963,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5w8wL9IpVlOerzOzOvkjvG',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5w8wL9IpVlOerzOzOvkjvG',
#   'valence': 0.181},
#  'Paris - Sabrina Carpenter': {'acousticness': 0.0482,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/359HNzfOXhCMHB1pNKhyfH',
#   'danceability': 0.576,
#   'duration_ms': 218080,
#   'energy': 0.671,
#   'id': '359HNzfOXhCMHB1pNKhyfH',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.114,
#   'loudness': -6.408,
#   'mode': 0,
#   'speechiness': 0.0474,
#   'tempo': 114.839,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/359HNzfOXhCMHB1pNKhyfH',
#   'type': 'audio_features',
#   'uri': 'spotify:track:359HNzfOXhCMHB1pNKhyfH',
#   'valence': 0.226},
#  'Energy (with A$AP Rocky & Sabrina Claudio) - BURNS': {'acousticness': 0.0627,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13jLiEg5wdMXuJzXXnRcnj',
#   'danceability': 0.684,
#   'duration_ms': 228396,
#   'energy': 0.862,
#   'id': '13jLiEg5wdMXuJzXXnRcnj',
#   'instrumentalness': 0.000177,
#   'key': 6,
#   'liveness': 0.126,
#   'loudness': -4.855,
#   'mode': 0,
#   'speechiness': 0.0952,
#   'tempo': 120.02,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/13jLiEg5wdMXuJzXXnRcnj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:13jLiEg5wdMXuJzXXnRcnj',
#   'valence': 0.275},
#  'Homicide (feat. Eminem) - Logic': {'acousticness': 0.137,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7M2tXmeS15NAzEn7ABFeBg',
#   'danceability': 0.694,
#   'duration_ms': 245387,
#   'energy': 0.759,
#   'id': '7M2tXmeS15NAzEn7ABFeBg',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.167,
#   'loudness': -5.667,
#   'mode': 0,
#   'speechiness': 0.398,
#   'tempo': 140.055,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7M2tXmeS15NAzEn7ABFeBg',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7M2tXmeS15NAzEn7ABFeBg',
#   'valence': 0.77},
#  "Stay (Don't Go Away) [feat. Raye] - David Guetta": {'acousticness': 0.259,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YhN72dRYL2Z3MsaKyT7rS',
#   'danceability': 0.669,
#   'duration_ms': 185943,
#   'energy': 0.797,
#   'id': '4YhN72dRYL2Z3MsaKyT7rS',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.199,
#   'loudness': -5.68,
#   'mode': 0,
#   'speechiness': 0.0624,
#   'tempo': 119.865,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4YhN72dRYL2Z3MsaKyT7rS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4YhN72dRYL2Z3MsaKyT7rS',
#   'valence': 0.552},
#  "I Don't Care (with Justin Bieber) - Ed Sheeran": {'acousticness': 0.0912,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HVWdVOQ0ZA45FuZGSfvns',
#   'danceability': 0.798,
#   'duration_ms': 219947,
#   'energy': 0.675,
#   'id': '3HVWdVOQ0ZA45FuZGSfvns',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0894,
#   'loudness': -5.041,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'tempo': 101.956,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3HVWdVOQ0ZA45FuZGSfvns',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3HVWdVOQ0ZA45FuZGSfvns',
#   'valence': 0.842},
#  'Like To Be You (feat. Julia Michaels) - Shawn Mendes': {'acousticness': 0.812,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2IssBpPtHcViZL5vYQNHhA',
#   'danceability': 0.737,
#   'duration_ms': 159400,
#   'energy': 0.451,
#   'id': '2IssBpPtHcViZL5vYQNHhA',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.108,
#   'loudness': -9.405,
#   'mode': 1,
#   'speechiness': 0.229,
#   'tempo': 153.766,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2IssBpPtHcViZL5vYQNHhA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2IssBpPtHcViZL5vYQNHhA',
#   'valence': 0.664},
#  'Temperature - Sean Paul': {'acousticness': 0.106,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k2GOhqsrxDTAbFFSdNJjT',
#   'danceability': 0.951,
#   'duration_ms': 218573,
#   'energy': 0.6,
#   'id': '0k2GOhqsrxDTAbFFSdNJjT',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0712,
#   'loudness': -4.675,
#   'mode': 0,
#   'speechiness': 0.0685,
#   'tempo': 125.04,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0k2GOhqsrxDTAbFFSdNJjT',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0k2GOhqsrxDTAbFFSdNJjT',
#   'valence': 0.822},
#  'The Purge - Hopsin': {'acousticness': 0.215,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7J2T6mw5zBGhHLsK3GC5PA',
#   'danceability': 0.714,
#   'duration_ms': 203704,
#   'energy': 0.844,
#   'id': '7J2T6mw5zBGhHLsK3GC5PA',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.13,
#   'loudness': -8.031,
#   'mode': 1,
#   'speechiness': 0.309,
#   'tempo': 147.786,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7J2T6mw5zBGhHLsK3GC5PA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7J2T6mw5zBGhHLsK3GC5PA',
#   'valence': 0.543},
#  'Love Yourself - Justin Bieber': {'acousticness': 0.835,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50kpGaPAhYJ3sGmk6vplg0',
#   'danceability': 0.609,
#   'duration_ms': 233720,
#   'energy': 0.378,
#   'id': '50kpGaPAhYJ3sGmk6vplg0',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.28,
#   'loudness': -9.828,
#   'mode': 1,
#   'speechiness': 0.438,
#   'tempo': 100.418,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/50kpGaPAhYJ3sGmk6vplg0',
#   'type': 'audio_features',
#   'uri': 'spotify:track:50kpGaPAhYJ3sGmk6vplg0',
#   'valence': 0.515},
#  '4 AM - Scooter': {'acousticness': 0.000736,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/29f9l4ImBUkA33j8kQBy65',
#   'danceability': 0.554,
#   'duration_ms': 197497,
#   'energy': 0.868,
#   'id': '29f9l4ImBUkA33j8kQBy65',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.327,
#   'loudness': -4.163,
#   'mode': 0,
#   'speechiness': 0.0949,
#   'tempo': 132.009,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/29f9l4ImBUkA33j8kQBy65',
#   'type': 'audio_features',
#   'uri': 'spotify:track:29f9l4ImBUkA33j8kQBy65',
#   'valence': 0.243},
#  'Scar Tissue - Red Hot Chili Peppers': {'acousticness': 0.0779,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1G391cbiT3v3Cywg8T7DM1',
#   'danceability': 0.595,
#   'duration_ms': 215907,
#   'energy': 0.717,
#   'id': '1G391cbiT3v3Cywg8T7DM1',
#   'instrumentalness': 0.00274,
#   'key': 0,
#   'liveness': 0.108,
#   'loudness': -4.803,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'tempo': 88.969,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1G391cbiT3v3Cywg8T7DM1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1G391cbiT3v3Cywg8T7DM1',
#   'valence': 0.547},
#  'Ready To Let Go - Cage The Elephant': {'acousticness': 0.011,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UyAtnwhaKv7EG1BdkBYRI',
#   'danceability': 0.719,
#   'duration_ms': 187973,
#   'energy': 0.896,
#   'id': '4UyAtnwhaKv7EG1BdkBYRI',
#   'instrumentalness': 3.25e-05,
#   'key': 1,
#   'liveness': 0.0731,
#   'loudness': -3.263,
#   'mode': 1,
#   'speechiness': 0.037,
#   'tempo': 100.962,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4UyAtnwhaKv7EG1BdkBYRI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4UyAtnwhaKv7EG1BdkBYRI',
#   'valence': 0.746},
#  'Midnight City - M83': {'acousticness': 0.0161,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1eyzqe2QqGZUmfcPZtrIyt',
#   'danceability': 0.526,
#   'duration_ms': 241440,
#   'energy': 0.712,
#   'id': '1eyzqe2QqGZUmfcPZtrIyt',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.179,
#   'loudness': -6.525,
#   'mode': 0,
#   'speechiness': 0.0356,
#   'tempo': 105.009,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1eyzqe2QqGZUmfcPZtrIyt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1eyzqe2QqGZUmfcPZtrIyt',
#   'valence': 0.32},
#  'In The Air Tonight - 2015 Remastered - Phil Collins': {'acousticness': 0.551,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18AXbzPzBS8Y3AkgSxzJPb',
#   'danceability': 0.446,
#   'duration_ms': 336453,
#   'energy': 0.239,
#   'id': '18AXbzPzBS8Y3AkgSxzJPb',
#   'instrumentalness': 4.1e-06,
#   'key': 0,
#   'liveness': 0.0697,
#   'loudness': -13.945,
#   'mode': 1,
#   'speechiness': 0.0316,
#   'tempo': 189.507,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/18AXbzPzBS8Y3AkgSxzJPb',
#   'type': 'audio_features',
#   'uri': 'spotify:track:18AXbzPzBS8Y3AkgSxzJPb',
#   'valence': 0.298},
#  "I Don't Care Anymore - 2016 Remaster - Phil Collins": {'acousticness': 0.188,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24IdPCimVnJJDRuB5YSDiS',
#   'danceability': 0.703,
#   'duration_ms': 305707,
#   'energy': 0.422,
#   'id': '24IdPCimVnJJDRuB5YSDiS',
#   'instrumentalness': 0.00311,
#   'key': 11,
#   'liveness': 0.0851,
#   'loudness': -8.297,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'tempo': 140.494,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/24IdPCimVnJJDRuB5YSDiS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:24IdPCimVnJJDRuB5YSDiS',
#   'valence': 0.442},
#  'Hurt - Johnny Cash': {'acousticness': 0.649,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28cnXtME493VX9NOw9cIUh',
#   'danceability': 0.534,
#   'duration_ms': 216533,
#   'energy': 0.392,
#   'id': '28cnXtME493VX9NOw9cIUh',
#   'instrumentalness': 0.000227,
#   'key': 9,
#   'liveness': 0.0948,
#   'loudness': -7.636,
#   'mode': 0,
#   'speechiness': 0.0267,
#   'tempo': 90.379,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/28cnXtME493VX9NOw9cIUh',
#   'type': 'audio_features',
#   'uri': 'spotify:track:28cnXtME493VX9NOw9cIUh',
#   'valence': 0.163},
#  'Hot Blood - KALEO': {'acousticness': 0.00327,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7d9sZF7jmepe2EYdETlNWK',
#   'danceability': 0.325,
#   'duration_ms': 218600,
#   'energy': 0.903,
#   'id': '7d9sZF7jmepe2EYdETlNWK',
#   'instrumentalness': 6.13e-06,
#   'key': 2,
#   'liveness': 0.0962,
#   'loudness': -3.173,
#   'mode': 1,
#   'speechiness': 0.117,
#   'tempo': 148.446,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7d9sZF7jmepe2EYdETlNWK',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7d9sZF7jmepe2EYdETlNWK',
#   'valence': 0.401},
#  'Way down We Go - KALEO': {'acousticness': 0.579,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0y1QJc3SJVPKJ1OvFmFqe6',
#   'danceability': 0.489,
#   'duration_ms': 213707,
#   'energy': 0.505,
#   'id': '0y1QJc3SJVPKJ1OvFmFqe6',
#   'instrumentalness': 0.000333,
#   'key': 10,
#   'liveness': 0.104,
#   'loudness': -8.022,
#   'mode': 0,
#   'speechiness': 0.117,
#   'tempo': 163.255,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0y1QJc3SJVPKJ1OvFmFqe6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0y1QJc3SJVPKJ1OvFmFqe6',
#   'valence': 0.337},
#  'Seven Nation Army - The White Stripes': {'acousticness': 0.00817,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7i6r9KotUPQg3ozKKgEPIN',
#   'danceability': 0.737,
#   'duration_ms': 231733,
#   'energy': 0.463,
#   'id': '7i6r9KotUPQg3ozKKgEPIN',
#   'instrumentalness': 0.447,
#   'key': 0,
#   'liveness': 0.255,
#   'loudness': -7.828,
#   'mode': 1,
#   'speechiness': 0.0792,
#   'tempo': 123.881,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7i6r9KotUPQg3ozKKgEPIN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7i6r9KotUPQg3ozKKgEPIN',
#   'valence': 0.324},
#  'Dynamite - Taio Cruz': {'acousticness': 0.00332,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DqdF42leyFIzqNDv9CjId',
#   'danceability': 0.754,
#   'duration_ms': 203867,
#   'energy': 0.804,
#   'id': '1DqdF42leyFIzqNDv9CjId',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.0329,
#   'loudness': -3.177,
#   'mode': 1,
#   'speechiness': 0.0853,
#   'tempo': 119.968,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1DqdF42leyFIzqNDv9CjId',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1DqdF42leyFIzqNDv9CjId',
#   'valence': 0.818},
#  'Row The Body (feat. French Montana) - Taio Cruz': {'acousticness': 0.172,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qmR4IEKBUpgPa14pGuWuS',
#   'danceability': 0.701,
#   'duration_ms': 237500,
#   'energy': 0.695,
#   'id': '5qmR4IEKBUpgPa14pGuWuS',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.238,
#   'loudness': -5.653,
#   'mode': 0,
#   'speechiness': 0.0628,
#   'tempo': 96.033,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5qmR4IEKBUpgPa14pGuWuS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5qmR4IEKBUpgPa14pGuWuS',
#   'valence': 0.624},
#  'Stereo Love - Original - Edward Maya': {'acousticness': 0.0747,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YoW0QdqzxVkpYsQ3sPV2M',
#   'danceability': 0.751,
#   'duration_ms': 192000,
#   'energy': 0.764,
#   'id': '1YoW0QdqzxVkpYsQ3sPV2M',
#   'instrumentalness': 0.00749,
#   'key': 9,
#   'liveness': 0.0925,
#   'loudness': -5.512,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'tempo': 130.076,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1YoW0QdqzxVkpYsQ3sPV2M',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1YoW0QdqzxVkpYsQ3sPV2M',
#   'valence': 0.46},
#  'You Found Me - The Fray': {'acousticness': 0.0187,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4IoYz8XqqdowINzfRrFnhi',
#   'danceability': 0.338,
#   'duration_ms': 241853,
#   'energy': 0.803,
#   'id': '4IoYz8XqqdowINzfRrFnhi',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.136,
#   'loudness': -5.412,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'tempo': 151.994,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4IoYz8XqqdowINzfRrFnhi',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4IoYz8XqqdowINzfRrFnhi',
#   'valence': 0.4},
#  'Lost in the Middle of Nowhere (feat. Becky G) - Kane Brown': {'acousticness': 0.00184,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KfKPfX5cZvOuHoy9io65A',
#   'danceability': 0.559,
#   'duration_ms': 188920,
#   'energy': 0.754,
#   'id': '5KfKPfX5cZvOuHoy9io65A',
#   'instrumentalness': 0.000462,
#   'key': 6,
#   'liveness': 0.0366,
#   'loudness': -5.344,
#   'mode': 0,
#   'speechiness': 0.0481,
#   'tempo': 85.993,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5KfKPfX5cZvOuHoy9io65A',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5KfKPfX5cZvOuHoy9io65A',
#   'valence': 0.438},
#  'Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit - Daft Punk': {'acousticness': 0.0426,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Foc5Q5nqNiosCNqttzHof',
#   'danceability': 0.794,
#   'duration_ms': 248413,
#   'energy': 0.811,
#   'id': '2Foc5Q5nqNiosCNqttzHof',
#   'instrumentalness': 1.07e-06,
#   'key': 6,
#   'liveness': 0.101,
#   'loudness': -8.966,
#   'mode': 0,
#   'speechiness': 0.038,
#   'tempo': 116.047,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2Foc5Q5nqNiosCNqttzHof',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2Foc5Q5nqNiosCNqttzHof',
#   'valence': 0.862},
#  'Sucker - Jonas Brothers': {'acousticness': 0.0427,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22vgEDb5hykfaTwLuskFGD',
#   'danceability': 0.842,
#   'duration_ms': 181027,
#   'energy': 0.734,
#   'id': '22vgEDb5hykfaTwLuskFGD',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.106,
#   'loudness': -5.065,
#   'mode': 0,
#   'speechiness': 0.0588,
#   'tempo': 137.958,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/22vgEDb5hykfaTwLuskFGD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:22vgEDb5hykfaTwLuskFGD',
#   'valence': 0.952},
#  ...}

# %% [markdown]
# now that we have data on my library, we need to get data for potential recommendations
# start with related artists to my top artists

# %%
def get_artist_id(name):
    try:
        fid = spotify.search(name)['artists']['items'][0]['id']
    except IndexError:
        fid = ''
    return fid

# %%
def clean_related_artists(fid):
    related_artists = []
    try:
        
        art_rs = spotify.get_similar_artist(fid)
        for i in range(0, 5):
            related_artists.append(art_rs['artists'][i]['name'])
    except KeyError:
        related_artists.append('')
    return related_artists

def get_top_tracks(fid):
    top_tracks = []
    try:
        top_tracks_dirty = spotify.get_artist_top_tracks(fid)['tracks']
        for i in range(0, len(top_tracks_dirty)):
            top_tracks.append(top_tracks_dirty[i]['name'])
    except KeyError:
        top_tracks.append('')
    return top_tracks

# %%
#makes above thing into function

def get_artist_recs():
    potential_recommendations = []
    top_artist_top_tracks = []
    related_top_tracks = []
    for artist in my_top_artists:
        taid = get_artist_id(artist)
        tops = get_top_tracks(taid)
        for tr in tops:
            top_artist_top_tracks.append(tr + ' - ' + artist)
        rartists = clean_related_artists(taid)
        for rartist in rartists:
            raid = get_artist_id(rartist)
            rtops = get_top_tracks(raid)
            for rtr in rtops:
                related_top_tracks.append(rtr + ' - ' + rartist)
    potential_recommendations = set(top_artist_top_tracks + related_top_tracks)
    for i in list(potential_recommendations):
        if i in new_library:
            potential_recommendations.remove(i)
    return potential_recommendations

# %%
final_pot_recs = get_artist_recs()

# %%
#this is a list of all potential recommendations based on top artists and their related artists and their top tracks,
#that are not already in the library. I will get audio features for each track, and later run a classifier
final_pot_recs
# Out:
# {'12.38 (feat. 21 Savage, Ink & Kadhja Bonet) - Childish Gambino',
#  '123 - Jess Glynne',
#  '123 - Smokepurpp',
#  '1999 - Troye Sivan',
#  '20 Years Later - Yung Pinch',
#  '2019 - Bazanji',
#  "223's (feat. 9lokknine) - YNW Melly",
#  '29 - Bankrol Hayden',
#  '3005 - Childish Gambino',
#  '40 Oz. - D12',
#  '772 Love - YNW Melly',
#  '8TEEN - Khalid',
#  '@ MEH - Playboi Carti',
#  'A Brand New Day (BTS World Original Soundtrack) [Pt. 2] - Zara Larsson',
#  'A Kiss - Bad Meets Evil',
#  'ARGENTINA - Gunna',
#  'Above The Law - Bad Meets Evil',
#  'Adam & Eve - Calboy',
#  'Adorn - Miguel',
#  "Ain't My Fault - Zara Larsson",
#  "Ain't Thinkin Bout You (feat. Louisa) - KREAM",
#  'Alexis - Joey Trap',
#  'Ali Bomaye - The Game',
#  'All For You - Years & Years',
#  'All I Am - Jess Glynne',
#  'All I Think About - Bad Meets Evil',
#  'All In My Head (Flex) (feat. Fetty Wap) - Fifth Harmony',
#  'All Me (feat. Keyshia Cole) - Kehlani',
#  'All My Love - Sabrina Claudio',
#  'All My Love - Wale',
#  'All Night - Matoma',
#  'All Star (with Lil Tjay) - Lil Tecca',
#  'All Star - Mike Perry',
#  'All The Time - Jeremih',
#  'All You Need To Know (feat. Calle Lehmann) - Gryffin',
#  'All the Time - Don Diablo Remix - Zara Larsson',
#  'All the Time - Zara Larsson',
#  'Ambition (feat. Meek Mill & Rick Ross) - Wale',
#  'American Psycho II - D12',
#  'American You - Yelawolf',
#  'Amigo - Lil Tecca',
#  'Anywhere - Rita Ora',
#  'Arms Around You (feat. Maluma & Swae Lee) - Lil Pump',
#  'Aston Martin Music - Rick Ross',
#  'Audi. - Smokepurpp',
#  'B.A.N.K.R.O.L. - Bankrol Hayden',
#  'B.S. (feat. H.E.R.) - Jhené Aiko',
#  'BLINDFOLD (feat. Lil Baby) - Gunna',
#  'BO$$ - Fifth Harmony',
#  'Babushka Boi - A$AP Rocky',
#  'Bacc Seat (feat. Ty Dolla $ign) - Roddy Ricch',
#  'Back To You - From 13 Reasons Why – Season 2 Soundtrack - Selena Gomez',
#  'Bad (feat. Rihanna) - Remix - Wale',
#  'Bad News - Tom MacDonald',
#  'Bad Things (with Camila Cabello) - Camila Cabello',
#  "Ballin' (with Roddy Ricch) - Roddy Ricch",
#  'Banana Clip - Miguel',
#  'Banana Split (with YNW Melly feat. Lil Durk) - YNW Melly',
#  'Bands - Comethazine',
#  'Bang - Ryan Caraveo',
#  'Barbarian (feat. Lil Tjay) - Calboy',
#  'Be Kind (with Halsey) - Halsey',
#  'Be Kind (with Halsey) - Marshmello',
#  'Be Yours - Yung Pinch',
#  "Beach Ballin' (feat. blackbear) - Yung Pinch",
#  'Beachside - Bazanji',
#  'Beast Mode (feat. PnB Rock & YoungBoy Never Broke Again) - PnB Rock',
#  'Beautiful (feat. Camila Cabello) - Bazzi',
#  'Beautiful (feat. Camila Cabello) - Camila Cabello',
#  'Beautiful People (feat. Khalid) - Ed Sheeran',
#  'Beautiful People (feat. Khalid) - Khalid',
#  'Belong to You (feat. 6LACK) - Sabrina Claudio',
#  'Beside You (feat. Georgia Ku) - Matoma',
#  'Best Friend - Yelawolf',
#  'Best Part (feat. Daniel Caesar) - H.E.R.',
#  'Bezerk (feat. A$AP Ferg) - Big Sean',
#  'Bigger Than - Seeb',
#  'Birthday Sex - Jeremih',
#  'Bleed It - Blueface',
#  'Blessings - Big Sean',
#  'Blessings - The Kid LAROI',
#  'Bloodshot - Mike Perry',
#  'Blue Cheese Salad - Young Nudy',
#  'Body - Dzeko Remix - Loud Luxury',
#  'Body Back (feat. Maia Wright) - Gryffin',
#  'Boss - Lil Pump',
#  'Bouncin (feat. Offset) - Kiana Ledé',
#  'Bow Down (feat. Just Juice) - Bazanji',
#  'Boy With Luv (feat. Halsey) - Halsey',
#  'Boyfriend - Selena Gomez',
#  'Breathe - Years & Years',
#  'Brothers (feat. Luh Kel) - Bankrol Hayden',
#  'Bruised Not Broken (feat. MNEK & Kiana Ledé) - Matoma',
#  'Bubbles - Ryan Caraveo',
#  'Burberry Headband - Lil Mosey',
#  'Bussdown (feat. Offset) - Blueface',
#  'CHANGES - Witt Lowry',
#  'COOLER THAN A BITCH (feat. Roddy Ricch) - Gunna',
#  'Call Out My Name - The Weeknd',
#  'Call You Mine - The Chainsmokers',
#  'Calling My Spirit - Kodak Black',
#  'Can I (feat. Tory Lanez) - Kehlani',
#  'Can I Be Him - James Arthur',
#  'Can You Feel the Love Tonight - Childish Gambino',
#  'Cancelled. - Kiana Ledé',
#  'Caroline (feat. Polo G) - Calboy',
#  'Carry On (from the Original Motion Picture "POKÉMON Detective Pikachu") - Rita Ora',
#  'Carry On - Martin Jensen',
#  'Carry On - Nicky Romero Remix - Rita Ora',
#  'Catfish Billy - Yelawolf',
#  'Catfish Billy 2 - Yelawolf',
#  'Champion (feat. Travis Scott) - NAV',
#  'Champions - Big Sean',
#  'Chanel - Frank Ocean',
#  'Change Your Life (feat. Jhené Aiko) - Kehlani',
#  'Changes - Lucidious',
#  'Changes - Mike Perry',
#  'Chariot (feat. Meek Mill, Lil Durk & Young Thug) - Calboy',
#  'Cheating on You - Charlie Puth',
#  'Chicago Freestyle (feat. Giveon) - Drake',
#  'Chocolate. (ft. Ari Lennox) - Kiana Ledé',
#  'Choices - KREAM',
#  'Chokehold - Cooliecut',
#  'Closer - Halsey',
#  'Closer - The Chainsmokers',
#  'Codeine (feat. Gunna) - NAV',
#  'Codeine Dreaming (feat. Lil Wayne) - Kodak Black',
#  'Cold Weather - Cooliecut',
#  'Come Through and Chill (feat. J. Cole & Salaam Remi) - Miguel',
#  'Comfortable - H.E.R.',
#  'Coming Home - Mike Perry',
#  'Confidently Lost - Sabrina Claudio',
#  'Consequences - Camila Cabello',
#  'Coronao Now (Remix) - Lil Pump',
#  'Coronao Now - Lil Pump',
#  'Costa Rica - Bankrol Hayden',
#  "Could've Been (feat. Bryson Tiller) - H.E.R.",
#  'Covid Mansion - Hopsin',
#  'Crash - Witt Lowry',
#  'Creeping (feat. Rich the Kid) - Lil Skies',
#  'Cross Me (feat. Chance the Rapper & PnB Rock) - PnB Rock',
#  'DOLLAZ ON MY HEAD (feat. Young Thug) - Gunna',
#  'Daddy (feat. Rich The Kid) - Blueface',
#  "Daddy's Lambo - Yelawolf",
#  'Dance To This (feat. Ariana Grande) - Troye Sivan',
#  'Dancing With A Stranger (With Normani) - Cheat Codes Remix - Cheat Codes',
#  "Day 'N' Nite - Martin Jensen Edit - Martin Jensen",
#  'Decisions (feat. Maia Wright) - KREAM',
#  'Deep End (feat. JHart) - Eden Prince Remix - KREAM',
#  'Demi - Comethazine',
#  'Desire - Gryffin Remix - Years & Years',
#  'Desire - Years & Years',
#  'Die For Me (feat. Future & Halsey) - Halsey',
#  'Dirty Dirty (feat. Lil Skies) - Smokepurpp',
#  'Dispatch (feat. DaBaby) - Young Nudy',
#  'Dive - Mike Perry',
#  'Do Not Disturb (feat. Lil Yachty & Offset) - Smokepurpp',
#  'Do the Talking - Lucidious',
#  "Don't Let Me Down (feat. Daya) - The Chainsmokers",
#  "Don't Say You Love Me - Fifth Harmony",
#  "Don't Shoot (feat. Rick Ross, 2 Chainz, Diddy, Fabolous, Wale, DJ Khaled, Swizz Beatz, Yo Gotti, Currensy, Problem, King Pharaoh & TGT) - The Game",
#  "Don't Start Now - Dua Lipa",
#  "Don't Tell 'Em - Jeremih",
#  "Don't Worry Bout Me - Zara Larsson",
#  'Done for Me (feat. Kehlani) - Charlie Puth',
#  'Dope Boy - Calboy',
#  'Double (feat. NLE Choppa) - Smokepurpp',
#  'Down (feat. Gucci Mane) - Fifth Harmony',
#  'Down Below - Roddy Ricch',
#  'Down On Me - Jeremih',
#  'Drink About - Seeb',
#  'Drip Too Hard (Lil Baby & Gunna) - Gunna',
#  'Drowning (feat. Kodak Black) - Kodak Black',
#  'Drowning - KREAM',
#  'EA (feat. 21 Savage) - Young Nudy',
#  'EX - Kiana Ledé',
#  'EX - Remix - Kiana Ledé',
#  'Easier - Seeb Remix - Seeb',
#  'Eastside (with Halsey & Khalid) - Halsey',
#  'Eastside (with Halsey & Khalid) - Khalid',
#  'Easy - Camila Cabello',
#  'Echo - Bad Meets Evil',
#  'Electricity (with Dua Lipa) - Dua Lipa',
#  'Empty - Cooliecut',
#  'Empty Space - James Arthur',
#  'Envy Me - Calboy',
#  'Equals - Lucidious',
#  'Escape - Bazanji',
#  'Everybody Business - Kehlani',
#  'Everybody Hates Me - Tom MacDonald',
#  'Expectations (feat. 6LACK) - Wale',
#  'Extendo (feat. Lil Uzi Vert) - Young Nudy',
#  'Eyes Shut - Years & Years',
#  'F&MU - Kehlani',
#  'FEELS LIKE HOME - Bea Miller',
#  'FIND HIM! - Comethazine',
#  'FRIENDS - Marshmello',
#  'Face the Truth - Lucidious',
#  'Fade Out - Seeb',
#  'Fairplay - Kiana Ledé',
#  'Fake Friends - Bazanji',
#  'Fall in Love with Death - Cooliecut',
#  "Fallin' All In You - Shawn Mendes",
#  'Falling Down - Bonus Track - XXXTENTACION',
#  'Falling Like The Stars - James Arthur',
#  'Family - The Chainsmokers',
#  'Fantasy - Bazzi',
#  'Fed Up - Bazanji',
#  'Feel Good (feat. Daya) - Gryffin',
#  'Feel Me - Selena Gomez',
#  'Feelin Like - Flipp Dinero',
#  'Feels (feat. Pharrell Williams, Katy Perry & Big Sean) - Big Sean',
#  'Feels Like Summer - Childish Gambino',
#  'Fendi (feat. Nicki Minaj & Murda Beatz) - PnB Rock',
#  'Fidget - Lil Skies',
#  'Fight Music - D12',
#  'Fill Me In - Loud Luxury',
#  'Fire N Gold - Bea Miller',
#  'FlatBed Freestyle - Playboi Carti',
#  'Focus - H.E.R.',
#  'For You (With Rita Ora) - Rita Ora',
#  'Foreign - Playboi Carti',
#  'Forfeit. (ft. Lucky Daye) - Kiana Ledé',
#  'Freaky Dancer (feat. DaBaby) - YK Osiris',
#  'Freddy Krueger (feat. Tee Grizzley) - YNW Melly',
#  'Fritolays (feat. Jay Critch) - Flipp Dinero',
#  'Frozen - Sabrina Claudio',
#  'Fukk Sleep (feat. FKA twigs) - A$AP Rocky',
#  "G's - Joey Trap",
#  'G.O.M.D. - J. Cole',
#  'GTA Lyfestyle - Young Nudy',
#  'Gallardo - Comethazine',
#  'Gemini - Tyla Yaweh',
#  'Get Dripped (feat. Playboi Carti) - Lil Yachty',
#  'Ghost - Ryan Caraveo',
#  'Ghost - Witt Lowry',
#  'Girl With The Tattoo Enter.lewd - Miguel',
#  'Girls - D12',
#  'Givenchy Kickin (feat. Lil Baby & Lil Tjay) - Calboy',
#  'Go Dumb (feat. blackbear, The Kid LAROI and Bankrol Hayden) - The Kid LAROI',
#  'Go Somewhere - KREAM',
#  'Godspeed - Frank Ocean',
#  'Gold Roses (feat. Drake) - Rick Ross',
#  'Good Day - iann dior',
#  'Good Thing (with Kehlani) - Kehlani',
#  'Greet Her - Lil Mosey',
#  'Grim Reaper - Ryan Caraveo',
#  'Grip - Seeb',
#  'Gucci Flip Flops (feat. Lil Yachty) - Lil Yachty',
#  'Gucci Gang - Lil Pump',
#  'HOLY GHOST - Joey Trap',
#  'Hallucinate - Dua Lipa',
#  'Hands - Mike Perry',
#  'Happier - Ed Sheeran',
#  'Happiness Over Everything (H.O.E.) (feat. Future & Miguel) - Jhené Aiko',
#  'Hard Place - H.E.R.',
#  'Hate It Or Love It - The Game',
#  'Hate Me (with Juice WRLD) - Juice WRLD',
#  'Havin My Way (feat. Lil Durk) - Lil Skies',
#  'Heatin Up (feat. Gunna) - Gunna',
#  'Heavenly Father (feat. Noah Kahan) - Recorded at Electric Lady Studios, NYC - Gryffin',
#  'Here I Am - Rick Ross',
#  'Hey Julie! (feat. Lil Yachty) - Lil Yachty',
#  'High Fashion (feat. Mustard) - Roddy Ricch',
#  'High Right Now (feat. Wiz Khalifa) - Remix - Tyla Yaweh',
#  'High Right Now - Tyla Yaweh',
#  'Him & I (with Halsey) - Halsey',
#  'Hold My Hand - Jess Glynne',
#  'Hold On (feat. Cheat Codes) - 2020 Edit - Cheat Codes',
#  'Hold You Tonight (with Chris Lane) - Gryffin',
#  'Holy Moly (feat. NLE Choppa) - Blueface',
#  'Honey - Kehlani',
#  'Hope - Lucidious',
#  'Hope - XXXTENTACION',
#  'Horses (with PnB Rock, Kodak Black & A Boogie Wit da Hoodie) - Kodak Black',
#  'Horses (with PnB Rock, Kodak Black & A Boogie Wit da Hoodie) - PnB Rock',
#  'How Come - D12',
#  'How Do You Sleep? - Sam Smith',
#  'How I Move (feat. Lil Baby) - Flipp Dinero',
#  'How Long - Charlie Puth',
#  'How To Be Lonely - Rita Ora',
#  'How We Do - The Game',
#  'Hurt - Witt Lowry',
#  "Hustlin' - Rick Ross",
#  'Hymn for the Weekend - Seeb Remix - Seeb',
#  'I - Lil Skies',
#  "I Can't Fall in Love Without You - Zara Larsson",
#  'I Can’t Get Enough (benny blanco, Selena Gomez, J Balvin, Tainy) - Selena Gomez',
#  'I Could Get Used To This - Martin Jensen',
#  "I Don't Care (with Justin Bieber) - Loud Luxury Remix - Loud Luxury",
#  "I Don't Care - Tom MacDonald",
#  "I Don't Fuck With You - Big Sean",
#  'I Feel It Coming - The Weeknd',
#  'I Got You - Bazzi',
#  'I Hate Hip-Hop - Tom MacDonald',
#  'I Know - Big Sean',
#  'I Know You (feat. Yung Pinch) - Yung Pinch',
#  'I Like Girls (feat. Lil Skies) - PnB Rock',
#  'I Love It (& Lil Pump) - Lil Pump',
#  'I Need Your Love (feat. Ellie Goulding) - Ellie Goulding',
#  'I Think I Luv Her - Tyla Yaweh',
#  'I Took A Pill In Ibiza - Seeb Remix - Seeb',
#  'I Wanna Know (feat. Bea Miller) - Bea Miller',
#  'I Warned Myself - Charlie Puth',
#  'I Will Never Let You Down - Rita Ora',
#  "I'll Be There - Jess Glynne",
#  "I'm Good - Joey Trap",
#  "I'm In Love With a Monster - Fifth Harmony",
#  "I'm Just Feelin' (Du Du Du) - Martin Jensen",
#  "I'm Not Alright - Loud Luxury",
#  "I'm Not The Only One - Sam Smith",
#  "I'm Sorry - Tom MacDonald",
#  'I.F.L.Y. - Bazzi',
#  "If I Can't Have You - Gryffin Remix - Gryffin",
#  'If I Tell You - Flipp Dinero',
#  "If You're Over Me - Years & Years",
#  'Ill Mind of Hopsin 5 - Hopsin',
#  'Ill Mind of Hopsin 8 - Hopsin',
#  'Ill Mind of Hopsin 9 - Hopsin',
#  'Illuminati - Lil Pump',
#  'Illusion - Yung Pinch',
#  'Imagination - Shawn Mendes',
#  'Impatient - Jeremih',
#  'Impossible - James Arthur',
#  'In My Feelings - Drake',
#  'In My Room - Frank Ocean',
#  'In Your Eyes (feat. Alida) - KREAM Remix - KREAM',
#  'In Your Eyes (with Doja Cat) - Remix - The Weeknd',
#  'Incredible - James TW',
#  'Into Your Arms (feat. Ava Max) - Witt Lowry',
#  'It Ain’t Me (with Selena Gomez) - Selena Gomez',
#  "It's Whatever - Smokepurpp",
#  'Ivy - Frank Ocean',
#  'I’m Ready (with Demi Lovato) - Sam Smith',
#  'Jocelyn Flores - XXXTENTACION',
#  'Jump Off - Flipp Dinero',
#  'Jump Out The Window - Big Sean',
#  'Kamikaze - Lil Mosey',
#  'Keep It Simple (feat. Wilder Woods) - Matoma',
#  'Kevin’s Heart - J. Cole',
#  'Kill The Lights (with Nile Rodgers) - Audien Remix - Jess Glynne',
#  'Kindest Regards - Witt Lowry',
#  'Kiss Somebody - Seeb',
#  'Know Your Worth - Khalid',
#  'Kumbaya - Hopsin',
#  'L$D - A$AP Rocky',
#  'LEAD THE RACE (UNDEFEATED) - Comethazine',
#  'Lay Me Down - Sam Smith',
#  'Leave Me On Read - YK Osiris',
#  'Legends - Juice WRLD',
#  'Lesley - Joey Trap',
#  'Let It Eat (feat. Ugly God) - Comethazine',
#  'Let It Go (feat. Anna Clendening) - Matoma',
#  'Let You Love Me - Rita Ora',
#  'Liar - Camila Cabello',
#  'Life Is Good (feat. Drake) - Drake',
#  'Lighters - Bad Meets Evil',
#  'Lights Go Down - Bazanji',
#  'Like It Is - Zara Larsson',
#  'Live Forever (With Cheat Codes) - Cheat Codes',
#  'Living Single - Big Sean',
#  'Lo Mein - Lil Uzi Vert',
#  'Location - Khalid',
#  'Location - Playboi Carti',
#  'Long Day - Yung Pinch',
#  'Look At Her Now - Selena Gomez',
#  'Look Like - Yung Pinch',
#  'Looking At Me (feat. Rich The Kid) - Flipp Dinero',
#  'Lose You To Love Me - Selena Gomez',
#  'Losing My Mind - Lucidious',
#  'Losing You (feat. Max) - Witt Lowry',
#  'Lost - Frank Ocean',
#  'Lost In Japan - Shawn Mendes',
#  'Lotus Flower Bomb (feat. Miguel) - Wale',
#  "Love Don't Change - Jeremih",
#  'Love Me Again (with Jess Glynne) - Jess Glynne',
#  'Love Me Like You Do - Ellie Goulding',
#  'Love... (Her Fault) [feat. Bryson Tiller] - Wale',
#  'Lovers and Friends (feat. YK Osiris) - YK Osiris',
#  'Low-Key - Hopsin',
#  'Lust - Lil Skies',
#  'MEMBERS ONLY! - Cooliecut',
#  'MIDDLE CHILD - PnB Rock',
#  'Mad At Me. - Kiana Ledé',
#  'Magic - Lil Skies',
#  'Magnolia - Playboi Carti',
#  'Mama Cry - YNW Melly',
#  'Man Down (feat. AlunaGeorge) - KREAM Remix - KREAM',
#  'Marvin Gaye (feat. Meghan Trainor) - Charlie Puth',
#  'Mercy - Shawn Mendes',
#  'Middle Of The Night - Martin Jensen',
#  'Midnight Sun - Mike Perry',
#  "Miss Movin' On - Fifth Harmony",
#  'Mister (feat. 21 Savage) - Young Nudy',
#  'Moment of Silence - Lucidious',
#  'Money In The Grave (Drake ft. Rick Ross) - Drake',
#  'Money In The Grave (Drake ft. Rick Ross) - Rick Ross',
#  'Murda - Ryan Caraveo',
#  'My Band - D12',
#  'My Ex - PnB Rock',
#  'My Life - The Game',
#  'My Mistake (feat. Trippz Michaud) - Witt Lowry',
#  'My My My! - Troye Sivan',
#  'My Type (feat. City Girls & Jhené Aiko) - Remix - Jhené Aiko',
#  'Myself - Bazzi',
#  'Myself - NAV',
#  'NEVER GONNA LIKE YOU - Bea Miller',
#  'Naked - James Arthur',
#  'Need Your Love (with Noah Kahan) - Gryffin',
#  'Neighbors - J. Cole',
#  'Nemo - Joey Trap',
#  'Nephew (feat. Lil Pump) - Smokepurpp',
#  'Never Be the Same - Camila Cabello',
#  'Never Call Me - Jhené Aiko',
#  'Nightmares (feat. Lil Skies) - Yung Pinch',
#  'Nights - Frank Ocean',
#  'Nights Like This (feat. Ty Dolla $ign) - Kehlani',
#  "No Flockin' - Kodak Black",
#  'No Longer Silent - Lucidious',
#  'No Response - Tom MacDonald',
#  'No Role Modelz - J. Cole',
#  'Nobody - James Arthur',
#  'Nobody Compares To You (feat. Katie Pearlman) - Gryffin',
#  'None Of Your Concern (feat. Big Sean) - Jhené Aiko',
#  'Nonstop - Drake',
#  'Not Afraid - Eminem',
#  'Nothing - Cooliecut',
#  'Notice Me - PnB Rock',
#  'Noticed - Lil Mosey',
#  'Nowadays (feat. Landon Cube) - Lil Skies',
#  'Nutcase - Ryan Caraveo',
#  'Obama (feat. DaBaby) - Blueface',
#  'Off My Chest (feat. Lil Pump) - Smokepurpp',
#  'Old Thing Back (feat. Ja Rule and Ralph Tresvant) - Matoma',
#  'On Chill (feat. Jeremih) - Wale',
#  'On My Life - Cheat Codes',
#  'On My Own - Bazanji',
#  'One Kiss (with Dua Lipa) - Dua Lipa',
#  'One Life - Mike Perry',
#  'One Night - Lil Yachty',
#  'One Touch - Jess Glynne',
#  'Only The Team (with Lil Mosey & Lil Tjay) - Lil Mosey',
#  'Only Want You - Martin Jensen Remix - Martin Jensen',
#  'Only You - Cheat Codes',
#  "Oprah's Bank Account (Lil Yachty & DaBaby feat. Drake) - Lil Yachty",
#  'Ouch (Thats Hurts) - Cooliecut',
#  'Out Of Love (feat. Internet Money) - Lil Tecca',
#  'Out Of Luck - Lil Tecca',
#  'Outside (feat. Ellie Goulding) - Ellie Goulding',
#  'Over the Rainbow - Cooliecut',
#  'P*$$Y Fairy (OTW) - Jhené Aiko',
#  'PAID MY DUES - NF',
#  'PICK IT UP (feat. A$AP Rocky) - A$AP Rocky',
#  'Pain 1993 (with Playboi Carti) - Drake',
#  'Pain 1993 (with Playboi Carti) - Playboi Carti',
#  'Paradise - Bazzi',
#  'Paradise - Ryan Caraveo',
#  'Paralyzed - NF',
#  'Pardon Me (Lil Yachty feat. Future & Mike WiLL Made-It) - Lil Yachty',
#  'Party We Will Throw Now! - The Game',
#  'Party on the West Coast (feat. Snoop Dogg) - Matoma',
#  'Passionfruit - Drake',
#  'Peanut Butter Jelly - Joey Trap',
#  'Peanut Butter Waffles - Ryan Caraveo',
#  'Perfect - Yung Pinch',
#  'Perfect World - Ryan Caraveo',
#  'Permanent - Comethazine',
#  'Peta (feat. Meek Mill) - Roddy Ricch',
#  'Photograph - Ed Sheeran',
#  'Picasso - Hopsin',
#  'Pimp Like Me - D12',
#  'Pina Colada - Yung Pinch',
#  'Pink + White - Frank Ocean',
#  'Planez - Jeremih',
#  'Play (with Years & Years) - Years & Years',
#  'Playinwitme (feat. Kehlani) - Kehlani',
#  'Please Keep Loving Me - James TW',
#  "Pls Don't Cry - Cooliecut",
#  'Politically Incorrect - Tom MacDonald',
#  'Pop The Trunk - Yelawolf',
#  'Poppin (feat. Lil Pump & Smokepurpp) - Lil Pump',
#  'Poppin (feat. Lil Pump & Smokepurpp) - Smokepurpp',
#  'Potato Salad - A$AP Rocky',
#  'Power - Ellie Goulding',
#  'Praying For My Soul - Flipp Dinero',
#  'Pretty Girl - Cheat Codes X CADE Remix - Cheat Codes',
#  'Price On My Head (feat. The Weeknd) - NAV',
#  'Problem With You - Sabrina Claudio',
#  'Project Dreams - Roddy Ricch',
#  'Promises (with Sam Smith) - Sam Smith',
#  'Psycho - Joey Trap',
#  'Pull Up - Lil Mosey',
#  'Purity (feat. Frank Ocean) - A$AP Rocky',
#  'Purple Lamborghini (with Rick Ross) - Rick Ross',
#  'Purple Pills - D12',
#  'Purpose (feat. G Herbo) - Calboy',
#  'Purse - Joey Trap',
#  'Push It - Rick Ross',
#  'Quite Miss Home - James Arthur',
#  'R.I.P. (feat. Rita Ora & Anitta) - Rita Ora',
#  'Ransom - Lil Tecca',
#  'Rap Game - D12',
#  'Rare - Selena Gomez',
#  'Raw - Bad Meets Evil',
#  'Recap (feat. Don Toliver) - NAV',
#  'Red Nation - The Game',
#  'Red Pills (Love in the Matrix) - Cooliecut',
#  'Red Roses (feat. Landon Cube) - Lil Skies',
#  'Remember (with ZOHARA) - Gryffin',
#  'Remember Me (Dúo) - Miguel',
#  'Remind Me to Forget - Miguel',
#  "Renee's Song - Bazzi",
#  'Rewrite The Stars (with James Arthur & Anne-Marie) - James Arthur',
#  'Rich Bitch - Bankrol Hayden',
#  'Rich Love (with Seeb) - Seeb',
#  'Ride - YK Osiris',
#  'Ride Out - Wale',
#  'Riot - Lil Skies',
#  'Ritual - Rita Ora',
#  'Roll In Peace (feat. XXXTENTACION) - Kodak Black',
#  'Roses (feat. ROZES) - The Chainsmokers',
#  'Rowdy - Yelawolf',
#  'Rumors (feat. ZAYN) - Sabrina Claudio',
#  'Run It Up (feat. Pop Smoke) - NAV',
#  'Run It Up - YK Osiris',
#  'S.L.U.T. - Bea Miller',
#  'SBCNCSLY - Sabrina Claudio',
#  'SKYBOX - Gunna',
#  'SOLVED THE PROBLEM - Comethazine',
#  'Sag My Pants - Hopsin',
#  'Saint Laurenttt - NAV',
#  'Salute (feat. French Montana) - Tyla Yaweh',
#  'Sandlott - Bankrol Hayden',
#  'Sativa - Jhené Aiko',
#  'Save Me - Lucidious',
#  'Say Love - James TW',
#  'Scared to Be Lonely - Dua Lipa',
#  'Scarface (feat. Capo & Rick Ross) - Rick Ross',
#  'Scottie Beam - Rick Ross',
#  'Second Chances. (ft. 6LACK) - Kiana Ledé',
#  'See The Way - Sabrina Claudio',
#  'See You Again (feat. Charlie Puth) - Charlie Puth',
#  'Self Control - Frank Ocean',
#  'Selfish - PnB Rock',
#  'Set Me Free - YK Osiris',
#  'Señorita - Camila Cabello',
#  'She Bad - Tyla Yaweh',
#  'Shine - Years & Years',
#  'Shit On You - D12',
#  'Shotta (feat. Megan Thee Stallion) - Young Nudy',
#  'Show Me Love - Miguel',
#  'Sick and Tired (ft. Machine Gun Kelly and Travis Barker) - iann dior',
#  'Silence - Khalid',
#  'Single Again - Big Sean',
#  'Sledgehammer - Fifth Harmony',
#  'Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) - A Boogie Wit da Hoodie',
#  'Slide (Remix) (feat. Pop Smoke, A Boogie Wit da Hoodie & Chris Brown) - H.E.R.',
#  'Slide - H.E.R.',
#  'Slow Down (with H.E.R.) - H.E.R.',
#  'Sober - Childish Gambino',
#  'Sober - Tom MacDonald',
#  'Soldier - James TW',
#  'Solo Dance - Martin Jensen',
#  'Some Way - NAV',
#  'Somebody - A Boogie Wit da Hoodie',
#  'Somebody - Lil Tecca',
#  "Somebody I'm Not - Martin Jensen",
#  'Something Just Like This - The Chainsmokers',
#  'Sorry - Halsey',
#  'South of the Border (feat. Camila Cabello & Cardi B) - Camila Cabello',
#  'South of the Border (feat. Camila Cabello & Cardi B) - Cheat Codes Remix - Cheat Codes',
#  'Speed Me Up (with Ty Dolla $ign, Lil Yachty & Sueco the Child) - Lil Yachty',
#  'Split/Whole Time - Lil Yachty',
#  'Stainless - The Game',
#  'Start Wit Me (feat. Gunna) - Roddy Ricch',
#  'Stay Schemin - Rick Ross',
#  'Strawberries & Cigarettes - Troye Sivan',
#  'Strings - iann dior',
#  'Suicidal (Remix) [feat. Juice WRLD] - Juice WRLD',
#  'Suicidal - YNW Melly',
#  'Suitcase - James TW',
#  "Summer Feelings (feat. Charlie Puth) - From 'SCOOB!' The Album - Charlie Puth",
#  'Summertime Magic - Childish Gambino',
#  'Sunday Morning (feat. Josie Dunne) - Matoma',
#  'Sundress - A$AP Rocky',
#  'Sunflower Seeds - Young Nudy',
#  'Sure Thing - Miguel',
#  'Surrender - Martin Jensen Remix - Martin Jensen',
#  'T.D (Lil Yachty & Tierra Whack feat. A$AP Rocky & Tyler, The Creator) - Lil Yachty',
#  'THAT BITCH - Bea Miller',
#  'THE RISE - Witt Lowry',
#  'TOP FLOOR (feat. Travis Scott) - Gunna',
#  'TTM (feat. Wiz Khalifa & NGHTMRE) - PnB Rock',
#  'Tables - Joey Trap',
#  'Take From Me - Bad Meets Evil',
#  'Take Me Home - Jess Glynne',
#  'Take Yourself Home - Troye Sivan',
#  'Takeaway - The Chainsmokers',
#  'Taki Taki (with Selena Gomez, Ozuna & Cardi B) - Selena Gomez',
#  'Talk (feat. Disclosure) - Khalid',
#  'Talking Body - KREAM Remix - KREAM',
#  'Tennessee Love - Yelawolf',
#  'That Way - Bonus Track - Lil Uzi Vert',
#  "That's My Girl - Fifth Harmony",
#  'The Bender (with Brando) - Matoma',
#  'The Box - Roddy Ricch',
#  'The Fault in Our Stars - Troye Sivan',
#  'The Game & Skrillex: El Chapo - The Game',
#  'The Good Side - Troye Sivan',
#  'The London (feat. J. Cole & Travis Scott) - J. Cole',
#  'The Need to Know (feat. SZA) - Wale',
#  'The Ocean (feat. Shy Martin) - Mike Perry',
#  'The Old Us - Hopsin',
#  'The Race - Remix - Young Nudy',
#  'The Reunion - Bad Meets Evil',
#  'The Runway - Bazanji',
#  'The Worst - Jhené Aiko',
#  'There for You - Troye Sivan',
#  'These Days (feat. Jess Glynne, Macklemore & Dan Caplen) - Jess Glynne',
#  "They Ain't You - Tyla Yaweh",
#  'Thinkin Bout You - Frank Ocean',
#  'This Way - From SUPERFLY - Original Soundtrack - H.E.R.',
#  'Thotiana (feat. Cardi B, YG) [Remix] - Blueface',
#  'Thotiana - Blueface',
#  'Thursday - Jess Glynne',
#  'Tie Me Down (with Elley Duhé) - Gryffin',
#  'Time - Edit - NF',
#  'Time Goes Down - Flipp Dinero',
#  'Timing - YK Osiris',
#  'To Die For - Sam Smith',
#  'Tommy Lee (feat. Post Malone) - Tyla Yaweh',
#  'Torn - Bonus Track - James TW',
#  'Torn - KREAM Remix - KREAM',
#  'Tour - Blueface',
#  'Toxic - Kehlani',
#  "Transportin' - Kodak Black",
#  'Treehouse (feat. Shotty Horroh) - James Arthur',
#  'Triggered (freestyle) - Jhené Aiko',
#  'Truth Is - Sabrina Claudio',
#  'Turks (with Gunna & ft. Travis Scott) - Gunna',
#  'Turks (with Gunna & ft. Travis Scott) - NAV',
#  'U 2 Luv - Jeremih',
#  'U Remind Me - Recorded at Spotify Studios NYC - James TW',
#  'Under The Sun (with J. Cole & Lute feat. DaBaby) - J. Cole',
#  'Understand Me - Tyla Yaweh',
#  'Unfamiliar - Seeb',
#  'Unjudge Me (feat. Moneybagg Yo) - Calboy',
#  'Unravel Me - Sabrina Claudio',
#  'Until I Die - Mike Perry',
#  'Up All Night - Khalid',
#  'Used To - Lucidious',
#  'Valentine - YK Osiris',
#  'Valentino - Years & Years',
#  'WHITEBOY - Tom MacDonald',
#  'WUNNA - Gunna',
#  'Wake Up in the Sky - Kodak Black',
#  'Walk (Remix) - Comethazine',
#  'Walk - Comethazine',
#  'Walk Em Down (feat. Roddy Ricch) - Roddy Ricch',
#  "We Don't Need 'Em - Ryan Caraveo",
#  'Welcome 2 Hell - Bad Meets Evil',
#  'Welcome to the Party (with French Montana & Lil Pump, feat. Zhavia Ward) - from Deadpool 2 - Lil Pump',
#  'Welcome to the Rodeo - Lil Skies',
#  'West Coast (feat. Blueface, ALLBLACK & YG) - Blueface',
#  'West Coast - Blueface',
#  'Westside - Flipp Dinero',
#  'Westside Story - The Game',
#  'Wet Dreamz - J. Cole',
#  'What I Please (feat. Denzel Curry) - Smokepurpp',
#  'What It Feels Like - Bazanji',
#  'When I Grow Up - NF',
#  'When You Leave - Breathe Carolina Remix - Matoma',
#  'When You Love Someone - Acoustic - James TW',
#  'When You Love Someone - James TW',
#  "While We're Young - Jhené Aiko",
#  'White Ferrari - Frank Ocean',
#  'White Trash - Tom MacDonald',
#  'Who Do You Love - The Chainsmokers',
#  'Who Shot Johnny? - Tyla Yaweh',
#  'Why - Bazzi',
#  'Wicked Games - Kiana Ledé',
#  'Wild Wild - Calboy',
#  'Without Me - Eminem',
#  'Without Me - Halsey',
#  'Wolves - Marshmello',
#  'Wonder If You Wonder - Witt Lowry',
#  'Woosah - Jeremih',
#  'Work Out - J. Cole',
#  'Worth It (feat. Kid Ink) - Fifth Harmony',
#  'Worth It - Remix - YK Osiris',
#  'Worth It - YK Osiris',
#  'Wrong Places (from Songland) - H.E.R.',
#  'YOUTH - Troye Sivan',
#  'Yacht Club (feat. Juice WRLD) - Lil Yachty',
#  'You & Me - James TW',
#  "You Should've Known - Hopsin",
#  'You and Me - Yelawolf',
#  'Young & Alive - Bazzi',
#  'ZEZE (feat. Travis Scott & Offset) - Kodak Black',
#  'Zone 6 (Remix) (feat. Future & 6LACK) - Young Nudy',
#  'feel something - Bea Miller',
#  "i can't breathe - Bea Miller",
#  "i'm so tired... - Troye Sivan",
#  "it's not u it's me - Bea Miller",
#  'like that - Bea Miller',
#  'lovely (with Khalid) - Khalid',
#  'oui - Jeremih',
#  'waves - Tame Impala Remix - Miguel'}

# %%
#my next set of recommendations will be based on new releases

# %%
#gets an albums id based on query
def get_album_id(q):
    new_al = spotify.search(q, search_type = 'album')
    return_album_id = new_al['albums']['items'][0]['id']
    return return_album_id

# %%
#gets tracks cleanly from spotify albums
def clean_album_tracks(alid):
    clean_album_songs = []
    iter_al_tracks = spotify.get_album_tracks(alid)['items']
    for trackb in iter_al_tracks:
        clean_album_songs.append(trackb['name'] + " - " + trackb['artists'][0]['name'])
    return clean_album_songs

# %%
def potential_release_radar():
    potential_rr_tracks = []
    rr = spotify.new_releases()
    dirty_rr = rr['albums']['items']
    for i in range(0, len(dirty_rr)):
        potential_rr_tracks.append(clean_album_tracks(get_album_id(
            dirty_rr[i]["name"] + " " + dirty_rr[i]['artists'][0]['name'])))
    return potential_rr_tracks

# %%
#new tracks released that the classifier will be run on
prr = potential_release_radar()

# %%
prr_clean = []
for i in prr:
    prr_clean = prr_clean + i
for i in prr_clean:
    if i in new_library:
        prr_clean.remove(i)
prr_clean
# Out:
# ['Make It Rain - Pop Smoke',
#  'Intro - Chloe x Halle',
#  'Forgive Me - Chloe x Halle',
#  'Baby Girl - Chloe x Halle',
#  'Do It - Chloe x Halle',
#  'Tipsy - Chloe x Halle',
#  'Ungodly Hour - Chloe x Halle',
#  'Busy Boy - Chloe x Halle',
#  'Catch Up (feat. Mike WiLL Made-It) - Chloe x Halle',
#  'Overwhelmed - Chloe x Halle',
#  'Lonely - Chloe x Halle',
#  "Don't Make It Harder On Me - Chloe x Halle",
#  'Wonder What She Thinks of Me - Chloe x Halle',
#  'ROYL - Chloe x Halle',
#  'GIRL - Maren Morris',
#  'The Feels - Maren Morris',
#  'All My Favorite People (feat. Brothers Osborne) - Maren Morris',
#  'A Song for Everything - Maren Morris',
#  'Common (feat. Brandi Carlile) - Maren Morris',
#  'Flavor - Maren Morris',
#  'Make Out With Me - Maren Morris',
#  'Gold Love - Maren Morris',
#  'Great Ones - Maren Morris',
#  'RSVP - Maren Morris',
#  'To Hell & Back - Maren Morris',
#  'The Bones - Maren Morris',
#  'Good Woman - Maren Morris',
#  'Shade - Maren Morris',
#  'Just for Now - Maren Morris',
#  'Takes Two - Maren Morris',
#  'Paradise - iann dior',
#  'Pretty Girls - iann dior',
#  'Sickness - iann dior',
#  'Psycho - iann dior',
#  'Sick and Tired (ft. Machine Gun Kelly and Travis Barker) - iann dior',
#  'Runaway Kid - iann dior',
#  'Good Day - iann dior',
#  'Never Lonely (feat. Jozzy) [from Insecure: Music From The HBO Original Series, Season 4] - Yung Baby Tate',
#  'Eat Itself (from Insecure: Music From The HBO Original Series, Season 4) - Jucee Froot',
#  'Look At Me (feat. Kay Dinero) [from Insecure: Music From The HBO Original Series, Season 4] - Poe Leos',
#  'Dirty (from Insecure: Music From The HBO Original Series, Season 4) - Rico Nasty',
#  'Feng Shui (from Insecure: Music From The HBO Original Series, Season 4) - Jidenna',
#  "The Love That I'm Giving (feat. Kent Jamz) [from Insecure: Music From The HBO Original Series, Season 4] - Iman Omari",
#  'Infrastructure (from Insecure: Music From The HBO Original Series, Season 4) - St. Panther',
#  'Reaching (feat. Alex Isley) [from Insecure: Music From The HBO Original Series, Season 4] - Cautious Clay',
#  'Rewind (from Insecure: Music From The HBO Original Series, Season 4) - Ravyn Lenae',
#  'Do Me Like That (feat. Buddy) [from Insecure: Music From The HBO Original Series, Season 4] - Yung Baby Tate',
#  'Temperature (from Insecure: Music From The HBO Original Series, Season 4) - TeaMarrr',
#  'Element (from Insecure: Music From The HBO Original Series, Season 4) - PJ',
#  'Cadillac Drive (feat. Price) [from Insecure: Music From The HBO Original Series, Season 4] - Pink Sweat$',
#  'Velvet (Remix) [feat. Lucky Daye] [from Insecure: Music From The HBO Original Series, Season 4] - KIRBY',
#  'Show You (Remix) [feat. Q] [from Insecure: Music From The HBO Original Series, Season 4] - Baby Rose',
#  "If It's Good (from Insecure: Music From The HBO Original Series, Season 4) - Raphael Saadiq",
#  'Bad Decisions (from Insecure: Music From The HBO Original Series, Season 4) - Buddy',
#  'Caramelo - Ozuna',
#  'Learn To Fly - Surfaces',
#  'I Remember Everything - John Prine',
#  'Build Me A Daddy - Luke Bryan',
#  'MENTE (with Tainy & Mau y Ricky) - Dylan Fuentes',
#  'Sweeter (feat. Terrace Martin) - Leon Bridges',
#  'Trenchtown Rock - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'Rebel Music (3 O’Clock Roadblock) - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  "Burnin' And Lootin' - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers",
#  'Them Belly Full (But We Hungry) - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'The Heathen - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'I Shot The Sheriff - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'War / No More Trouble - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'Crazy Baldhead / Running Away - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'No Woman, No Cry - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'Lively Up Yourself - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  "Jammin' - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers",
#  'Get Up, Stand Up - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'Exodus - Live At The Rainbow Theatre, London / 1977 - Bob Marley & The Wailers',
#  'GO (feat. Juice WRLD) - The Kid LAROI',
#  'Pretty Girl hi! - UMI',
#  'Zeppelin - Mixed - Michael Cassette',
#  'Meet Me In Montauk - Mixed - Signalrunners',
#  'Not A Lot Left - Mixed - Myon',
#  'Fake Awake - Ecomix (Mixed) - Andy Moor',
#  'Elf - 2001 Returning Mix (Mixed) - Bart Claessen',
#  'These Shoulders - Club Mix (Mixed) - Signalrunners',
#  'Larry Mountains 54 - Mixed - David West',
#  'Illumina - Mixed - Maor Levi',
#  'Welsh Morphology - Mixed - David West',
#  'Kiksu - Mixed - Kyau & Albert',
#  'World On Fire - 12 Inch Mix (Mixed) - Above & Beyond',
#  'Shapes - Oliver Smith Remix (Mixed) - Maor Levi',
#  'Zeppelin - Edit - Michael Cassette',
#  'Meet Me In Montauk - Edit - Signalrunners',
#  'Not A Lot Left - Edit - Myon',
#  'Fake Awake - Ecomix (Edit) - Andy Moor',
#  'Elf - 2001 Returning Mix (Edit) - Bart Claessen',
#  'These Shoulders - Club Mix (Edit) - Signalrunners',
#  'Larry Mountains 54 - Edit - David West',
#  'Illumina - Edit - Maor Levi',
#  'Black 2 - Buddy',
#  'Vuelve - ChocQuibTown',
#  'No Vuelvas a Mí - ChocQuibTown',
#  'Fresa - ChocQuibTown',
#  'Amor Tóxico - ChocQuibTown',
#  'Pa Olvidarte - ChocQuibTown',
#  'Que Me Baile - ChocQuibTown',
#  'Lo Que Quieras Tú - ChocQuibTown',
#  'Quisiera - ChocQuibTown',
#  'No Hay Nadie Más - ChocQuibTown',
#  'Humano - ChocQuibTown',
#  'Pa Olvidarte (feat. Manuel Turizo) - Remix - ChocQuibTown',
#  'SUPREMACY - FEVER 333']

# %%
#now before I get features I will group together all possible recommendations and put them in a new list
new_and_artist_recs = set(list(final_pot_recs) + prr_clean)

# %%
#get audio features and dump all this in a dictionary
potential_recs_songdata_dict = {}
for i in new_and_artist_recs:
    rqery = spotify.search(make_query(i), search_type = "track")
    try:
        songid = rqery['tracks']['items'][0]['id']
        audio_data = spotify.get_audio_data(songid)
        potential_recs_songdata_dict[i] = audio_data
    except:
        audio_data = {}

# %%
#remove missing data
missing_keys = []
for k, v in potential_recs_songdata_dict.items():
    if v == {}:
        missing_keys.append(k)
missing_keys

for k in missing_keys:
    del potential_recs_songdata_dict[k]

for k, v in potential_recs_songdata_dict.items():
    print(v['valence'])
# Out:
# 0.396
# 0.672
# 0.705
# 0.0562
# 0.533
# 0.369
# 0.274
# 0.238
# 0.512
# 0.156
# 0.26
# 0.909
# 0.231
# 0.125
# 0.503
# 0.701
# 0.0399
# 0.477
# 0.321
# 0.0773
# 0.606
# 0.569
# 0.917
# 0.411
# 0.73
# 0.733
# 0.793
# 0.686
# 0.696
# 0.201
# 0.592
# 0.216
# 0.43
# 0.819
# 0.577
# 0.307
# 0.716
# 0.38
# 0.543
# 0.736
# 0.459
# 0.348
# 0.646
# 0.4
# 0.12
# 0.555
# 0.584
# 0.195
# 0.13
# 0.472
# 0.298
# 0.512
# 0.417
# 0.561
# 0.16
# 0.55
# 0.548
# 0.295
# 0.479
# 0.699
# 0.438
# 0.718
# 0.603
# 0.591
# 0.396
# 0.391
# 0.621
# 0.4
# 0.594
# 0.481
# 0.226
# 0.13
# 0.67
# 0.35
# 0.457
# 0.765
# 0.472
# 0.503
# 0.615
# 0.435
# 0.101
# 0.326
# 0.392
# 0.668
# 0.695
# 0.12
# 0.0363
# 0.801
# 0.759
# 0.686
# 0.574
# 0.273
# 0.418
# 0.613
# 0.662
# 0.6
# 0.5
# 0.794
# 0.548
# 0.515
# 0.333
# 0.718
# 0.709
# 0.528
# 0.771
# 0.494
# 0.559
# 0.164
# 0.191
# 0.634
# 0.417
# 0.36
# 0.208
# 0.195
# 0.338
# 0.245
# 0.078
# 0.264
# 0.191
# 0.62
# 0.437
# 0.805
# 0.67
# 0.697
# 0.674
# 0.69
# 0.661
# 0.339
# 0.289
# 0.0405
# 0.241
# 0.494
# 0.398
# 0.786
# 0.37
# 0.504
# 0.257
# 0.505
# 0.375
# 0.604
# 0.311
# 0.728
# 0.556
# 0.547
# 0.656
# 0.333
# 0.45
# 0.72
# 0.756
# 0.617
# 0.193
# 0.264
# 0.771
# 0.427
# 0.397
# 0.919
# 0.577
# 0.356
# 0.0815
# 0.333
# 0.811
# 0.363
# 0.878
# 0.475
# 0.659
# 0.758
# 0.34
# 0.588
# 0.254
# 0.486
# 0.253
# 0.483
# 0.123
# 0.8
# 0.814
# 0.532
# 0.182
# 0.33
# 0.428
# 0.2
# 0.642
# 0.811
# 0.754
# 0.331
# 0.749
# 0.207
# 0.445
# 0.472
# 0.214
# 0.585
# 0.539
# 0.604
# 0.687
# 0.275
# 0.535
# 0.281
# 0.597
# 0.622
# 0.325
# 0.101
# 0.447
# 0.544
# 0.44
# 0.528
# 0.626
# 0.928
# 0.59
# 0.345
# 0.613
# 0.17
# 0.268
# 0.452
# 0.261
# 0.54
# 0.674
# 0.685
# 0.698
# 0.404
# 0.381
# 0.637
# 0.503
# 0.767
# 0.797
# 0.394
# 0.511
# 0.256
# 0.278
# 0.447
# 0.156
# 0.34
# 0.554
# 0.347
# 0.188
# 0.549
# 0.808
# 0.899
# 0.382
# 0.353
# 0.227
# 0.716
# 0.463
# 0.865
# 0.233
# 0.392
# 0.495
# 0.472
# 0.305
# 0.294
# 0.642
# 0.724
# 0.394
# 0.902
# 0.194
# 0.443
# 0.598
# 0.683
# 0.358
# 0.504
# 0.628
# 0.0567
# 0.495
# 0.683
# 0.393
# 0.273
# 0.473
# 0.27
# 0.457
# 0.676
# 0.238
# 0.272
# 0.961
# 0.289
# 0.101
# 0.403
# 0.307
# 0.815
# 0.257
# 0.73
# 0.495
# 0.677
# 0.391
# 0.506
# 0.375
# 0.597
# 0.315
# 0.63
# 0.9
# 0.455
# 0.354
# 0.431
# 0.164
# 0.608
# 0.206
# 0.0795
# 0.717
# 0.639
# 0.27
# 0.588
# 0.698
# 0.482
# 0.383
# 0.351
# 0.273
# 0.431
# 0.52
# 0.508
# 0.356
# 0.446
# 0.219
# 0.486
# 0.265
# 0.377
# 0.704
# 0.629
# 0.374
# 0.403
# 0.782
# 0.0875
# 0.668
# 0.88
# 0.291
# 0.755
# 0.228
# 0.377
# 0.578
# 0.744
# 0.591
# 0.355
# 0.573
# 0.856
# 0.503
# 0.337
# 0.487
# 0.669
# 0.212
# 0.653
# 0.305
# 0.866
# 0.538
# 0.217
# 0.0873
# 0.312
# 0.52
# 0.749
# 0.815
# 0.805
# 0.844
# 0.355
# 0.0859
# 0.392
# 0.273
# 0.591
# 0.475
# 0.712
# 0.539
# 0.326
# 0.37
# 0.187
# 0.826
# 0.13
# 0.326
# 0.71
# 0.345
# 0.0872
# 0.58
# 0.159
# 0.541
# 0.35
# 0.418
# 0.718
# 0.495
# 0.361
# 0.413
# 0.373
# 0.497
# 0.856
# 0.389
# 0.511
# 0.156
# 0.365
# 0.596
# 0.372
# 0.534
# 0.0978
# 0.46
# 0.283
# 0.391
# 0.321
# 0.706
# 0.321
# 0.65
# 0.244
# 0.469
# 0.414
# 0.692
# 0.431
# 0.798
# 0.746
# 0.329
# 0.405
# 0.383
# 0.62
# 0.15
# 0.612
# 0.291
# 0.477
# 0.343
# 0.573
# 0.318
# 0.0763
# 0.727
# 0.711
# 0.278
# 0.294
# 0.728
# 0.553
# 0.516
# 0.648
# 0.354
# 0.709
# 0.4
# 0.408
# 0.416
# 0.733
# 0.546
# 0.27
# 0.314
# 0.374
# 0.55
# 0.562
# 0.0397
# 0.832
# 0.402
# 0.554
# 0.196
# 0.89
# 0.588
# 0.452
# 0.435
# 0.283
# 0.493
# 0.379
# 0.2
# 0.304
# 0.255
# 0.428
# 0.599
# 0.48
# 0.473
# 0.309
# 0.295
# 0.289
# 0.234
# 0.873
# 0.265
# 0.764
# 0.808
# 0.543
# 0.235
# 0.326
# 0.161
# 0.649
# 0.518
# 0.504
# 0.316
# 0.526
# 0.223
# 0.299
# 0.306
# 0.34
# 0.249
# 0.247
# 0.637
# 0.434
# 0.571
# 0.319
# 0.798
# 0.25
# 0.872
# 0.845
# 0.553
# 0.712
# 0.618
# 0.449
# 0.606
# 0.645
# 0.77
# 0.486
# 0.249
# 0.65
# 0.316
# 0.084
# 0.312
# 0.0871
# 0.669
# 0.496
# 0.425
# 0.588
# 0.321
# 0.589
# 0.61
# 0.645
# 0.177
# 0.409
# 0.562
# 0.794
# 0.369
# 0.375
# 0.77
# 0.67
# 0.324
# 0.561
# 0.607
# 0.523
# 0.824
# 0.227
# 0.288
# 0.55
# 0.434
# 0.665
# 0.505
# 0.401
# 0.219
# 0.576
# 0.355
# 0.225
# 0.379
# 0.0735
# 0.548
# 0.511
# 0.0727
# 0.536
# 0.592
# 0.321
# 0.647
# 0.152
# 0.647
# 0.456
# 0.579
# 0.661
# 0.728
# 0.446
# 0.574
# 0.389
# 0.299
# 0.456
# 0.327
# 0.17
# 0.223
# 0.137
# 0.35
# 0.736
# 0.346
# 0.676
# 0.23
# 0.752
# 0.442
# 0.393
# 0.319
# 0.322
# 0.158
# 0.566
# 0.578
# 0.335
# 0.346
# 0.407
# 0.364
# 0.356
# 0.836
# 0.175
# 0.796
# 0.721
# 0.536
# 0.396
# 0.584
# 0.278
# 0.458
# 0.55
# 0.374
# 0.7
# 0.0391
# 0.493
# 0.27
# 0.604
# 0.594
# 0.355
# 0.392
# 0.479
# 0.408
# 0.0614
# 0.692
# 0.59
# 0.735
# 0.346
# 0.42
# 0.273
# 0.595
# 0.856
# 0.448
# 0.435
# 0.74
# 0.482
# 0.0443
# 0.903
# 0.775
# 0.303
# 0.0862
# 0.156
# 0.508
# 0.52
# 0.595
# 0.83
# 0.322
# 0.353
# 0.437
# 0.905
# 0.324
# 0.219
# 0.286
# 0.718
# 0.399
# 0.475
# 0.341
# 0.738
# 0.54
# 0.636
# 0.452
# 0.452
# 0.418
# 0.126
# 0.418
# 0.618
# 0.74
# 0.508
# 0.502
# 0.12
# 0.163
# 0.524
# 0.663
# 0.362
# 0.335
# 0.343
# 0.033
# 0.443
# 0.426
# 0.189
# 0.441
# 0.497
# 0.688
# 0.269
# 0.284
# 0.483
# 0.34
# 0.835
# 0.779
# 0.315
# 0.727
# 0.469
# 0.49
# 0.337
# 0.784
# 0.29
# 0.67
# 0.423
# 0.427
# 0.351
# 0.547
# 0.594
# 0.542
# 0.321
# 0.649
# 0.568
# 0.505
# 0.588
# 0.572
# 0.523
# 0.138
# 0.287
# 0.34
# 0.322
# 0.667
# 0.712
# 0.225
# 0.405
# 0.236
# 0.107
# 0.71
# 0.415
# 0.613
# 0.422
# 0.787
# 0.692
# 0.566
# 0.309
# 0.54
# 0.652
# 0.562
# 0.415
# 0.243
# 0.228
# 0.489
# 0.887
# 0.326
# 0.411
# 0.595
# 0.652
# 0.417
# 0.571
# 0.367
# 0.326
# 0.605
# 0.442
# 0.676
# 0.552
# 0.123
# 0.507
# 0.437
# 0.315
# 0.545
# 0.591
# 0.47
# 0.712
# 0.451
# 0.684
# 0.71
# 0.489
# 0.699
# 0.477
# 0.352
# 0.349
# 0.632
# 0.377
# 0.314
# 0.17
# 0.443
# 0.533
# 0.535
# 0.153
# 0.304
# 0.542
# 0.828
# 0.324
# 0.138
# 0.664
# 0.233
# 0.401
# 0.676
# 0.0338
# 0.509
# 0.131
# 0.565
# 0.427
# 0.122
# 0.513
# 0.302
# 0.504
# 0.448
# 0.144
# 0.123
# 0.351
# 0.522
# 0.521
# 0.564
# 0.175
# 0.645
# 0.27
# 0.205
# 0.519
# 0.579
# 0.583
# 0.69
# 0.0397
# 0.483
# 0.602
# 0.631
# 0.601
# 0.479
# 0.43
# 0.668
# 0.408
# 0.55
# 0.353

# %%
#adds song and artist as a key for easier queries in Mongo
for k, v in songdata_dict.items():
    v["Track"] = k
songdata_dict
# Out:
# {'Shameless - iann dior': {'Track': 'Shameless - iann dior',
#   'acousticness': 0.186,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VZFXDtx8NnXWeJHOMzEan',
#   'danceability': 0.709,
#   'duration_ms': 106012,
#   'energy': 0.76,
#   'id': '4VZFXDtx8NnXWeJHOMzEan',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.164,
#   'loudness': -7.583,
#   'mode': 1,
#   'speechiness': 0.148,
#   'tempo': 81.495,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4VZFXDtx8NnXWeJHOMzEan',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4VZFXDtx8NnXWeJHOMzEan',
#   'valence': 0.709},
#  'Cinderella Story - A Boogie Wit da Hoodie': {'Track': 'Cinderella Story - A Boogie Wit da Hoodie',
#   'acousticness': 0.272,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18AIesWCXvIbXu8RqQw1E1',
#   'danceability': 0.639,
#   'duration_ms': 185455,
#   'energy': 0.571,
#   'id': '18AIesWCXvIbXu8RqQw1E1',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.144,
#   'loudness': -7.332,
#   'mode': 1,
#   'speechiness': 0.511,
#   'tempo': 88.047,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/18AIesWCXvIbXu8RqQw1E1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:18AIesWCXvIbXu8RqQw1E1',
#   'valence': 0.569},
#  'Gummy - Loud Luxury': {'Track': 'Gummy - Loud Luxury',
#   'acousticness': 0.0159,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7rWUy2a3j1QmvkcQfI3tPY',
#   'danceability': 0.803,
#   'duration_ms': 179688,
#   'energy': 0.785,
#   'id': '7rWUy2a3j1QmvkcQfI3tPY',
#   'instrumentalness': 2.82e-05,
#   'key': 0,
#   'liveness': 0.112,
#   'loudness': -5.481,
#   'mode': 0,
#   'speechiness': 0.0397,
#   'tempo': 118.985,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7rWUy2a3j1QmvkcQfI3tPY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7rWUy2a3j1QmvkcQfI3tPY',
#   'valence': 0.567},
#  'Relationship (feat. Future) - Young Thug': {'Track': 'Relationship (feat. Future) - Young Thug',
#   'acousticness': 0.00252,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25oOaleife6E2MIKmFkPvg',
#   'danceability': 0.842,
#   'duration_ms': 215307,
#   'energy': 0.597,
#   'id': '25oOaleife6E2MIKmFkPvg',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.124,
#   'loudness': -6.336,
#   'mode': 1,
#   'speechiness': 0.0627,
#   'tempo': 145.992,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/25oOaleife6E2MIKmFkPvg',
#   'type': 'audio_features',
#   'uri': 'spotify:track:25oOaleife6E2MIKmFkPvg',
#   'valence': 0.298},
#  'Close Friends (Lil Baby & Gunna) - Lil Baby': {'Track': 'Close Friends (Lil Baby & Gunna) - Lil Baby',
#   'acousticness': 0.0509,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nzhL67GpF9szXWg5y509A',
#   'danceability': 0.676,
#   'duration_ms': 203881,
#   'energy': 0.578,
#   'id': '5nzhL67GpF9szXWg5y509A',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.0796,
#   'loudness': -4.669,
#   'mode': 0,
#   'speechiness': 0.375,
#   'tempo': 158.896,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5nzhL67GpF9szXWg5y509A',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5nzhL67GpF9szXWg5y509A',
#   'valence': 0.698},
#  'GO (feat. Juice WRLD) - The Kid LAROI': {'Track': 'GO (feat. Juice WRLD) - The Kid LAROI',
#   'acousticness': 0.185,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2t7D3y0jvYjR8IP9Bosyew',
#   'danceability': 0.544,
#   'duration_ms': 183947,
#   'energy': 0.744,
#   'id': '2t7D3y0jvYjR8IP9Bosyew',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.336,
#   'loudness': -5.007,
#   'mode': 1,
#   'speechiness': 0.0889,
#   'tempo': 73.699,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2t7D3y0jvYjR8IP9Bosyew',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2t7D3y0jvYjR8IP9Bosyew',
#   'valence': 0.572},
#  'Addison Rae - The Kid LAROI': {'Track': 'Addison Rae - The Kid LAROI',
#   'acousticness': 0.0155,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ImaJZH7XqxrzbQZpYDmol',
#   'danceability': 0.901,
#   'duration_ms': 163574,
#   'energy': 0.49,
#   'id': '2ImaJZH7XqxrzbQZpYDmol',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.109,
#   'loudness': -9.099,
#   'mode': 0,
#   'speechiness': 0.129,
#   'tempo': 135.015,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ImaJZH7XqxrzbQZpYDmol',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ImaJZH7XqxrzbQZpYDmol',
#   'valence': 0.397},
#  'Trap - Rompasso Remix - SAINt JHN': {'Track': 'Trap - Rompasso Remix - SAINt JHN',
#   'acousticness': 0.0225,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GfdYJsR3ZZuNBVH9l2nHj',
#   'danceability': 0.694,
#   'duration_ms': 168750,
#   'energy': 0.739,
#   'id': '5GfdYJsR3ZZuNBVH9l2nHj',
#   'instrumentalness': 9.11e-06,
#   'key': 5,
#   'liveness': 0.507,
#   'loudness': -5.457,
#   'mode': 1,
#   'speechiness': 0.185,
#   'tempo': 128.049,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5GfdYJsR3ZZuNBVH9l2nHj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5GfdYJsR3ZZuNBVH9l2nHj',
#   'valence': 0.222},
#  'VALENTINO - Imanbek Remix - 24kGoldn': {'Track': 'VALENTINO - Imanbek Remix - 24kGoldn',
#   'acousticness': 0.0161,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/660BgHpKo1jhR9MMSFn7CF',
#   'danceability': 0.791,
#   'duration_ms': 177975,
#   'energy': 0.795,
#   'id': '660BgHpKo1jhR9MMSFn7CF',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.362,
#   'loudness': -4.854,
#   'mode': 1,
#   'speechiness': 0.0415,
#   'tempo': 124.007,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/660BgHpKo1jhR9MMSFn7CF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:660BgHpKo1jhR9MMSFn7CF',
#   'valence': 0.963},
#  'The Bigger Picture - Lil Baby': {'Track': 'The Bigger Picture - Lil Baby',
#   'acousticness': 0.0127,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44gRhRi2OhEf7moAUj6MD1',
#   'danceability': 0.59,
#   'duration_ms': 252729,
#   'energy': 0.618,
#   'id': '44gRhRi2OhEf7moAUj6MD1',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.244,
#   'loudness': -5.756,
#   'mode': 1,
#   'speechiness': 0.334,
#   'tempo': 96.459,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/44gRhRi2OhEf7moAUj6MD1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:44gRhRi2OhEf7moAUj6MD1',
#   'valence': 0.153},
#  'Lalala - Ilkan Gunuc Remix - Y2K': {'Track': 'Lalala - Ilkan Gunuc Remix - Y2K',
#   'acousticness': 0.0701,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1D9kLvE4SBX6EOG8uJa7Vy',
#   'danceability': 0.774,
#   'duration_ms': 178408,
#   'energy': 0.831,
#   'id': '1D9kLvE4SBX6EOG8uJa7Vy',
#   'instrumentalness': 2.21e-06,
#   'key': 8,
#   'liveness': 0.0825,
#   'loudness': -4.672,
#   'mode': 1,
#   'speechiness': 0.0514,
#   'tempo': 124.035,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1D9kLvE4SBX6EOG8uJa7Vy',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1D9kLvE4SBX6EOG8uJa7Vy',
#   'valence': 0.333},
#  'Otherside Of America - Meek Mill': {'Track': 'Otherside Of America - Meek Mill',
#   'acousticness': 0.0878,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JBvJ9PwrYA1oeUzI3FMRI',
#   'danceability': 0.73,
#   'duration_ms': 218103,
#   'energy': 0.772,
#   'id': '3JBvJ9PwrYA1oeUzI3FMRI',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.401,
#   'loudness': -3.883,
#   'mode': 0,
#   'speechiness': 0.316,
#   'tempo': 147.053,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3JBvJ9PwrYA1oeUzI3FMRI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3JBvJ9PwrYA1oeUzI3FMRI',
#   'valence': 0.403},
#  'Alien - Dennis Lloyd': {'Track': 'Alien - Dennis Lloyd',
#   'acousticness': 0.00813,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Tqshmc0rnQPaIGJfRp2Da',
#   'danceability': 0.71,
#   'duration_ms': 138639,
#   'energy': 0.768,
#   'id': '1Tqshmc0rnQPaIGJfRp2Da',
#   'instrumentalness': 3.66e-05,
#   'key': 0,
#   'liveness': 0.0791,
#   'loudness': -4.772,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'tempo': 118.085,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1Tqshmc0rnQPaIGJfRp2Da',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1Tqshmc0rnQPaIGJfRp2Da',
#   'valence': 0.419},
#  'Tomorrow (feat. 433) - Tiësto': {'Track': 'Tomorrow (feat. 433) - Tiësto',
#   'acousticness': 0.00607,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0uH5ORp6Ai5PP0SUofxoc7',
#   'danceability': 0.661,
#   'duration_ms': 165000,
#   'energy': 0.942,
#   'id': '0uH5ORp6Ai5PP0SUofxoc7',
#   'instrumentalness': 0.44,
#   'key': 10,
#   'liveness': 0.0778,
#   'loudness': -3.75,
#   'mode': 0,
#   'speechiness': 0.282,
#   'tempo': 127.947,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0uH5ORp6Ai5PP0SUofxoc7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0uH5ORp6Ai5PP0SUofxoc7',
#   'valence': 0.203},
#  'You & I (feat. Tyler Sjöström & Bertrand Lacoste) - VINIL Remix - Sterkøl': {'Track': 'You & I (feat. Tyler Sjöström & Bertrand Lacoste) - VINIL Remix - Sterkøl',
#   'acousticness': 0.156,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Xd66AmcJ4bjRJYOAAliMS',
#   'danceability': 0.578,
#   'duration_ms': 219193,
#   'energy': 0.801,
#   'id': '1Xd66AmcJ4bjRJYOAAliMS',
#   'instrumentalness': 0.0013,
#   'key': 5,
#   'liveness': 0.146,
#   'loudness': -4.412,
#   'mode': 1,
#   'speechiness': 0.099,
#   'tempo': 115.055,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1Xd66AmcJ4bjRJYOAAliMS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1Xd66AmcJ4bjRJYOAAliMS',
#   'valence': 0.373},
#  'Paris - Cevith': {'Track': 'Paris - Cevith',
#   'acousticness': 0.00643,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1sevsHttEKM5eQdpibYbUA',
#   'danceability': 0.692,
#   'duration_ms': 179032,
#   'energy': 0.788,
#   'id': '1sevsHttEKM5eQdpibYbUA',
#   'instrumentalness': 0.00293,
#   'key': 9,
#   'liveness': 0.227,
#   'loudness': -7.077,
#   'mode': 0,
#   'speechiness': 0.0477,
#   'tempo': 124.04,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1sevsHttEKM5eQdpibYbUA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1sevsHttEKM5eQdpibYbUA',
#   'valence': 0.637},
#  'Godzilla - Aftermath': {'Track': 'Godzilla - Aftermath',
#   'acousticness': 0.0714,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0eyyjiGgRWpDJqq3HCuexl',
#   'danceability': 0.705,
#   'duration_ms': 194199,
#   'energy': 0.862,
#   'id': '0eyyjiGgRWpDJqq3HCuexl',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.875,
#   'loudness': -5.671,
#   'mode': 0,
#   'speechiness': 0.385,
#   'tempo': 124.043,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0eyyjiGgRWpDJqq3HCuexl',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0eyyjiGgRWpDJqq3HCuexl',
#   'valence': 0.579},
#  'Keeps Me High (WHOCARES Remix) - HADES': {'Track': 'Keeps Me High (WHOCARES Remix) - HADES',
#   'acousticness': 0.0279,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18ktwdSdzDaW7gt6KPgrwW',
#   'danceability': 0.715,
#   'duration_ms': 158095,
#   'energy': 0.951,
#   'id': '18ktwdSdzDaW7gt6KPgrwW',
#   'instrumentalness': 0.0107,
#   'key': 8,
#   'liveness': 0.071,
#   'loudness': -3.337,
#   'mode': 1,
#   'speechiness': 0.0624,
#   'tempo': 126.012,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/18ktwdSdzDaW7gt6KPgrwW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:18ktwdSdzDaW7gt6KPgrwW',
#   'valence': 0.525},
#  'I Love My Friends (And My Friends Love Me) - Steve Aoki': {'Track': 'I Love My Friends (And My Friends Love Me) - Steve Aoki',
#   'acousticness': 0.112,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2GiQyNKidWwzHkgDs03dwN',
#   'danceability': 0.757,
#   'duration_ms': 181428,
#   'energy': 0.927,
#   'id': '2GiQyNKidWwzHkgDs03dwN',
#   'instrumentalness': 1.53e-05,
#   'key': 4,
#   'liveness': 0.507,
#   'loudness': -3.462,
#   'mode': 1,
#   'speechiness': 0.088,
#   'tempo': 124.056,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2GiQyNKidWwzHkgDs03dwN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2GiQyNKidWwzHkgDs03dwN',
#   'valence': 0.758},
#  'Tinted Eyes (feat. blackbear & 24kGoldn) - DVBBS': {'Track': 'Tinted Eyes (feat. blackbear & 24kGoldn) - DVBBS',
#   'acousticness': 0.00598,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/68UW3plyDDNg1dkNIZRezJ',
#   'danceability': 0.743,
#   'duration_ms': 175082,
#   'energy': 0.801,
#   'id': '68UW3plyDDNg1dkNIZRezJ',
#   'instrumentalness': 2.46e-05,
#   'key': 5,
#   'liveness': 0.178,
#   'loudness': -4.097,
#   'mode': 0,
#   'speechiness': 0.0343,
#   'tempo': 121.965,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/68UW3plyDDNg1dkNIZRezJ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:68UW3plyDDNg1dkNIZRezJ',
#   'valence': 0.381},
#  'Kiss Me Hard - DJ Antoine vs Mad Mark 2k20 Mix - DJ Antoine': {'Track': 'Kiss Me Hard - DJ Antoine vs Mad Mark 2k20 Mix - DJ Antoine',
#   'acousticness': 0.0755,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0b59Hg9erJyJeCgX2d8xSt',
#   'danceability': 0.728,
#   'duration_ms': 158247,
#   'energy': 0.827,
#   'id': '0b59Hg9erJyJeCgX2d8xSt',
#   'instrumentalness': 9.87e-05,
#   'key': 0,
#   'liveness': 0.0908,
#   'loudness': -5.526,
#   'mode': 0,
#   'speechiness': 0.0562,
#   'tempo': 124.957,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0b59Hg9erJyJeCgX2d8xSt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0b59Hg9erJyJeCgX2d8xSt',
#   'valence': 0.786},
#  'Best Friend (feat. Tory Lanez) - A Boogie Wit da Hoodie': {'Track': 'Best Friend (feat. Tory Lanez) - A Boogie Wit da Hoodie',
#   'acousticness': 0.211,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7GNKDhpJtw7G7nodKz4NOH',
#   'danceability': 0.839,
#   'duration_ms': 260497,
#   'energy': 0.525,
#   'id': '7GNKDhpJtw7G7nodKz4NOH',
#   'instrumentalness': 0.000153,
#   'key': 9,
#   'liveness': 0.0701,
#   'loudness': -7.446,
#   'mode': 0,
#   'speechiness': 0.35,
#   'tempo': 149.863,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7GNKDhpJtw7G7nodKz4NOH',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7GNKDhpJtw7G7nodKz4NOH',
#   'valence': 0.541},
#  "F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar) - A$AP Rocky": {'Track': "F**kin' Problems (feat. Drake, 2 Chainz & Kendrick Lamar) - A$AP Rocky"},
#  'Antisocial (with Travis Scott) - Ed Sheeran': {'Track': 'Antisocial (with Travis Scott) - Ed Sheeran',
#   'acousticness': 0.133,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DhRbox3xkceP64k3JeYfW',
#   'danceability': 0.715,
#   'duration_ms': 161747,
#   'energy': 0.823,
#   'id': '1DhRbox3xkceP64k3JeYfW',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.361,
#   'loudness': -5.313,
#   'mode': 0,
#   'speechiness': 0.0495,
#   'tempo': 151.956,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1DhRbox3xkceP64k3JeYfW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1DhRbox3xkceP64k3JeYfW',
#   'valence': 0.91},
#  'Who Needs Love - Trippie Redd': {'Track': 'Who Needs Love - Trippie Redd',
#   'acousticness': 0.763,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ktxr00GpTtbMNeBjNeY8D',
#   'danceability': 0.85,
#   'duration_ms': 158532,
#   'energy': 0.516,
#   'id': '2ktxr00GpTtbMNeBjNeY8D',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0896,
#   'loudness': -7.664,
#   'mode': 0,
#   'speechiness': 0.0714,
#   'tempo': 108.963,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ktxr00GpTtbMNeBjNeY8D',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ktxr00GpTtbMNeBjNeY8D',
#   'valence': 0.874},
#  'Weak When Ur Around - blackbear': {'Track': 'Weak When Ur Around - blackbear',
#   'acousticness': 0.678,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UWkbO4emEOu9YUeOGq3vU',
#   'danceability': 0.769,
#   'duration_ms': 169500,
#   'energy': 0.323,
#   'id': '3UWkbO4emEOu9YUeOGq3vU',
#   'instrumentalness': 0,
#   'key': 3,
#   'liveness': 0.116,
#   'loudness': -12.887,
#   'mode': 0,
#   'speechiness': 0.0524,
#   'tempo': 94.977,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3UWkbO4emEOu9YUeOGq3vU',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3UWkbO4emEOu9YUeOGq3vU',
#   'valence': 0.574},
#  'Way Too Fly (feat. DaVido) - A Boogie Wit da Hoodie': {'Track': 'Way Too Fly (feat. DaVido) - A Boogie Wit da Hoodie',
#   'acousticness': 0.125,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1NAR2XeNMp6SegDBp0NlRy',
#   'danceability': 0.602,
#   'duration_ms': 172708,
#   'energy': 0.771,
#   'id': '1NAR2XeNMp6SegDBp0NlRy',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.254,
#   'loudness': -4.799,
#   'mode': 0,
#   'speechiness': 0.261,
#   'tempo': 216.115,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1NAR2XeNMp6SegDBp0NlRy',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1NAR2XeNMp6SegDBp0NlRy',
#   'valence': 0.864},
#  'Foreigner (feat. A Boogie Wit da Hoodie) - Pop Smoke': {'Track': 'Foreigner (feat. A Boogie Wit da Hoodie) - Pop Smoke',
#   'acousticness': 0.471,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iBKCNKl5UjxfOgyxnQ6q6',
#   'danceability': 0.484,
#   'duration_ms': 161120,
#   'energy': 0.553,
#   'id': '7iBKCNKl5UjxfOgyxnQ6q6',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.276,
#   'loudness': -7.914,
#   'mode': 0,
#   'speechiness': 0.353,
#   'tempo': 103.772,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/7iBKCNKl5UjxfOgyxnQ6q6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7iBKCNKl5UjxfOgyxnQ6q6',
#   'valence': 0.598},
#  'Satisfaction (Isak Original Extended) - Benny Benassi Presents The Biz - Benny Benassi': {'Track': 'Satisfaction (Isak Original Extended) - Benny Benassi Presents The Biz - Benny Benassi',
#   'acousticness': 0.163,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1n7omixiROWs5q6xpWiQuL',
#   'danceability': 0.793,
#   'duration_ms': 285571,
#   'energy': 0.698,
#   'id': '1n7omixiROWs5q6xpWiQuL',
#   'instrumentalness': 0.145,
#   'key': 11,
#   'liveness': 0.0745,
#   'loudness': -3.626,
#   'mode': 1,
#   'speechiness': 0.104,
#   'tempo': 130.017,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1n7omixiROWs5q6xpWiQuL',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1n7omixiROWs5q6xpWiQuL',
#   'valence': 0.339},
#  'South of the Border (feat. Camila Cabello & Cardi B) - Ed Sheeran': {'Track': 'South of the Border (feat. Camila Cabello & Cardi B) - Ed Sheeran',
#   'acousticness': 0.148,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vUmTMuQqjdnvlZmAH61Qk',
#   'danceability': 0.857,
#   'duration_ms': 204467,
#   'energy': 0.621,
#   'id': '4vUmTMuQqjdnvlZmAH61Qk',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0865,
#   'loudness': -6.376,
#   'mode': 0,
#   'speechiness': 0.0824,
#   'tempo': 97.986,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4vUmTMuQqjdnvlZmAH61Qk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4vUmTMuQqjdnvlZmAH61Qk',
#   'valence': 0.668},
#  'ily (i love you baby) (feat. Emilee) - Surf Mesa': {'Track': 'ily (i love you baby) (feat. Emilee) - Surf Mesa',
#   'acousticness': 0.0686,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62aP9fBQKYKxi7PDXwcUAS',
#   'danceability': 0.674,
#   'duration_ms': 176547,
#   'energy': 0.774,
#   'id': '62aP9fBQKYKxi7PDXwcUAS',
#   'instrumentalness': 0.00188,
#   'key': 11,
#   'liveness': 0.393,
#   'loudness': -7.567,
#   'mode': 0,
#   'speechiness': 0.0892,
#   'tempo': 112.05,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/62aP9fBQKYKxi7PDXwcUAS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:62aP9fBQKYKxi7PDXwcUAS',
#   'valence': 0.33},
#  'Next Round on Me - twoloud': {'Track': 'Next Round on Me - twoloud',
#   'acousticness': 0.000866,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1GcrvqKcQ3ew9nQQHcT6tz',
#   'danceability': 0.858,
#   'duration_ms': 157117,
#   'energy': 0.707,
#   'id': '1GcrvqKcQ3ew9nQQHcT6tz',
#   'instrumentalness': 0.00117,
#   'key': 1,
#   'liveness': 0.266,
#   'loudness': -5.518,
#   'mode': 1,
#   'speechiness': 0.0491,
#   'tempo': 123.966,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1GcrvqKcQ3ew9nQQHcT6tz',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1GcrvqKcQ3ew9nQQHcT6tz',
#   'valence': 0.461},
#  'Roses Remix (feat. Future) - SAINt JHN': {'Track': 'Roses Remix (feat. Future) - SAINt JHN',
#   'acousticness': 0.0247,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1KyZ4rUiW2lkqGNLQYKpcC',
#   'danceability': 0.941,
#   'duration_ms': 187898,
#   'energy': 0.463,
#   'id': '1KyZ4rUiW2lkqGNLQYKpcC',
#   'instrumentalness': 5.53e-05,
#   'key': 8,
#   'liveness': 0.192,
#   'loudness': -5.993,
#   'mode': 1,
#   'speechiness': 0.113,
#   'tempo': 127.003,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1KyZ4rUiW2lkqGNLQYKpcC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1KyZ4rUiW2lkqGNLQYKpcC',
#   'valence': 0.312},
#  'Both Sides (feat. Lil Baby) - Gucci Mane': {'Track': 'Both Sides (feat. Lil Baby) - Gucci Mane',
#   'acousticness': 0.0084,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34xlXbZ4Ws3GGpUKeimDu5',
#   'danceability': 0.844,
#   'duration_ms': 180753,
#   'energy': 0.616,
#   'id': '34xlXbZ4Ws3GGpUKeimDu5',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.121,
#   'loudness': -5.2,
#   'mode': 1,
#   'speechiness': 0.161,
#   'tempo': 160.024,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/34xlXbZ4Ws3GGpUKeimDu5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:34xlXbZ4Ws3GGpUKeimDu5',
#   'valence': 0.188},
#  'Kalinka - Dimitri Vegas & Like Mike Edit - Timmy Trumpet': {'Track': 'Kalinka - Dimitri Vegas & Like Mike Edit - Timmy Trumpet',
#   'acousticness': 0.0065,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DByxA4MRvkBR8DPEFnrgr',
#   'danceability': 0.514,
#   'duration_ms': 160669,
#   'energy': 0.936,
#   'id': '3DByxA4MRvkBR8DPEFnrgr',
#   'instrumentalness': 0.0297,
#   'key': 1,
#   'liveness': 0.0728,
#   'loudness': -3.517,
#   'mode': 0,
#   'speechiness': 0.23,
#   'tempo': 127.914,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3DByxA4MRvkBR8DPEFnrgr',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3DByxA4MRvkBR8DPEFnrgr',
#   'valence': 0.201},
#  'A-List - Remix - Speedy': {'Track': 'A-List - Remix - Speedy',
#   'acousticness': 0.013,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/12QEaxiZzdz27r1Xz7dTHV',
#   'danceability': 0.679,
#   'duration_ms': 236000,
#   'energy': 0.72,
#   'id': '12QEaxiZzdz27r1Xz7dTHV',
#   'instrumentalness': 5.12e-06,
#   'key': 5,
#   'liveness': 0.132,
#   'loudness': -6.42,
#   'mode': 1,
#   'speechiness': 0.08,
#   'tempo': 142.067,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/12QEaxiZzdz27r1Xz7dTHV',
#   'type': 'audio_features',
#   'uri': 'spotify:track:12QEaxiZzdz27r1Xz7dTHV',
#   'valence': 0.668},
#  'goosebumps - Skylar Grey': {'Track': 'goosebumps - Skylar Grey',
#   'acousticness': 0.281,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7alhwlGsBjxMg1tlhfNSi8',
#   'danceability': 0.696,
#   'duration_ms': 266667,
#   'energy': 0.638,
#   'id': '7alhwlGsBjxMg1tlhfNSi8',
#   'instrumentalness': 8.91e-05,
#   'key': 8,
#   'liveness': 0.105,
#   'loudness': -5.211,
#   'mode': 0,
#   'speechiness': 0.119,
#   'tempo': 108.042,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7alhwlGsBjxMg1tlhfNSi8',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7alhwlGsBjxMg1tlhfNSi8',
#   'valence': 0.262},
#  'TKN (feat. Travis Scott) - ROSALÍA': {'Track': 'TKN (feat. Travis Scott) - ROSALÍA',
#   'acousticness': 0.192,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4w47S36wQGBhGg073q3nt7',
#   'danceability': 0.776,
#   'duration_ms': 129371,
#   'energy': 0.509,
#   'id': '4w47S36wQGBhGg073q3nt7',
#   'instrumentalness': 1.49e-06,
#   'key': 0,
#   'liveness': 0.115,
#   'loudness': -6.266,
#   'mode': 0,
#   'speechiness': 0.467,
#   'tempo': 94.634,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4w47S36wQGBhGg073q3nt7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4w47S36wQGBhGg073q3nt7',
#   'valence': 0.485},
#  'Oxygen - Winona Oak': {'Track': 'Oxygen - Winona Oak',
#   'acousticness': 0.162,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64ouROglsBxfd84TpVlPQZ',
#   'danceability': 0.639,
#   'duration_ms': 192080,
#   'energy': 0.601,
#   'id': '64ouROglsBxfd84TpVlPQZ',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.0791,
#   'loudness': -5.839,
#   'mode': 0,
#   'speechiness': 0.0519,
#   'tempo': 116.045,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/64ouROglsBxfd84TpVlPQZ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:64ouROglsBxfd84TpVlPQZ',
#   'valence': 0.292},
#  'Tell Me U Luv Me (with Trippie Redd) - Juice WRLD': {'Track': 'Tell Me U Luv Me (with Trippie Redd) - Juice WRLD',
#   'acousticness': 0.299,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CNcRgjGw1v9VQaTaytdnD',
#   'danceability': 0.609,
#   'duration_ms': 180129,
#   'energy': 0.757,
#   'id': '4CNcRgjGw1v9VQaTaytdnD',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.63,
#   'loudness': -5.605,
#   'mode': 1,
#   'speechiness': 0.119,
#   'tempo': 128.022,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4CNcRgjGw1v9VQaTaytdnD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4CNcRgjGw1v9VQaTaytdnD',
#   'valence': 0.379},
#  'X - Nicky Jam': {'Track': 'X - Nicky Jam',
#   'acousticness': 0.0338,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5YUyW9opqNsMSEzzecZih1',
#   'danceability': 0.594,
#   'duration_ms': 172854,
#   'energy': 0.749,
#   'id': '5YUyW9opqNsMSEzzecZih1',
#   'instrumentalness': 0.00106,
#   'key': 9,
#   'liveness': 0.3,
#   'loudness': -5.298,
#   'mode': 0,
#   'speechiness': 0.056,
#   'tempo': 179.968,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5YUyW9opqNsMSEzzecZih1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5YUyW9opqNsMSEzzecZih1',
#   'valence': 0.694},
#  'X (feat. Maluma & Ozuna) - Remix - Nicky Jam': {'Track': 'X (feat. Maluma & Ozuna) - Remix - Nicky Jam',
#   'acousticness': 0.0561,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JjPBQfI2Y8nIjnm65X6Pw',
#   'danceability': 0.663,
#   'duration_ms': 235747,
#   'energy': 0.696,
#   'id': '6JjPBQfI2Y8nIjnm65X6Pw',
#   'instrumentalness': 3.77e-05,
#   'key': 9,
#   'liveness': 0.0778,
#   'loudness': -4.957,
#   'mode': 0,
#   'speechiness': 0.103,
#   'tempo': 180.113,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6JjPBQfI2Y8nIjnm65X6Pw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6JjPBQfI2Y8nIjnm65X6Pw',
#   'valence': 0.738},
#  'Motto (feat. Lil Uzi Vert, G-Eazy & Mally Mall) - David Guetta': {'Track': 'Motto (feat. Lil Uzi Vert, G-Eazy & Mally Mall) - David Guetta',
#   'acousticness': 0.052,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LvXQDy62I5MD6JEBZcDXS',
#   'danceability': 0.742,
#   'duration_ms': 149520,
#   'energy': 0.827,
#   'id': '4LvXQDy62I5MD6JEBZcDXS',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.263,
#   'loudness': -5.067,
#   'mode': 1,
#   'speechiness': 0.0584,
#   'tempo': 85.014,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4LvXQDy62I5MD6JEBZcDXS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4LvXQDy62I5MD6JEBZcDXS',
#   'valence': 0.654},
#  'Sweet & Bitter - Kush Kush': {'Track': 'Sweet & Bitter - Kush Kush',
#   'acousticness': 0.262,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54IXM88EcHuLHkTlRHamKw',
#   'danceability': 0.776,
#   'duration_ms': 181270,
#   'energy': 0.605,
#   'id': '54IXM88EcHuLHkTlRHamKw',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0642,
#   'loudness': -5.916,
#   'mode': 1,
#   'speechiness': 0.0545,
#   'tempo': 98.966,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/54IXM88EcHuLHkTlRHamKw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:54IXM88EcHuLHkTlRHamKw',
#   'valence': 0.617},
#  'SnD - Jah Khalib': {'Track': 'SnD - Jah Khalib',
#   'acousticness': 0.375,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34ttji2fIHtqipyVsda1E5',
#   'danceability': 0.8,
#   'duration_ms': 250540,
#   'energy': 0.6,
#   'id': '34ttji2fIHtqipyVsda1E5',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.0893,
#   'loudness': -5.953,
#   'mode': 0,
#   'speechiness': 0.0475,
#   'tempo': 139.967,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/34ttji2fIHtqipyVsda1E5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:34ttji2fIHtqipyVsda1E5',
#   'valence': 0.505},
#  'Zombie (Zombic & Felix Schorn Remix) - Besomorph': {'Track': 'Zombie (Zombic & Felix Schorn Remix) - Besomorph',
#   'acousticness': 0.0158,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3p07oZZpSNdVtN93M5yIY5',
#   'danceability': 0.608,
#   'duration_ms': 160000,
#   'energy': 0.828,
#   'id': '3p07oZZpSNdVtN93M5yIY5',
#   'instrumentalness': 0.00465,
#   'key': 8,
#   'liveness': 0.247,
#   'loudness': -7.841,
#   'mode': 1,
#   'speechiness': 0.125,
#   'tempo': 125.857,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3p07oZZpSNdVtN93M5yIY5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3p07oZZpSNdVtN93M5yIY5',
#   'valence': 0.398},
#  'Down - KALUMA': {'Track': 'Down - KALUMA',
#   'acousticness': 0.0249,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0oMoHEZPRd2DnD3EErXYpG',
#   'danceability': 0.717,
#   'duration_ms': 207000,
#   'energy': 0.661,
#   'id': '0oMoHEZPRd2DnD3EErXYpG',
#   'instrumentalness': 1.56e-06,
#   'key': 11,
#   'liveness': 0.128,
#   'loudness': -7.602,
#   'mode': 0,
#   'speechiness': 0.0408,
#   'tempo': 128.051,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0oMoHEZPRd2DnD3EErXYpG',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0oMoHEZPRd2DnD3EErXYpG',
#   'valence': 0.344},
#  'Sad (feat. Afrojack) - Chico Rose': {'Track': 'Sad (feat. Afrojack) - Chico Rose',
#   'acousticness': 0.0421,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ESPuOrSsRcBISzcMlzmY5',
#   'danceability': 0.717,
#   'duration_ms': 161280,
#   'energy': 0.716,
#   'id': '4ESPuOrSsRcBISzcMlzmY5',
#   'instrumentalness': 0.000467,
#   'key': 3,
#   'liveness': 0.0699,
#   'loudness': -5.485,
#   'mode': 0,
#   'speechiness': 0.0432,
#   'tempo': 125.064,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4ESPuOrSsRcBISzcMlzmY5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4ESPuOrSsRcBISzcMlzmY5',
#   'valence': 0.206},
#  'London - DJ Antoine Vs Mad Mark 2k16 Radio Edit - DJ Antoine': {'Track': 'London - DJ Antoine Vs Mad Mark 2k16 Radio Edit - DJ Antoine',
#   'acousticness': 0.0272,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MGC8lKkD3wNdr7KjFRa3C',
#   'danceability': 0.771,
#   'duration_ms': 213432,
#   'energy': 0.841,
#   'id': '0MGC8lKkD3wNdr7KjFRa3C',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.228,
#   'loudness': -5.545,
#   'mode': 1,
#   'speechiness': 0.113,
#   'tempo': 125.979,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0MGC8lKkD3wNdr7KjFRa3C',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0MGC8lKkD3wNdr7KjFRa3C',
#   'valence': 0.856},
#  'You & I - Bru-C': {'Track': 'You & I - Bru-C',
#   'acousticness': 0.087,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PX9O7QzWYClP6PPuIaomj',
#   'danceability': 0.646,
#   'duration_ms': 264000,
#   'energy': 0.864,
#   'id': '0PX9O7QzWYClP6PPuIaomj',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0923,
#   'loudness': -3.727,
#   'mode': 1,
#   'speechiness': 0.0718,
#   'tempo': 87.419,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0PX9O7QzWYClP6PPuIaomj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0PX9O7QzWYClP6PPuIaomj',
#   'valence': 0.082},
#  'In And Out Of Love - Armin van Buuren': {'Track': 'In And Out Of Love - Armin van Buuren',
#   'acousticness': 0.067,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57nKL06bKwjaM5Y0aMtY9v',
#   'danceability': 0.528,
#   'duration_ms': 181680,
#   'energy': 0.705,
#   'id': '57nKL06bKwjaM5Y0aMtY9v',
#   'instrumentalness': 6.4e-05,
#   'key': 1,
#   'liveness': 0.125,
#   'loudness': -6.777,
#   'mode': 1,
#   'speechiness': 0.029,
#   'tempo': 134.983,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/57nKL06bKwjaM5Y0aMtY9v',
#   'type': 'audio_features',
#   'uri': 'spotify:track:57nKL06bKwjaM5Y0aMtY9v',
#   'valence': 0.418},
#  'After Hours - The Weeknd': {'Track': 'After Hours - The Weeknd',
#   'acousticness': 0.0811,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2p8IUWQDrpjuFltbdgLOag',
#   'danceability': 0.664,
#   'duration_ms': 361027,
#   'energy': 0.572,
#   'id': '2p8IUWQDrpjuFltbdgLOag',
#   'instrumentalness': 0.00604,
#   'key': 5,
#   'liveness': 0.121,
#   'loudness': -6.099,
#   'mode': 0,
#   'speechiness': 0.0305,
#   'tempo': 108.959,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2p8IUWQDrpjuFltbdgLOag',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2p8IUWQDrpjuFltbdgLOag',
#   'valence': 0.143},
#  'Need Me - J.I the Prince of N.Y': {'Track': 'Need Me - J.I the Prince of N.Y',
#   'acousticness': 0.156,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dzja72gQodveSpguIQGJl',
#   'danceability': 0.815,
#   'duration_ms': 151641,
#   'energy': 0.567,
#   'id': '2dzja72gQodveSpguIQGJl',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.0884,
#   'loudness': -4.653,
#   'mode': 0,
#   'speechiness': 0.135,
#   'tempo': 95.034,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2dzja72gQodveSpguIQGJl',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2dzja72gQodveSpguIQGJl',
#   'valence': 0.732},
#  "Nobody's Better (feat. Fetty Wap) - Z": {'Track': "Nobody's Better (feat. Fetty Wap) - Z",
#   'acousticness': 0.0134,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6XKm1z5lYIq486iWMLnSFY',
#   'danceability': 0.357,
#   'duration_ms': 209591,
#   'energy': 0.661,
#   'id': '6XKm1z5lYIq486iWMLnSFY',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.166,
#   'loudness': -7.259,
#   'mode': 0,
#   'speechiness': 0.106,
#   'tempo': 101.038,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6XKm1z5lYIq486iWMLnSFY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6XKm1z5lYIq486iWMLnSFY',
#   'valence': 0.541},
#  'Eenie Meenie - Radio Version - Sean Kingston': {'Track': 'Eenie Meenie - Radio Version - Sean Kingston',
#   'acousticness': 0.0412,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Yaw2PmyOETOnEM3TCf98I',
#   'danceability': 0.718,
#   'duration_ms': 201973,
#   'energy': 0.638,
#   'id': '4Yaw2PmyOETOnEM3TCf98I',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.169,
#   'loudness': -3.479,
#   'mode': 1,
#   'speechiness': 0.031,
#   'tempo': 121.242,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4Yaw2PmyOETOnEM3TCf98I',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4Yaw2PmyOETOnEM3TCf98I',
#   'valence': 0.835},
#  'Wake Up Dead - T-Pain': {'Track': 'Wake Up Dead - T-Pain',
#   'acousticness': 0.0787,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13KcxQJSvNbTFRB1pNf9DZ',
#   'danceability': 0.469,
#   'duration_ms': 271464,
#   'energy': 0.413,
#   'id': '13KcxQJSvNbTFRB1pNf9DZ',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.119,
#   'loudness': -7.573,
#   'mode': 0,
#   'speechiness': 0.0575,
#   'tempo': 100.959,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/13KcxQJSvNbTFRB1pNf9DZ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:13KcxQJSvNbTFRB1pNf9DZ',
#   'valence': 0.442},
#  "That's A Fact (feat. Fivio Foreign & Mr. Swipey) - Remix - French Montana": {'Track': "That's A Fact (feat. Fivio Foreign & Mr. Swipey) - Remix - French Montana",
#   'acousticness': 0.00791,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4bEqx2oD0GUgs3bICkrJ1l',
#   'danceability': 0.75,
#   'duration_ms': 244163,
#   'energy': 0.677,
#   'id': '4bEqx2oD0GUgs3bICkrJ1l',
#   'instrumentalness': 6.47e-05,
#   'key': 5,
#   'liveness': 0.292,
#   'loudness': -5.762,
#   'mode': 0,
#   'speechiness': 0.286,
#   'tempo': 150.322,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4bEqx2oD0GUgs3bICkrJ1l',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4bEqx2oD0GUgs3bICkrJ1l',
#   'valence': 0.393},
#  'Mazel Tov - IDK': {'Track': 'Mazel Tov - IDK',
#   'acousticness': 0.000467,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2q0nvnoM52HGglPqzRxD5P',
#   'danceability': 0.837,
#   'duration_ms': 140308,
#   'energy': 0.371,
#   'id': '2q0nvnoM52HGglPqzRxD5P',
#   'instrumentalness': 1.2e-05,
#   'key': 1,
#   'liveness': 0.125,
#   'loudness': -7.94,
#   'mode': 1,
#   'speechiness': 0.131,
#   'tempo': 129.994,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2q0nvnoM52HGglPqzRxD5P',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2q0nvnoM52HGglPqzRxD5P',
#   'valence': 0.228},
#  'Prospect (ft. Lil Baby) - iann dior': {'Track': 'Prospect (ft. Lil Baby) - iann dior',
#   'acousticness': 0.203,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Zjdzxx0dsavsr7Ehr8fGE',
#   'danceability': 0.816,
#   'duration_ms': 226314,
#   'energy': 0.579,
#   'id': '4Zjdzxx0dsavsr7Ehr8fGE',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.127,
#   'loudness': -6.097,
#   'mode': 1,
#   'speechiness': 0.0867,
#   'tempo': 120.078,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4Zjdzxx0dsavsr7Ehr8fGE',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4Zjdzxx0dsavsr7Ehr8fGE',
#   'valence': 0.43},
#  'Rain On Me (with Ariana Grande) - Lady Gaga': {'Track': 'Rain On Me (with Ariana Grande) - Lady Gaga',
#   'acousticness': 0.021,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24ySl2hOPGCDcxBxFIqWBu',
#   'danceability': 0.672,
#   'duration_ms': 182200,
#   'energy': 0.855,
#   'id': '24ySl2hOPGCDcxBxFIqWBu',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.323,
#   'loudness': -3.764,
#   'mode': 1,
#   'speechiness': 0.0397,
#   'tempo': 123.056,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/24ySl2hOPGCDcxBxFIqWBu',
#   'type': 'audio_features',
#   'uri': 'spotify:track:24ySl2hOPGCDcxBxFIqWBu',
#   'valence': 0.646},
#  'Hopeless Romantic (feat. Swae Lee) - Wiz Khalifa': {'Track': 'Hopeless Romantic (feat. Swae Lee) - Wiz Khalifa',
#   'acousticness': 0.307,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7IBSffWIu7P2MC7kMwy2FM',
#   'danceability': 0.877,
#   'duration_ms': 226743,
#   'energy': 0.477,
#   'id': '7IBSffWIu7P2MC7kMwy2FM',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0929,
#   'loudness': -7.379,
#   'mode': 0,
#   'speechiness': 0.0587,
#   'tempo': 127.023,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7IBSffWIu7P2MC7kMwy2FM',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7IBSffWIu7P2MC7kMwy2FM',
#   'valence': 0.552},
#  'Chicago\u202c\u202c - Vigiland': {'Track': 'Chicago\u202c\u202c - Vigiland',
#   'acousticness': 0.00362,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22eSlcMUCvdx126aiXbces',
#   'danceability': 0.961,
#   'duration_ms': 141113,
#   'energy': 0.491,
#   'id': '22eSlcMUCvdx126aiXbces',
#   'instrumentalness': 0.0159,
#   'key': 9,
#   'liveness': 0.119,
#   'loudness': -6.264,
#   'mode': 0,
#   'speechiness': 0.0644,
#   'tempo': 124.074,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/22eSlcMUCvdx126aiXbces',
#   'type': 'audio_features',
#   'uri': 'spotify:track:22eSlcMUCvdx126aiXbces',
#   'valence': 0.586},
#  'Drown (feat. Clinton Kane) - Martin Garrix': {'Track': 'Drown (feat. Clinton Kane) - Martin Garrix',
#   'acousticness': 0.212,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RVtBlHFKj51Ipvpfv5ER4',
#   'danceability': 0.573,
#   'duration_ms': 174062,
#   'energy': 0.739,
#   'id': '4RVtBlHFKj51Ipvpfv5ER4',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.175,
#   'loudness': -5.455,
#   'mode': 1,
#   'speechiness': 0.0581,
#   'tempo': 120.077,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4RVtBlHFKj51Ipvpfv5ER4',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4RVtBlHFKj51Ipvpfv5ER4',
#   'valence': 0.363},
#  'All Around The World (La La La) - Marnik Remix - R3HAB': {'Track': 'All Around The World (La La La) - Marnik Remix - R3HAB',
#   'acousticness': 0.0882,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ALOVWJZcJO70uojmNHtb6',
#   'danceability': 0.707,
#   'duration_ms': 170693,
#   'energy': 0.914,
#   'id': '6ALOVWJZcJO70uojmNHtb6',
#   'instrumentalness': 0.0833,
#   'key': 9,
#   'liveness': 0.112,
#   'loudness': -4.329,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'tempo': 135.015,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6ALOVWJZcJO70uojmNHtb6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6ALOVWJZcJO70uojmNHtb6',
#   'valence': 0.706},
#  'My Best Life (feat. Mike Waters) - Club Mix - KSHMR': {'Track': 'My Best Life (feat. Mike Waters) - Club Mix - KSHMR',
#   'acousticness': 0.018,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78XfOXpUShe7mFwhjBEd94',
#   'danceability': 0.603,
#   'duration_ms': 198533,
#   'energy': 0.921,
#   'id': '78XfOXpUShe7mFwhjBEd94',
#   'instrumentalness': 9.2e-05,
#   'key': 8,
#   'liveness': 0.183,
#   'loudness': -3.693,
#   'mode': 0,
#   'speechiness': 0.391,
#   'tempo': 120.201,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/78XfOXpUShe7mFwhjBEd94',
#   'type': 'audio_features',
#   'uri': 'spotify:track:78XfOXpUShe7mFwhjBEd94',
#   'valence': 0.675},
#  'SOS (feat. Aloe Blacc) - Avicii': {'Track': 'SOS (feat. Aloe Blacc) - Avicii',
#   'acousticness': 0.272,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2x0RZdkZcD8QRI53XT4GI5',
#   'danceability': 0.802,
#   'duration_ms': 157202,
#   'energy': 0.645,
#   'id': '2x0RZdkZcD8QRI53XT4GI5',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.119,
#   'loudness': -6.181,
#   'mode': 0,
#   'speechiness': 0.0715,
#   'tempo': 100.001,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2x0RZdkZcD8QRI53XT4GI5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2x0RZdkZcD8QRI53XT4GI5',
#   'valence': 0.376},
#  'House Party - Radio Edit - DJ Antoine': {'Track': 'House Party - Radio Edit - DJ Antoine',
#   'acousticness': 0.0693,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wm8SCfjMXhHXGtraWwGw9',
#   'danceability': 0.699,
#   'duration_ms': 206800,
#   'energy': 0.916,
#   'id': '1wm8SCfjMXhHXGtraWwGw9',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.159,
#   'loudness': -3.382,
#   'mode': 0,
#   'speechiness': 0.0558,
#   'tempo': 127.968,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1wm8SCfjMXhHXGtraWwGw9',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1wm8SCfjMXhHXGtraWwGw9',
#   'valence': 0.773},
#  'My Love (feat. Jess Glynne) - Route 94': {'Track': 'My Love (feat. Jess Glynne) - Route 94',
#   'acousticness': 0.000132,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61UQzeiIluhpzpMdY4ag3q',
#   'danceability': 0.814,
#   'duration_ms': 259934,
#   'energy': 0.622,
#   'id': '61UQzeiIluhpzpMdY4ag3q',
#   'instrumentalness': 0.72,
#   'key': 8,
#   'liveness': 0.0658,
#   'loudness': -7.573,
#   'mode': 1,
#   'speechiness': 0.0492,
#   'tempo': 119.976,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/61UQzeiIluhpzpMdY4ag3q',
#   'type': 'audio_features',
#   'uri': 'spotify:track:61UQzeiIluhpzpMdY4ag3q',
#   'valence': 0.726},
#  'Right Now (Na Na Na) - Akon': {'Track': 'Right Now (Na Na Na) - Akon',
#   'acousticness': 0.267,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ARJhjuI6TNYZCxYygFQ4F',
#   'danceability': 0.832,
#   'duration_ms': 240747,
#   'energy': 0.87,
#   'id': '1ARJhjuI6TNYZCxYygFQ4F',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.412,
#   'loudness': -4.2,
#   'mode': 0,
#   'speechiness': 0.167,
#   'tempo': 138.003,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1ARJhjuI6TNYZCxYygFQ4F',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1ARJhjuI6TNYZCxYygFQ4F',
#   'valence': 0.566},
#  'Summer of Love - Cascada': {'Track': 'Summer of Love - Cascada',
#   'acousticness': 0.00273,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5AzuRUQBFH1xtxZlUtT0VJ',
#   'danceability': 0.569,
#   'duration_ms': 215735,
#   'energy': 0.747,
#   'id': '5AzuRUQBFH1xtxZlUtT0VJ',
#   'instrumentalness': 1.31e-05,
#   'key': 8,
#   'liveness': 0.247,
#   'loudness': -5.634,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'tempo': 127.94,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5AzuRUQBFH1xtxZlUtT0VJ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5AzuRUQBFH1xtxZlUtT0VJ',
#   'valence': 0.549},
#  'Temperature Rising - Tory Lanez': {'Track': 'Temperature Rising - Tory Lanez',
#   'acousticness': 0.00756,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FKFLWFa7fVoftc7UmYhDC',
#   'danceability': 0.569,
#   'duration_ms': 136333,
#   'energy': 0.519,
#   'id': '1FKFLWFa7fVoftc7UmYhDC',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0809,
#   'loudness': -5.44,
#   'mode': 0,
#   'speechiness': 0.0464,
#   'tempo': 131.91,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/1FKFLWFa7fVoftc7UmYhDC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1FKFLWFa7fVoftc7UmYhDC',
#   'valence': 0.0769},
#  'Daisies - Katy Perry': {'Track': 'Daisies - Katy Perry',
#   'acousticness': 0.0837,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uqh9bualXNHXXwO2wPorc',
#   'danceability': 0.639,
#   'duration_ms': 173124,
#   'energy': 0.546,
#   'id': '4uqh9bualXNHXXwO2wPorc',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.122,
#   'loudness': -5.382,
#   'mode': 1,
#   'speechiness': 0.0407,
#   'tempo': 122.179,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4uqh9bualXNHXXwO2wPorc',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4uqh9bualXNHXXwO2wPorc',
#   'valence': 0.149},
#  'Beautiful Pain (Losin My Mind) - Polo G': {'Track': 'Beautiful Pain (Losin My Mind) - Polo G',
#   'acousticness': 0.137,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4SIB2yxKoFOrbkjA4zfQbB',
#   'danceability': 0.597,
#   'duration_ms': 171442,
#   'energy': 0.477,
#   'id': '4SIB2yxKoFOrbkjA4zfQbB',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.113,
#   'loudness': -9.638,
#   'mode': 0,
#   'speechiness': 0.642,
#   'tempo': 80.382,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4SIB2yxKoFOrbkjA4zfQbB',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4SIB2yxKoFOrbkjA4zfQbB',
#   'valence': 0.512},
#  'Rude Boy - Rihanna': {'Track': 'Rude Boy - Rihanna',
#   'acousticness': 0.113,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60jzFy6Nn4M0iD1d94oteF',
#   'danceability': 0.563,
#   'duration_ms': 222920,
#   'energy': 0.75,
#   'id': '60jzFy6Nn4M0iD1d94oteF',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.0788,
#   'loudness': -4.496,
#   'mode': 1,
#   'speechiness': 0.127,
#   'tempo': 173.906,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/60jzFy6Nn4M0iD1d94oteF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:60jzFy6Nn4M0iD1d94oteF',
#   'valence': 0.812},
#  'Tu Meri - Jersey Club Remix By Jayhaan - Jayhaan': {'Track': 'Tu Meri - Jersey Club Remix By Jayhaan - Jayhaan',
#   'acousticness': 0.017,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/39u5UghSExp8XeJlxcHEeG',
#   'danceability': 0.767,
#   'duration_ms': 101052,
#   'energy': 0.934,
#   'id': '39u5UghSExp8XeJlxcHEeG',
#   'instrumentalness': 0.0112,
#   'key': 5,
#   'liveness': 0.0936,
#   'loudness': -7.248,
#   'mode': 0,
#   'speechiness': 0.0442,
#   'tempo': 145.044,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/39u5UghSExp8XeJlxcHEeG',
#   'type': 'audio_features',
#   'uri': 'spotify:track:39u5UghSExp8XeJlxcHEeG',
#   'valence': 0.51},
#  'Push It - O.T. Genasis': {'Track': 'Push It - O.T. Genasis',
#   'acousticness': 0.143,
# ...
#   'acousticness': 0.0627,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13jLiEg5wdMXuJzXXnRcnj',
#   'danceability': 0.684,
#   'duration_ms': 228396,
#   'energy': 0.862,
#   'id': '13jLiEg5wdMXuJzXXnRcnj',
#   'instrumentalness': 0.000177,
#   'key': 6,
#   'liveness': 0.126,
#   'loudness': -4.855,
#   'mode': 0,
#   'speechiness': 0.0952,
#   'tempo': 120.02,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/13jLiEg5wdMXuJzXXnRcnj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:13jLiEg5wdMXuJzXXnRcnj',
#   'valence': 0.275},
#  'Homicide (feat. Eminem) - Logic': {'Track': 'Homicide (feat. Eminem) - Logic',
#   'acousticness': 0.137,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7M2tXmeS15NAzEn7ABFeBg',
#   'danceability': 0.694,
#   'duration_ms': 245387,
#   'energy': 0.759,
#   'id': '7M2tXmeS15NAzEn7ABFeBg',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.167,
#   'loudness': -5.667,
#   'mode': 0,
#   'speechiness': 0.398,
#   'tempo': 140.055,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7M2tXmeS15NAzEn7ABFeBg',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7M2tXmeS15NAzEn7ABFeBg',
#   'valence': 0.77},
#  "Stay (Don't Go Away) [feat. Raye] - David Guetta": {'Track': "Stay (Don't Go Away) [feat. Raye] - David Guetta",
#   'acousticness': 0.259,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YhN72dRYL2Z3MsaKyT7rS',
#   'danceability': 0.669,
#   'duration_ms': 185943,
#   'energy': 0.797,
#   'id': '4YhN72dRYL2Z3MsaKyT7rS',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.199,
#   'loudness': -5.68,
#   'mode': 0,
#   'speechiness': 0.0624,
#   'tempo': 119.865,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4YhN72dRYL2Z3MsaKyT7rS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4YhN72dRYL2Z3MsaKyT7rS',
#   'valence': 0.552},
#  "I Don't Care (with Justin Bieber) - Ed Sheeran": {'Track': "I Don't Care (with Justin Bieber) - Ed Sheeran",
#   'acousticness': 0.0912,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HVWdVOQ0ZA45FuZGSfvns',
#   'danceability': 0.798,
#   'duration_ms': 219947,
#   'energy': 0.675,
#   'id': '3HVWdVOQ0ZA45FuZGSfvns',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0894,
#   'loudness': -5.041,
#   'mode': 1,
#   'speechiness': 0.0442,
#   'tempo': 101.956,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3HVWdVOQ0ZA45FuZGSfvns',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3HVWdVOQ0ZA45FuZGSfvns',
#   'valence': 0.842},
#  'Like To Be You (feat. Julia Michaels) - Shawn Mendes': {'Track': 'Like To Be You (feat. Julia Michaels) - Shawn Mendes',
#   'acousticness': 0.812,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2IssBpPtHcViZL5vYQNHhA',
#   'danceability': 0.737,
#   'duration_ms': 159400,
#   'energy': 0.451,
#   'id': '2IssBpPtHcViZL5vYQNHhA',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.108,
#   'loudness': -9.405,
#   'mode': 1,
#   'speechiness': 0.229,
#   'tempo': 153.766,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2IssBpPtHcViZL5vYQNHhA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2IssBpPtHcViZL5vYQNHhA',
#   'valence': 0.664},
#  'Temperature - Sean Paul': {'Track': 'Temperature - Sean Paul',
#   'acousticness': 0.106,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0k2GOhqsrxDTAbFFSdNJjT',
#   'danceability': 0.951,
#   'duration_ms': 218573,
#   'energy': 0.6,
#   'id': '0k2GOhqsrxDTAbFFSdNJjT',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0712,
#   'loudness': -4.675,
#   'mode': 0,
#   'speechiness': 0.0685,
#   'tempo': 125.04,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0k2GOhqsrxDTAbFFSdNJjT',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0k2GOhqsrxDTAbFFSdNJjT',
#   'valence': 0.822},
#  'The Purge - Hopsin': {'Track': 'The Purge - Hopsin',
#   'acousticness': 0.215,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7J2T6mw5zBGhHLsK3GC5PA',
#   'danceability': 0.714,
#   'duration_ms': 203704,
#   'energy': 0.844,
#   'id': '7J2T6mw5zBGhHLsK3GC5PA',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.13,
#   'loudness': -8.031,
#   'mode': 1,
#   'speechiness': 0.309,
#   'tempo': 147.786,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7J2T6mw5zBGhHLsK3GC5PA',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7J2T6mw5zBGhHLsK3GC5PA',
#   'valence': 0.543},
#  'Love Yourself - Justin Bieber': {'Track': 'Love Yourself - Justin Bieber',
#   'acousticness': 0.835,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/50kpGaPAhYJ3sGmk6vplg0',
#   'danceability': 0.609,
#   'duration_ms': 233720,
#   'energy': 0.378,
#   'id': '50kpGaPAhYJ3sGmk6vplg0',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.28,
#   'loudness': -9.828,
#   'mode': 1,
#   'speechiness': 0.438,
#   'tempo': 100.418,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/50kpGaPAhYJ3sGmk6vplg0',
#   'type': 'audio_features',
#   'uri': 'spotify:track:50kpGaPAhYJ3sGmk6vplg0',
#   'valence': 0.515},
#  '4 AM - Scooter': {'Track': '4 AM - Scooter',
#   'acousticness': 0.000736,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/29f9l4ImBUkA33j8kQBy65',
#   'danceability': 0.554,
#   'duration_ms': 197497,
#   'energy': 0.868,
#   'id': '29f9l4ImBUkA33j8kQBy65',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.327,
#   'loudness': -4.163,
#   'mode': 0,
#   'speechiness': 0.0949,
#   'tempo': 132.009,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/29f9l4ImBUkA33j8kQBy65',
#   'type': 'audio_features',
#   'uri': 'spotify:track:29f9l4ImBUkA33j8kQBy65',
#   'valence': 0.243},
#  'Scar Tissue - Red Hot Chili Peppers': {'Track': 'Scar Tissue - Red Hot Chili Peppers',
#   'acousticness': 0.0779,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1G391cbiT3v3Cywg8T7DM1',
#   'danceability': 0.595,
#   'duration_ms': 215907,
#   'energy': 0.717,
#   'id': '1G391cbiT3v3Cywg8T7DM1',
#   'instrumentalness': 0.00274,
#   'key': 0,
#   'liveness': 0.108,
#   'loudness': -4.803,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'tempo': 88.969,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1G391cbiT3v3Cywg8T7DM1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1G391cbiT3v3Cywg8T7DM1',
#   'valence': 0.547},
#  'Ready To Let Go - Cage The Elephant': {'Track': 'Ready To Let Go - Cage The Elephant',
#   'acousticness': 0.011,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4UyAtnwhaKv7EG1BdkBYRI',
#   'danceability': 0.719,
#   'duration_ms': 187973,
#   'energy': 0.896,
#   'id': '4UyAtnwhaKv7EG1BdkBYRI',
#   'instrumentalness': 3.25e-05,
#   'key': 1,
#   'liveness': 0.0731,
#   'loudness': -3.263,
#   'mode': 1,
#   'speechiness': 0.037,
#   'tempo': 100.962,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4UyAtnwhaKv7EG1BdkBYRI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4UyAtnwhaKv7EG1BdkBYRI',
#   'valence': 0.746},
#  'Midnight City - M83': {'Track': 'Midnight City - M83',
#   'acousticness': 0.0161,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1eyzqe2QqGZUmfcPZtrIyt',
#   'danceability': 0.526,
#   'duration_ms': 241440,
#   'energy': 0.712,
#   'id': '1eyzqe2QqGZUmfcPZtrIyt',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.179,
#   'loudness': -6.525,
#   'mode': 0,
#   'speechiness': 0.0356,
#   'tempo': 105.009,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1eyzqe2QqGZUmfcPZtrIyt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1eyzqe2QqGZUmfcPZtrIyt',
#   'valence': 0.32},
#  'In The Air Tonight - 2015 Remastered - Phil Collins': {'Track': 'In The Air Tonight - 2015 Remastered - Phil Collins',
#   'acousticness': 0.551,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18AXbzPzBS8Y3AkgSxzJPb',
#   'danceability': 0.446,
#   'duration_ms': 336453,
#   'energy': 0.239,
#   'id': '18AXbzPzBS8Y3AkgSxzJPb',
#   'instrumentalness': 4.1e-06,
#   'key': 0,
#   'liveness': 0.0697,
#   'loudness': -13.945,
#   'mode': 1,
#   'speechiness': 0.0316,
#   'tempo': 189.507,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/18AXbzPzBS8Y3AkgSxzJPb',
#   'type': 'audio_features',
#   'uri': 'spotify:track:18AXbzPzBS8Y3AkgSxzJPb',
#   'valence': 0.298},
#  "I Don't Care Anymore - 2016 Remaster - Phil Collins": {'Track': "I Don't Care Anymore - 2016 Remaster - Phil Collins",
#   'acousticness': 0.188,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24IdPCimVnJJDRuB5YSDiS',
#   'danceability': 0.703,
#   'duration_ms': 305707,
#   'energy': 0.422,
#   'id': '24IdPCimVnJJDRuB5YSDiS',
#   'instrumentalness': 0.00311,
#   'key': 11,
#   'liveness': 0.0851,
#   'loudness': -8.297,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'tempo': 140.494,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/24IdPCimVnJJDRuB5YSDiS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:24IdPCimVnJJDRuB5YSDiS',
#   'valence': 0.442},
#  'Hurt - Johnny Cash': {'Track': 'Hurt - Johnny Cash',
#   'acousticness': 0.649,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/28cnXtME493VX9NOw9cIUh',
#   'danceability': 0.534,
#   'duration_ms': 216533,
#   'energy': 0.392,
#   'id': '28cnXtME493VX9NOw9cIUh',
#   'instrumentalness': 0.000227,
#   'key': 9,
#   'liveness': 0.0948,
#   'loudness': -7.636,
#   'mode': 0,
#   'speechiness': 0.0267,
#   'tempo': 90.379,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/28cnXtME493VX9NOw9cIUh',
#   'type': 'audio_features',
#   'uri': 'spotify:track:28cnXtME493VX9NOw9cIUh',
#   'valence': 0.163},
#  'Hot Blood - KALEO': {'Track': 'Hot Blood - KALEO',
#   'acousticness': 0.00327,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7d9sZF7jmepe2EYdETlNWK',
#   'danceability': 0.325,
#   'duration_ms': 218600,
#   'energy': 0.903,
#   'id': '7d9sZF7jmepe2EYdETlNWK',
#   'instrumentalness': 6.13e-06,
#   'key': 2,
#   'liveness': 0.0962,
#   'loudness': -3.173,
#   'mode': 1,
#   'speechiness': 0.117,
#   'tempo': 148.446,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7d9sZF7jmepe2EYdETlNWK',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7d9sZF7jmepe2EYdETlNWK',
#   'valence': 0.401},
#  'Way down We Go - KALEO': {'Track': 'Way down We Go - KALEO',
#   'acousticness': 0.579,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0y1QJc3SJVPKJ1OvFmFqe6',
#   'danceability': 0.489,
#   'duration_ms': 213707,
#   'energy': 0.505,
#   'id': '0y1QJc3SJVPKJ1OvFmFqe6',
#   'instrumentalness': 0.000333,
#   'key': 10,
#   'liveness': 0.104,
#   'loudness': -8.022,
#   'mode': 0,
#   'speechiness': 0.117,
#   'tempo': 163.255,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0y1QJc3SJVPKJ1OvFmFqe6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0y1QJc3SJVPKJ1OvFmFqe6',
#   'valence': 0.337},
#  'Seven Nation Army - The White Stripes': {'Track': 'Seven Nation Army - The White Stripes',
#   'acousticness': 0.00817,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7i6r9KotUPQg3ozKKgEPIN',
#   'danceability': 0.737,
#   'duration_ms': 231733,
#   'energy': 0.463,
#   'id': '7i6r9KotUPQg3ozKKgEPIN',
#   'instrumentalness': 0.447,
#   'key': 0,
#   'liveness': 0.255,
#   'loudness': -7.828,
#   'mode': 1,
#   'speechiness': 0.0792,
#   'tempo': 123.881,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7i6r9KotUPQg3ozKKgEPIN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7i6r9KotUPQg3ozKKgEPIN',
#   'valence': 0.324},
#  'Dynamite - Taio Cruz': {'Track': 'Dynamite - Taio Cruz',
#   'acousticness': 0.00332,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DqdF42leyFIzqNDv9CjId',
#   'danceability': 0.754,
#   'duration_ms': 203867,
#   'energy': 0.804,
#   'id': '1DqdF42leyFIzqNDv9CjId',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.0329,
#   'loudness': -3.177,
#   'mode': 1,
#   'speechiness': 0.0853,
#   'tempo': 119.968,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1DqdF42leyFIzqNDv9CjId',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1DqdF42leyFIzqNDv9CjId',
#   'valence': 0.818},
#  'Row The Body (feat. French Montana) - Taio Cruz': {'Track': 'Row The Body (feat. French Montana) - Taio Cruz',
#   'acousticness': 0.172,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5qmR4IEKBUpgPa14pGuWuS',
#   'danceability': 0.701,
#   'duration_ms': 237500,
#   'energy': 0.695,
#   'id': '5qmR4IEKBUpgPa14pGuWuS',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.238,
#   'loudness': -5.653,
#   'mode': 0,
#   'speechiness': 0.0628,
#   'tempo': 96.033,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5qmR4IEKBUpgPa14pGuWuS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5qmR4IEKBUpgPa14pGuWuS',
#   'valence': 0.624},
#  'Stereo Love - Original - Edward Maya': {'Track': 'Stereo Love - Original - Edward Maya',
#   'acousticness': 0.0747,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YoW0QdqzxVkpYsQ3sPV2M',
#   'danceability': 0.751,
#   'duration_ms': 192000,
#   'energy': 0.764,
#   'id': '1YoW0QdqzxVkpYsQ3sPV2M',
#   'instrumentalness': 0.00749,
#   'key': 9,
#   'liveness': 0.0925,
#   'loudness': -5.512,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'tempo': 130.076,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1YoW0QdqzxVkpYsQ3sPV2M',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1YoW0QdqzxVkpYsQ3sPV2M',
#   'valence': 0.46},
#  'You Found Me - The Fray': {'Track': 'You Found Me - The Fray',
#   'acousticness': 0.0187,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4IoYz8XqqdowINzfRrFnhi',
#   'danceability': 0.338,
#   'duration_ms': 241853,
#   'energy': 0.803,
#   'id': '4IoYz8XqqdowINzfRrFnhi',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.136,
#   'loudness': -5.412,
#   'mode': 0,
#   'speechiness': 0.0413,
#   'tempo': 151.994,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4IoYz8XqqdowINzfRrFnhi',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4IoYz8XqqdowINzfRrFnhi',
#   'valence': 0.4},
#  'Lost in the Middle of Nowhere (feat. Becky G) - Kane Brown': {'Track': 'Lost in the Middle of Nowhere (feat. Becky G) - Kane Brown',
#   'acousticness': 0.00184,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KfKPfX5cZvOuHoy9io65A',
#   'danceability': 0.559,
#   'duration_ms': 188920,
#   'energy': 0.754,
#   'id': '5KfKPfX5cZvOuHoy9io65A',
#   'instrumentalness': 0.000462,
#   'key': 6,
#   'liveness': 0.0366,
#   'loudness': -5.344,
#   'mode': 0,
#   'speechiness': 0.0481,
#   'tempo': 85.993,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5KfKPfX5cZvOuHoy9io65A',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5KfKPfX5cZvOuHoy9io65A',
#   'valence': 0.438},
#  'Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit - Daft Punk': {'Track': 'Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit - Daft Punk',
#   'acousticness': 0.0426,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Foc5Q5nqNiosCNqttzHof',
#   'danceability': 0.794,
#   'duration_ms': 248413,
#   'energy': 0.811,
#   'id': '2Foc5Q5nqNiosCNqttzHof',
#   'instrumentalness': 1.07e-06,
#   'key': 6,
#   'liveness': 0.101,
#   'loudness': -8.966,
#   'mode': 0,
#   'speechiness': 0.038,
#   'tempo': 116.047,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2Foc5Q5nqNiosCNqttzHof',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2Foc5Q5nqNiosCNqttzHof',
#   'valence': 0.862},
#  'Sucker - Jonas Brothers': {'Track': 'Sucker - Jonas Brothers',
#   'acousticness': 0.0427,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22vgEDb5hykfaTwLuskFGD',
#   'danceability': 0.842,
#   'duration_ms': 181027,
#   'energy': 0.734,
#   'id': '22vgEDb5hykfaTwLuskFGD',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.106,
#   'loudness': -5.065,
#   'mode': 0,
#   'speechiness': 0.0588,
#   'tempo': 137.958,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/22vgEDb5hykfaTwLuskFGD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:22vgEDb5hykfaTwLuskFGD',
#   'valence': 0.952},
#  ...}

# %%
for k, v in potential_recs_songdata_dict.items():
    v["Track"] = k
potential_recs_songdata_dict
# Out:
# {'123 - Jess Glynne': {'Track': '123 - Jess Glynne',
#   'acousticness': 0.0901,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gFgp6Ofp808Kc2qLQiN5e',
#   'danceability': 0.707,
#   'duration_ms': 190280,
#   'energy': 0.674,
#   'id': '3gFgp6Ofp808Kc2qLQiN5e',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.115,
#   'loudness': -5.578,
#   'mode': 1,
#   'speechiness': 0.177,
#   'tempo': 95.02,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3gFgp6Ofp808Kc2qLQiN5e',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3gFgp6Ofp808Kc2qLQiN5e',
#   'valence': 0.928},
#  '123 - Smokepurpp': {'Track': '123 - Smokepurpp',
#   'acousticness': 0.196,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MHPgpKYfTVml3qEXspnLQ',
#   'danceability': 0.88,
#   'duration_ms': 170000,
#   'energy': 0.61,
#   'id': '0MHPgpKYfTVml3qEXspnLQ',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.105,
#   'loudness': -5.257,
#   'mode': 1,
#   'speechiness': 0.402,
#   'tempo': 135.993,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0MHPgpKYfTVml3qEXspnLQ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0MHPgpKYfTVml3qEXspnLQ',
#   'valence': 0.383},
#  '1999 - Troye Sivan': {'Track': '1999 - Troye Sivan',
#   'acousticness': 0.0227,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05mAIVLkIWc2d1UBYZBCp8',
#   'danceability': 0.739,
#   'duration_ms': 189000,
#   'energy': 0.742,
#   'id': '05mAIVLkIWc2d1UBYZBCp8',
#   'instrumentalness': 1.39e-06,
#   'key': 7,
#   'liveness': 0.229,
#   'loudness': -4.586,
#   'mode': 1,
#   'speechiness': 0.0329,
#   'tempo': 124.016,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/05mAIVLkIWc2d1UBYZBCp8',
#   'type': 'audio_features',
#   'uri': 'spotify:track:05mAIVLkIWc2d1UBYZBCp8',
#   'valence': 0.659},
#  '20 Years Later - Yung Pinch': {'Track': '20 Years Later - Yung Pinch',
#   'acousticness': 0.232,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0dc3ds3WAOo6TazfgBuT0E',
#   'danceability': 0.762,
#   'duration_ms': 215189,
#   'energy': 0.518,
#   'id': '0dc3ds3WAOo6TazfgBuT0E',
#   'instrumentalness': 1.11e-06,
#   'key': 9,
#   'liveness': 0.113,
#   'loudness': -7.283,
#   'mode': 0,
#   'speechiness': 0.109,
#   'tempo': 144.942,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0dc3ds3WAOo6TazfgBuT0E',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0dc3ds3WAOo6TazfgBuT0E',
#   'valence': 0.547},
#  '2019 - Bazanji': {'Track': '2019 - Bazanji',
#   'acousticness': 0.15,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4DERbz1e89YD9VZt7or9GB',
#   'danceability': 0.597,
#   'duration_ms': 112245,
#   'energy': 0.881,
#   'id': '4DERbz1e89YD9VZt7or9GB',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.16,
#   'loudness': -5.23,
#   'mode': 0,
#   'speechiness': 0.119,
#   'tempo': 147.042,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4DERbz1e89YD9VZt7or9GB',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4DERbz1e89YD9VZt7or9GB',
#   'valence': 0.295},
#  '29 - Bankrol Hayden': {'Track': '29 - Bankrol Hayden',
#   'acousticness': 0.804,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/294r8rdOqr0Nv1vuV5u8Qv',
#   'danceability': 0.784,
#   'duration_ms': 116715,
#   'energy': 0.391,
#   'id': '294r8rdOqr0Nv1vuV5u8Qv',
#   'instrumentalness': 0,
#   'key': 3,
#   'liveness': 0.18,
#   'loudness': -10.628,
#   'mode': 1,
#   'speechiness': 0.215,
#   'tempo': 90.789,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/294r8rdOqr0Nv1vuV5u8Qv',
#   'type': 'audio_features',
#   'uri': 'spotify:track:294r8rdOqr0Nv1vuV5u8Qv',
#   'valence': 0.711},
#  '3005 - Childish Gambino': {'Track': '3005 - Childish Gambino',
#   'acousticness': 0.113,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ZltjIqztEpZtafc8w0I9t',
#   'danceability': 0.472,
#   'duration_ms': 234215,
#   'energy': 0.448,
#   'id': '2ZltjIqztEpZtafc8w0I9t',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0914,
#   'loudness': -7.272,
#   'mode': 0,
#   'speechiness': 0.326,
#   'tempo': 166.077,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ZltjIqztEpZtafc8w0I9t',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ZltjIqztEpZtafc8w0I9t',
#   'valence': 0.636},
#  '40 Oz. - D12': {'Track': '40 Oz. - D12',
#   'acousticness': 0.0785,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3SNIM6IPegio1UqXCYAhoc',
#   'danceability': 0.73,
#   'duration_ms': 242520,
#   'energy': 0.798,
#   'id': '3SNIM6IPegio1UqXCYAhoc',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.339,
#   'loudness': -4.105,
#   'mode': 0,
#   'speechiness': 0.209,
#   'tempo': 82.986,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3SNIM6IPegio1UqXCYAhoc',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3SNIM6IPegio1UqXCYAhoc',
#   'valence': 0.448},
#  '772 Love - YNW Melly': {'Track': '772 Love - YNW Melly',
#   'acousticness': 0.226,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/230wNo1dnexltKYQbsW7oD',
#   'danceability': 0.676,
#   'duration_ms': 209489,
#   'energy': 0.623,
#   'id': '230wNo1dnexltKYQbsW7oD',
#   'instrumentalness': 1.66e-05,
#   'key': 6,
#   'liveness': 0.159,
#   'loudness': -7.297,
#   'mode': 0,
#   'speechiness': 0.0352,
#   'tempo': 111.466,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/230wNo1dnexltKYQbsW7oD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:230wNo1dnexltKYQbsW7oD',
#   'valence': 0.347},
#  '8TEEN - Khalid': {'Track': '8TEEN - Khalid',
#   'acousticness': 0.225,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5bgwqaRSS3M8WHWruHgSL5',
#   'danceability': 0.83,
#   'duration_ms': 228600,
#   'energy': 0.585,
#   'id': '5bgwqaRSS3M8WHWruHgSL5',
#   'instrumentalness': 0.00209,
#   'key': 1,
#   'liveness': 0.0576,
#   'loudness': -5.802,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'tempo': 105.03,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5bgwqaRSS3M8WHWruHgSL5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5bgwqaRSS3M8WHWruHgSL5',
#   'valence': 0.642},
#  '@ MEH - Playboi Carti': {'Track': '@ MEH - Playboi Carti',
#   'acousticness': 0.0136,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5UusfWUMMLEXLMc1ViNZoe',
#   'danceability': 0.876,
#   'duration_ms': 166799,
#   'energy': 0.492,
#   'id': '5UusfWUMMLEXLMc1ViNZoe',
#   'instrumentalness': 0.000283,
#   'key': 11,
#   'liveness': 0.0678,
#   'loudness': -8.11,
#   'mode': 0,
#   'speechiness': 0.153,
#   'tempo': 151.044,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5UusfWUMMLEXLMc1ViNZoe',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5UusfWUMMLEXLMc1ViNZoe',
#   'valence': 0.4},
#  'A Brand New Day (BTS World Original Soundtrack) [Pt. 2] - Zara Larsson': {'Track': 'A Brand New Day (BTS World Original Soundtrack) [Pt. 2] - Zara Larsson',
#   'acousticness': 0.339,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XkyZyKMdFungjDb9cUKc3',
#   'danceability': 0.804,
#   'duration_ms': 205020,
#   'energy': 0.498,
#   'id': '5XkyZyKMdFungjDb9cUKc3',
#   'instrumentalness': 0.000236,
#   'key': 8,
#   'liveness': 0.18,
#   'loudness': -7.387,
#   'mode': 0,
#   'speechiness': 0.0571,
#   'tempo': 105.008,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5XkyZyKMdFungjDb9cUKc3',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5XkyZyKMdFungjDb9cUKc3',
#   'valence': 0.704},
#  'A Kiss - Bad Meets Evil': {'Track': 'A Kiss - Bad Meets Evil',
#   'acousticness': 0.00846,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eing5jncX5PU3Wtf8ssBc',
#   'danceability': 0.633,
#   'duration_ms': 274467,
#   'energy': 0.827,
#   'id': '4eing5jncX5PU3Wtf8ssBc',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.172,
#   'loudness': -5.775,
#   'mode': 0,
#   'speechiness': 0.251,
#   'tempo': 75.543,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4eing5jncX5PU3Wtf8ssBc',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4eing5jncX5PU3Wtf8ssBc',
#   'valence': 0.88},
#  'A Song for Everything - Maren Morris': {'Track': 'A Song for Everything - Maren Morris',
#   'acousticness': 0.159,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59C9WyONT72bKyaystIzjq',
#   'danceability': 0.578,
#   'duration_ms': 194453,
#   'energy': 0.569,
#   'id': '59C9WyONT72bKyaystIzjq',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.105,
#   'loudness': -7.863,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'tempo': 100.037,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/59C9WyONT72bKyaystIzjq',
#   'type': 'audio_features',
#   'uri': 'spotify:track:59C9WyONT72bKyaystIzjq',
#   'valence': 0.187},
#  'ARGENTINA - Gunna': {'Track': 'ARGENTINA - Gunna',
#   'acousticness': 0.0912,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4LkEHc33eXcXFQNwxruw7W',
#   'danceability': 0.804,
#   'duration_ms': 149133,
#   'energy': 0.725,
#   'id': '4LkEHc33eXcXFQNwxruw7W',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.0708,
#   'loudness': -9.463,
#   'mode': 1,
#   'speechiness': 0.0838,
#   'tempo': 139.967,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4LkEHc33eXcXFQNwxruw7W',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4LkEHc33eXcXFQNwxruw7W',
#   'valence': 0.356},
#  'Above The Law - Bad Meets Evil': {'Track': 'Above The Law - Bad Meets Evil',
#   'acousticness': 0.092,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5oEgPvhTZ4CFjeuuLfmMsI',
#   'danceability': 0.443,
#   'duration_ms': 209613,
#   'energy': 0.895,
#   'id': '5oEgPvhTZ4CFjeuuLfmMsI',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.239,
#   'loudness': -3.377,
#   'mode': 1,
#   'speechiness': 0.469,
#   'tempo': 183.602,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5oEgPvhTZ4CFjeuuLfmMsI',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5oEgPvhTZ4CFjeuuLfmMsI',
#   'valence': 0.52},
#  'Adam & Eve - Calboy': {'Track': 'Adam & Eve - Calboy',
#   'acousticness': 0.203,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0J6UvGEMuJvzPKvlDbBvLz',
#   'danceability': 0.781,
#   'duration_ms': 179467,
#   'energy': 0.696,
#   'id': '0J6UvGEMuJvzPKvlDbBvLz',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.13,
#   'loudness': -5.553,
#   'mode': 0,
#   'speechiness': 0.313,
#   'tempo': 74.998,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0J6UvGEMuJvzPKvlDbBvLz',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0J6UvGEMuJvzPKvlDbBvLz',
#   'valence': 0.692},
#  'Adorn - Miguel': {'Track': 'Adorn - Miguel',
#   'acousticness': 0.0543,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25cUhiAod71TIQSNicOaW3',
#   'danceability': 0.625,
#   'duration_ms': 193147,
#   'energy': 0.576,
#   'id': '25cUhiAod71TIQSNicOaW3',
#   'instrumentalness': 4.07e-05,
#   'key': 11,
#   'liveness': 0.187,
#   'loudness': -5.693,
#   'mode': 0,
#   'speechiness': 0.175,
#   'tempo': 179.063,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/25cUhiAod71TIQSNicOaW3',
#   'type': 'audio_features',
#   'uri': 'spotify:track:25cUhiAod71TIQSNicOaW3',
#   'valence': 0.235},
#  'Alexis - Joey Trap': {'Track': 'Alexis - Joey Trap',
#   'acousticness': 0.741,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/54yT3t8hSaJUvdHer3ZaB1',
#   'danceability': 0.839,
#   'duration_ms': 83000,
#   'energy': 0.539,
#   'id': '54yT3t8hSaJUvdHer3ZaB1',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0966,
#   'loudness': -9.238,
#   'mode': 1,
#   'speechiness': 0.0926,
#   'tempo': 124.921,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/54yT3t8hSaJUvdHer3ZaB1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:54yT3t8hSaJUvdHer3ZaB1',
#   'valence': 0.645},
#  'Ali Bomaye - The Game': {'Track': 'Ali Bomaye - The Game',
#   'acousticness': 0.0209,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0LFcFGLYTX6UmeIdO7NVd7',
#   'danceability': 0.381,
#   'duration_ms': 372707,
#   'energy': 0.69,
#   'id': '0LFcFGLYTX6UmeIdO7NVd7',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.438,
#   'loudness': -5.312,
#   'mode': 0,
#   'speechiness': 0.455,
#   'tempo': 78.239,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0LFcFGLYTX6UmeIdO7NVd7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0LFcFGLYTX6UmeIdO7NVd7',
#   'valence': 0.223},
#  'All For You - Years & Years': {'Track': 'All For You - Years & Years',
#   'acousticness': 0.135,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ehnD9UaRVYK6GeUmBFCez',
#   'danceability': 0.65,
#   'duration_ms': 219640,
#   'energy': 0.718,
#   'id': '2ehnD9UaRVYK6GeUmBFCez',
#   'instrumentalness': 9.53e-05,
#   'key': 1,
#   'liveness': 0.106,
#   'loudness': -4.365,
#   'mode': 0,
#   'speechiness': 0.0384,
#   'tempo': 114.034,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2ehnD9UaRVYK6GeUmBFCez',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2ehnD9UaRVYK6GeUmBFCez',
#   'valence': 0.686},
#  'All I Am - Jess Glynne': {'Track': 'All I Am - Jess Glynne',
#   'acousticness': 0.0445,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6X6SdJzxyw7GzxwP2fr9WV',
#   'danceability': 0.74,
#   'duration_ms': 218868,
#   'energy': 0.669,
#   'id': '6X6SdJzxyw7GzxwP2fr9WV',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.184,
#   'loudness': -5.199,
#   'mode': 1,
#   'speechiness': 0.0373,
#   'tempo': 122.007,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6X6SdJzxyw7GzxwP2fr9WV',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6X6SdJzxyw7GzxwP2fr9WV',
#   'valence': 0.536},
#  'All I Think About - Bad Meets Evil': {'Track': 'All I Think About - Bad Meets Evil',
#   'acousticness': 0.169,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5J1wAUibWxgBp5oOrivcpQ',
#   'danceability': 0.836,
#   'duration_ms': 372680,
#   'energy': 0.915,
#   'id': '5J1wAUibWxgBp5oOrivcpQ',
#   'instrumentalness': 7.09e-06,
#   'key': 7,
#   'liveness': 0.113,
#   'loudness': -4.052,
#   'mode': 1,
#   'speechiness': 0.344,
#   'tempo': 120.332,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5J1wAUibWxgBp5oOrivcpQ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5J1wAUibWxgBp5oOrivcpQ',
#   'valence': 0.63},
#  'All In My Head (Flex) (feat. Fetty Wap) - Fifth Harmony': {'Track': 'All In My Head (Flex) (feat. Fetty Wap) - Fifth Harmony',
#   'acousticness': 0.023,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7nD9nN3jord9wWcfW3Gkcm',
#   'danceability': 0.689,
#   'duration_ms': 210573,
#   'energy': 0.791,
#   'id': '7nD9nN3jord9wWcfW3Gkcm',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0526,
#   'loudness': -5.194,
#   'mode': 0,
#   'speechiness': 0.053,
#   'tempo': 95.04,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7nD9nN3jord9wWcfW3Gkcm',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7nD9nN3jord9wWcfW3Gkcm',
#   'valence': 0.755},
#  'All Me (feat. Keyshia Cole) - Kehlani': {'Track': 'All Me (feat. Keyshia Cole) - Kehlani',
#   'acousticness': 0.233,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ucRKbRlikYHyoI17gfR0c',
#   'danceability': 0.42,
#   'duration_ms': 178348,
#   'energy': 0.731,
#   'id': '3ucRKbRlikYHyoI17gfR0c',
#   'instrumentalness': 0,
#   'key': 3,
#   'liveness': 0.196,
#   'loudness': -2.657,
#   'mode': 0,
#   'speechiness': 0.0548,
#   'tempo': 95.575,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3ucRKbRlikYHyoI17gfR0c',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3ucRKbRlikYHyoI17gfR0c',
#   'valence': 0.588},
#  'All My Favorite People (feat. Brothers Osborne) - Maren Morris': {'Track': 'All My Favorite People (feat. Brothers Osborne) - Maren Morris',
#   'acousticness': 0.0327,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tEPv5fuzMhtm6NM5GvQiF',
#   'danceability': 0.422,
#   'duration_ms': 199787,
#   'energy': 0.919,
#   'id': '0tEPv5fuzMhtm6NM5GvQiF',
#   'instrumentalness': 0.000605,
#   'key': 4,
#   'liveness': 0.33,
#   'loudness': -4.0,
#   'mode': 1,
#   'speechiness': 0.0639,
#   'tempo': 83.867,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0tEPv5fuzMhtm6NM5GvQiF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0tEPv5fuzMhtm6NM5GvQiF',
#   'valence': 0.553},
#  'All My Love - Sabrina Claudio': {'Track': 'All My Love - Sabrina Claudio',
#   'acousticness': 0.384,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/454UyoTlRt9FFI9ErpMPMk',
#   'danceability': 0.725,
#   'duration_ms': 154483,
#   'energy': 0.888,
#   'id': '454UyoTlRt9FFI9ErpMPMk',
#   'instrumentalness': 0.00269,
#   'key': 5,
#   'liveness': 0.163,
#   'loudness': -4.272,
#   'mode': 1,
#   'speechiness': 0.246,
#   'tempo': 87.011,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/454UyoTlRt9FFI9ErpMPMk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:454UyoTlRt9FFI9ErpMPMk',
#   'valence': 0.595},
#  'All My Love - Wale': {'Track': 'All My Love - Wale',
#   'acousticness': 0.384,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/454UyoTlRt9FFI9ErpMPMk',
#   'danceability': 0.725,
#   'duration_ms': 154483,
#   'energy': 0.888,
#   'id': '454UyoTlRt9FFI9ErpMPMk',
#   'instrumentalness': 0.00269,
#   'key': 5,
#   'liveness': 0.163,
#   'loudness': -4.272,
#   'mode': 1,
#   'speechiness': 0.246,
#   'tempo': 87.011,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/454UyoTlRt9FFI9ErpMPMk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:454UyoTlRt9FFI9ErpMPMk',
#   'valence': 0.595},
#  'All Night - Matoma': {'Track': 'All Night - Matoma',
#   'acousticness': 0.0041,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0dXNQ8dckG4eYfEtq9zcva',
#   'danceability': 0.538,
#   'duration_ms': 197640,
#   'energy': 0.804,
#   'id': '0dXNQ8dckG4eYfEtq9zcva',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.33,
#   'loudness': -5.194,
#   'mode': 1,
#   'speechiness': 0.0358,
#   'tempo': 144.992,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0dXNQ8dckG4eYfEtq9zcva',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0dXNQ8dckG4eYfEtq9zcva',
#   'valence': 0.507},
#  'All Star (with Lil Tjay) - Lil Tecca': {'Track': 'All Star (with Lil Tjay) - Lil Tecca',
#   'acousticness': 0.265,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62uolmVjOio9xIfwDM1ZvC',
#   'danceability': 0.782,
#   'duration_ms': 180234,
#   'energy': 0.644,
#   'id': '62uolmVjOio9xIfwDM1ZvC',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.122,
#   'loudness': -5.559,
#   'mode': 0,
#   'speechiness': 0.162,
#   'tempo': 129.972,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/62uolmVjOio9xIfwDM1ZvC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:62uolmVjOio9xIfwDM1ZvC',
#   'valence': 0.434},
#  'All Star - Mike Perry': {'Track': 'All Star - Mike Perry',
#   'acousticness': 0.016,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2u0oTsc6XcvJTh24ynQ1Ao',
#   'danceability': 0.66,
#   'duration_ms': 151278,
#   'energy': 0.852,
#   'id': '2u0oTsc6XcvJTh24ynQ1Ao',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.203,
#   'loudness': -3.573,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'tempo': 103.988,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2u0oTsc6XcvJTh24ynQ1Ao',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2u0oTsc6XcvJTh24ynQ1Ao',
#   'valence': 0.594},
#  'All The Time - Jeremih': {'Track': 'All The Time - Jeremih',
#   'acousticness': 0.545,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0USZx50eApN045zIIyjePN',
#   'danceability': 0.675,
#   'duration_ms': 264200,
#   'energy': 0.44,
#   'id': '0USZx50eApN045zIIyjePN',
#   'instrumentalness': 6.24e-06,
#   'key': 9,
#   'liveness': 0.197,
#   'loudness': -9.298,
#   'mode': 0,
#   'speechiness': 0.349,
#   'tempo': 109.823,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0USZx50eApN045zIIyjePN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0USZx50eApN045zIIyjePN',
#   'valence': 0.0338},
#  'All You Need To Know (feat. Calle Lehmann) - Gryffin': {'Track': 'All You Need To Know (feat. Calle Lehmann) - Gryffin',
#   'acousticness': 0.00968,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Gcv5SsxnQWpmOnUI19EJk',
#   'danceability': 0.513,
#   'duration_ms': 238459,
#   'energy': 0.788,
#   'id': '4Gcv5SsxnQWpmOnUI19EJk',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.11,
#   'loudness': -4.629,
#   'mode': 1,
#   'speechiness': 0.0364,
#   'tempo': 139.987,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4Gcv5SsxnQWpmOnUI19EJk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4Gcv5SsxnQWpmOnUI19EJk',
#   'valence': 0.234},
#  'All the Time - Don Diablo Remix - Zara Larsson': {'Track': 'All the Time - Don Diablo Remix - Zara Larsson',
#   'acousticness': 0.0794,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1z1Hg7Vb0AhHDiEmnDE79l',
#   'danceability': 0.675,
#   'duration_ms': 176616,
#   'energy': 0.931,
#   'id': '1z1Hg7Vb0AhHDiEmnDE79l',
#   'instrumentalness': 2.33e-05,
#   'key': 1,
#   'liveness': 0.11,
#   'loudness': -3.432,
#   'mode': 0,
#   'speechiness': 0.0742,
#   'tempo': 124.008,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1z1Hg7Vb0AhHDiEmnDE79l',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1z1Hg7Vb0AhHDiEmnDE79l',
#   'valence': 0.613},
#  'All the Time - Zara Larsson': {'Track': 'All the Time - Zara Larsson',
#   'acousticness': 0.18,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OTSBoYKO7HzGVj8Bu2OH9',
#   'danceability': 0.665,
#   'duration_ms': 228112,
#   'energy': 0.799,
#   'id': '3OTSBoYKO7HzGVj8Bu2OH9',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.125,
#   'loudness': -2.868,
#   'mode': 0,
#   'speechiness': 0.0617,
#   'tempo': 101.976,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3OTSBoYKO7HzGVj8Bu2OH9',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3OTSBoYKO7HzGVj8Bu2OH9',
#   'valence': 0.5},
#  'Ambition (feat. Meek Mill & Rick Ross) - Wale': {'Track': 'Ambition (feat. Meek Mill & Rick Ross) - Wale',
#   'acousticness': 0.398,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5tZmLjU4vhPlJb12IweZuB',
#   'danceability': 0.42,
#   'duration_ms': 302547,
#   'energy': 0.744,
#   'id': '5tZmLjU4vhPlJb12IweZuB',
#   'instrumentalness': 8.54e-06,
#   'key': 8,
#   'liveness': 0.192,
#   'loudness': -5.033,
#   'mode': 1,
#   'speechiness': 0.396,
#   'tempo': 161.792,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5tZmLjU4vhPlJb12IweZuB',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5tZmLjU4vhPlJb12IweZuB',
#   'valence': 0.324},
#  'American Psycho II - D12': {'Track': 'American Psycho II - D12',
#   'acousticness': 0.403,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Qr9Dl5b43RAZuXTSqzBzu',
#   'danceability': 0.646,
#   'duration_ms': 224240,
#   'energy': 0.83,
#   'id': '0Qr9Dl5b43RAZuXTSqzBzu',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.138,
#   'loudness': -4.456,
#   'mode': 0,
#   'speechiness': 0.32,
#   'tempo': 93.364,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0Qr9Dl5b43RAZuXTSqzBzu',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0Qr9Dl5b43RAZuXTSqzBzu',
#   'valence': 0.71},
#  'American You - Yelawolf': {'Track': 'American You - Yelawolf',
#   'acousticness': 0.186,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2g5cChGDcrjtpRVGA7q4Eh',
#   'danceability': 0.752,
#   'duration_ms': 212147,
#   'energy': 0.754,
#   'id': '2g5cChGDcrjtpRVGA7q4Eh',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.11,
#   'loudness': -5.061,
#   'mode': 1,
#   'speechiness': 0.133,
#   'tempo': 82.986,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2g5cChGDcrjtpRVGA7q4Eh',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2g5cChGDcrjtpRVGA7q4Eh',
#   'valence': 0.353},
#  'Amigo - Lil Tecca': {'Track': 'Amigo - Lil Tecca',
#   'acousticness': 0.415,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2BULAwmRpScmZE7YOF07e5',
#   'danceability': 0.774,
#   'duration_ms': 150093,
#   'energy': 0.669,
#   'id': '2BULAwmRpScmZE7YOF07e5',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.105,
#   'loudness': -7.397,
#   'mode': 0,
#   'speechiness': 0.221,
#   'tempo': 89.954,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2BULAwmRpScmZE7YOF07e5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2BULAwmRpScmZE7YOF07e5',
#   'valence': 0.528},
#  'Amor Tóxico - ChocQuibTown': {'Track': 'Amor Tóxico - ChocQuibTown',
#   'acousticness': 0.236,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Vajo5NIrDIy3KlO6q8ZVL',
#   'danceability': 0.79,
#   'duration_ms': 216182,
#   'energy': 0.848,
#   'id': '6Vajo5NIrDIy3KlO6q8ZVL',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.0838,
#   'loudness': -4.085,
#   'mode': 1,
#   'speechiness': 0.315,
#   'tempo': 99.966,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6Vajo5NIrDIy3KlO6q8ZVL',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6Vajo5NIrDIy3KlO6q8ZVL',
#   'valence': 0.676},
#  'Anywhere - Rita Ora': {'Track': 'Anywhere - Rita Ora',
#   'acousticness': 0.0364,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7EI6Iki24tBHAMxtb4xQN2',
#   'danceability': 0.628,
#   'duration_ms': 215064,
#   'energy': 0.797,
#   'id': '7EI6Iki24tBHAMxtb4xQN2',
#   'instrumentalness': 0,
#   'key': 11,
#   'liveness': 0.104,
#   'loudness': -3.953,
#   'mode': 0,
#   'speechiness': 0.0596,
#   'tempo': 106.93,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7EI6Iki24tBHAMxtb4xQN2',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7EI6Iki24tBHAMxtb4xQN2',
#   'valence': 0.321},
#  'Arms Around You (feat. Maluma & Swae Lee) - Lil Pump': {'Track': 'Arms Around You (feat. Maluma & Swae Lee) - Lil Pump',
#   'acousticness': 0.0302,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LskIZrCeLxRvCiGP8gxlh',
#   'danceability': 0.703,
#   'duration_ms': 198903,
#   'energy': 0.723,
#   'id': '2LskIZrCeLxRvCiGP8gxlh',
#   'instrumentalness': 2.06e-06,
#   'key': 9,
#   'liveness': 0.126,
#   'loudness': -5.45,
#   'mode': 0,
#   'speechiness': 0.0412,
#   'tempo': 104.969,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2LskIZrCeLxRvCiGP8gxlh',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2LskIZrCeLxRvCiGP8gxlh',
#   'valence': 0.288},
#  'Aston Martin Music - Rick Ross': {'Track': 'Aston Martin Music - Rick Ross',
#   'acousticness': 0.0125,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5W7xC99N2Zzfh69r7I7zWK',
#   'danceability': 0.57,
#   'duration_ms': 270627,
#   'energy': 0.58,
#   'id': '5W7xC99N2Zzfh69r7I7zWK',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.0497,
#   'loudness': -5.547,
#   'mode': 0,
#   'speechiness': 0.209,
#   'tempo': 171.917,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5W7xC99N2Zzfh69r7I7zWK',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5W7xC99N2Zzfh69r7I7zWK',
#   'valence': 0.405},
#  'Audi. - Smokepurpp': {'Track': 'Audi. - Smokepurpp',
#   'acousticness': 0.0214,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2INqEk4ko5AsGVLBsiKiQe',
#   'danceability': 0.794,
#   'duration_ms': 159522,
#   'energy': 0.366,
#   'id': '2INqEk4ko5AsGVLBsiKiQe',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.0964,
#   'loudness': -10.051,
#   'mode': 1,
#   'speechiness': 0.135,
#   'tempo': 122.993,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2INqEk4ko5AsGVLBsiKiQe',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2INqEk4ko5AsGVLBsiKiQe',
#   'valence': 0.278},
#  'B.A.N.K.R.O.L. - Bankrol Hayden': {'Track': 'B.A.N.K.R.O.L. - Bankrol Hayden',
#   'acousticness': 0.137,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6qVPeiDQyjLbZKN24ufCu7',
#   'danceability': 0.901,
#   'duration_ms': 108000,
#   'energy': 0.347,
#   'id': '6qVPeiDQyjLbZKN24ufCu7',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.144,
#   'loudness': -10.488,
#   'mode': 1,
#   'speechiness': 0.364,
#   'tempo': 138.077,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6qVPeiDQyjLbZKN24ufCu7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6qVPeiDQyjLbZKN24ufCu7',
#   'valence': 0.67},
#  'B.S. (feat. H.E.R.) - Jhené Aiko': {'Track': 'B.S. (feat. H.E.R.) - Jhené Aiko',
#   'acousticness': 0.554,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63wx9vdskaXbYxyDx4oJCZ',
#   'danceability': 0.617,
#   'duration_ms': 212867,
#   'energy': 0.525,
#   'id': '63wx9vdskaXbYxyDx4oJCZ',
#   'instrumentalness': 1.1e-06,
#   'key': 8,
#   'liveness': 0.135,
#   'loudness': -10.426,
#   'mode': 0,
#   'speechiness': 0.12,
#   'tempo': 135.781,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/63wx9vdskaXbYxyDx4oJCZ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:63wx9vdskaXbYxyDx4oJCZ',
#   'valence': 0.377},
#  'BLINDFOLD (feat. Lil Baby) - Gunna': {'Track': 'BLINDFOLD (feat. Lil Baby) - Gunna',
#   'acousticness': 0.0562,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02mYw61RoS1vXvkD9Q5dpN',
#   'danceability': 0.889,
#   'duration_ms': 154667,
#   'energy': 0.507,
#   'id': '02mYw61RoS1vXvkD9Q5dpN',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.116,
#   'loudness': -8.74,
#   'mode': 1,
#   'speechiness': 0.162,
#   'tempo': 111.994,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/02mYw61RoS1vXvkD9Q5dpN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:02mYw61RoS1vXvkD9Q5dpN',
#   'valence': 0.219},
#  'BO$$ - Fifth Harmony': {'Track': 'BO$$ - Fifth Harmony',
#   'acousticness': 0.00621,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1COvXs6jaykXC73h9OSBVM',
#   'danceability': 0.813,
#   'duration_ms': 171413,
#   'energy': 0.872,
#   'id': '1COvXs6jaykXC73h9OSBVM',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.0498,
#   'loudness': -5.224,
#   'mode': 1,
#   'speechiness': 0.107,
#   'tempo': 103.016,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1COvXs6jaykXC73h9OSBVM',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1COvXs6jaykXC73h9OSBVM',
#   'valence': 0.736},
#  'Babushka Boi - A$AP Rocky': {'Track': 'Babushka Boi - A$AP Rocky',
#   'acousticness': 0.304,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/643PW82aBMUa1FiWi5VQY7',
#   'danceability': 0.897,
#   'duration_ms': 187105,
#   'energy': 0.743,
#   'id': '643PW82aBMUa1FiWi5VQY7',
#   'instrumentalness': 4.44e-05,
#   'key': 10,
#   'liveness': 0.137,
#   'loudness': -5.446,
#   'mode': 0,
#   'speechiness': 0.222,
#   'tempo': 134.979,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/643PW82aBMUa1FiWi5VQY7',
#   'type': 'audio_features',
#   'uri': 'spotify:track:643PW82aBMUa1FiWi5VQY7',
#   'valence': 0.905},
#  'Baby Girl - Chloe x Halle': {'Track': 'Baby Girl - Chloe x Halle',
#   'acousticness': 0.00449,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AYn4YyxEF0SR3fGr6x7KN',
#   'danceability': 0.684,
#   'duration_ms': 212373,
#   'energy': 0.473,
#   'id': '1AYn4YyxEF0SR3fGr6x7KN',
#   'instrumentalness': 0.000552,
#   'key': 1,
#   'liveness': 0.337,
#   'loudness': -6.434,
#   'mode': 1,
#   'speechiness': 0.0427,
#   'tempo': 81.004,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1AYn4YyxEF0SR3fGr6x7KN',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1AYn4YyxEF0SR3fGr6x7KN',
#   'valence': 0.299},
#  'Bacc Seat (feat. Ty Dolla $ign) - Roddy Ricch': {'Track': 'Bacc Seat (feat. Ty Dolla $ign) - Roddy Ricch',
#   'acousticness': 0.0404,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6In6SkveIw26thdYRhHTVX',
#   'danceability': 0.783,
#   'duration_ms': 172320,
#   'energy': 0.524,
#   'id': '6In6SkveIw26thdYRhHTVX',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.087,
#   'loudness': -6.828,
#   'mode': 1,
#   'speechiness': 0.115,
#   'tempo': 144.989,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6In6SkveIw26thdYRhHTVX',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6In6SkveIw26thdYRhHTVX',
#   'valence': 0.153},
#  'Back To You - From 13 Reasons Why – Season 2 Soundtrack - Selena Gomez': {'Track': 'Back To You - From 13 Reasons Why – Season 2 Soundtrack - Selena Gomez',
#   'acousticness': 0.0945,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4hQ6UGyWQIGJmHSo0J88JW',
#   'danceability': 0.601,
#   'duration_ms': 207905,
#   'energy': 0.724,
#   'id': '4hQ6UGyWQIGJmHSo0J88JW',
#   'instrumentalness': 1.68e-06,
#   'key': 6,
#   'liveness': 0.12,
#   'loudness': -4.856,
#   'mode': 1,
#   'speechiness': 0.0486,
#   'tempo': 102.061,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4hQ6UGyWQIGJmHSo0J88JW',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4hQ6UGyWQIGJmHSo0J88JW',
#   'valence': 0.508},
#  'Bad (feat. Rihanna) - Remix - Wale': {'Track': 'Bad (feat. Rihanna) - Remix - Wale',
#   'acousticness': 0.307,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5yhKaacMZGRo4s6evJx9vk',
#   'danceability': 0.807,
#   'duration_ms': 238827,
#   'energy': 0.702,
#   'id': '5yhKaacMZGRo4s6evJx9vk',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.111,
#   'loudness': -6.594,
#   'mode': 0,
#   'speechiness': 0.0748,
#   'tempo': 114.038,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5yhKaacMZGRo4s6evJx9vk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5yhKaacMZGRo4s6evJx9vk',
#   'valence': 0.447},
#  'Bad Decisions (from Insecure: Music From The HBO Original Series, Season 4) - Buddy': {'Track': 'Bad Decisions (from Insecure: Music From The HBO Original Series, Season 4) - Buddy',
#   'acousticness': 0.137,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/099wJxKPfoY3R0rqH3C1J1',
#   'danceability': 0.725,
#   'duration_ms': 211429,
#   'energy': 0.372,
#   'id': '099wJxKPfoY3R0rqH3C1J1',
#   'instrumentalness': 0.000623,
#   'key': 5,
#   'liveness': 0.12,
#   'loudness': -13.487,
#   'mode': 1,
#   'speechiness': 0.165,
#   'tempo': 83.995,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/099wJxKPfoY3R0rqH3C1J1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:099wJxKPfoY3R0rqH3C1J1',
#   'valence': 0.477},
#  'Bad News - Tom MacDonald': {'Track': 'Bad News - Tom MacDonald',
#   'acousticness': 0.635,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77WizHcbHf2At6ELNxZ7rv',
#   'danceability': 0.81,
#   'duration_ms': 255000,
#   'energy': 0.578,
#   'id': '77WizHcbHf2At6ELNxZ7rv',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.088,
#   'loudness': -6.202,
#   'mode': 1,
#   'speechiness': 0.192,
#   'tempo': 79.998,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/77WizHcbHf2At6ELNxZ7rv',
#   'type': 'audio_features',
#   'uri': 'spotify:track:77WizHcbHf2At6ELNxZ7rv',
#   'valence': 0.538},
#  'Bad Things (with Camila Cabello) - Camila Cabello': {'Track': 'Bad Things (with Camila Cabello) - Camila Cabello',
#   'acousticness': 0.214,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PSBzsahR2AKwLJgx8ehBj',
#   'danceability': 0.697,
#   'duration_ms': 239293,
#   'energy': 0.691,
#   'id': '1PSBzsahR2AKwLJgx8ehBj',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.185,
#   'loudness': -4.757,
#   'mode': 1,
#   'speechiness': 0.146,
#   'tempo': 137.853,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1PSBzsahR2AKwLJgx8ehBj',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1PSBzsahR2AKwLJgx8ehBj',
#   'valence': 0.305},
#  "Ballin' (with Roddy Ricch) - Roddy Ricch": {'Track': "Ballin' (with Roddy Ricch) - Roddy Ricch",
#   'acousticness': 0.392,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3QzAOrNlsabgbMwlZt7TAY',
#   'danceability': 0.809,
#   'duration_ms': 180435,
#   'energy': 0.545,
#   'id': '3QzAOrNlsabgbMwlZt7TAY',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.151,
#   'loudness': -6.678,
#   'mode': 1,
#   'speechiness': 0.0735,
#   'tempo': 97.008,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3QzAOrNlsabgbMwlZt7TAY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3QzAOrNlsabgbMwlZt7TAY',
#   'valence': 0.244},
#  'Banana Clip - Miguel': {'Track': 'Banana Clip - Miguel',
#   'acousticness': 0.0973,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xagjcywpcyNFghafZPQJv',
#   'danceability': 0.638,
#   'duration_ms': 201627,
#   'energy': 0.708,
#   'id': '6xagjcywpcyNFghafZPQJv',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.177,
#   'loudness': -5.342,
#   'mode': 0,
#   'speechiness': 0.0754,
#   'tempo': 84.978,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6xagjcywpcyNFghafZPQJv',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6xagjcywpcyNFghafZPQJv',
#   'valence': 0.606},
#  'Banana Split (with YNW Melly feat. Lil Durk) - YNW Melly': {'Track': 'Banana Split (with YNW Melly feat. Lil Durk) - YNW Melly',
#   'acousticness': 0.42,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57Lw4YmOvpighLOnwqiuKr',
#   'danceability': 0.743,
#   'duration_ms': 192969,
#   'energy': 0.55,
#   'id': '57Lw4YmOvpighLOnwqiuKr',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.162,
#   'loudness': -6.521,
#   'mode': 0,
#   'speechiness': 0.436,
#   'tempo': 141.864,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/57Lw4YmOvpighLOnwqiuKr',
#   'type': 'audio_features',
#   'uri': 'spotify:track:57Lw4YmOvpighLOnwqiuKr',
#   'valence': 0.564},
#  'Bands - Comethazine': {'Track': 'Bands - Comethazine',
#   'acousticness': 0.21,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0AphwbfFSlGgGDlXGeiEpu',
#   'danceability': 0.834,
#   'duration_ms': 98734,
#   'energy': 0.457,
#   'id': '0AphwbfFSlGgGDlXGeiEpu',
#   'instrumentalness': 0,
#   'key': 10,
#   'liveness': 0.0641,
#   'loudness': -10.775,
#   'mode': 1,
#   'speechiness': 0.572,
#   'tempo': 158.008,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0AphwbfFSlGgGDlXGeiEpu',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0AphwbfFSlGgGDlXGeiEpu',
#   'valence': 0.533},
#  'Bang - Ryan Caraveo': {'Track': 'Bang - Ryan Caraveo',
#   'acousticness': 0.254,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NSF7NcIXyJsbKcONXsKSa',
#   'danceability': 0.697,
#   'duration_ms': 184213,
#   'energy': 0.451,
#   'id': '5NSF7NcIXyJsbKcONXsKSa',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0839,
#   'loudness': -7.993,
#   'mode': 1,
#   'speechiness': 0.252,
#   'tempo': 169.946,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5NSF7NcIXyJsbKcONXsKSa',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5NSF7NcIXyJsbKcONXsKSa',
#   'valence': 0.245},
#  'Barbarian (feat. Lil Tjay) - Calboy': {'Track': 'Barbarian (feat. Lil Tjay) - Calboy',
#   'acousticness': 0.135,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NAheKWXXFvj86udnCMiYD',
#   'danceability': 0.667,
#   'duration_ms': 243280,
#   'energy': 0.648,
#   'id': '5NAheKWXXFvj86udnCMiYD',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.108,
#   'loudness': -7.838,
#   'mode': 0,
#   'speechiness': 0.152,
#   'tempo': 149.927,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5NAheKWXXFvj86udnCMiYD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5NAheKWXXFvj86udnCMiYD',
#   'valence': 0.579},
#  'Be Kind (with Halsey) - Halsey': {'Track': 'Be Kind (with Halsey) - Halsey',
#   'acousticness': 0.00776,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Z8FwOEN59mRMxDCtb8N0A',
#   'danceability': 0.63,
#   'duration_ms': 172762,
#   'energy': 0.633,
#   'id': '3Z8FwOEN59mRMxDCtb8N0A',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.0541,
#   'loudness': -7.088,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'tempo': 93.995,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3Z8FwOEN59mRMxDCtb8N0A',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3Z8FwOEN59mRMxDCtb8N0A',
#   'valence': 0.452},
#  'Be Kind (with Halsey) - Marshmello': {'Track': 'Be Kind (with Halsey) - Marshmello',
#   'acousticness': 0.00776,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Z8FwOEN59mRMxDCtb8N0A',
#   'danceability': 0.63,
#   'duration_ms': 172762,
#   'energy': 0.633,
#   'id': '3Z8FwOEN59mRMxDCtb8N0A',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.0541,
#   'loudness': -7.088,
#   'mode': 1,
#   'speechiness': 0.0457,
#   'tempo': 93.995,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3Z8FwOEN59mRMxDCtb8N0A',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3Z8FwOEN59mRMxDCtb8N0A',
#   'valence': 0.452},
#  'Be Yours - Yung Pinch': {'Track': 'Be Yours - Yung Pinch',
#   'acousticness': 0.437,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tvMa5NqaI4DIHTUcHQZW4',
#   'danceability': 0.704,
#   'duration_ms': 135758,
#   'energy': 0.688,
#   'id': '3tvMa5NqaI4DIHTUcHQZW4',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.121,
#   'loudness': -4.942,
#   'mode': 1,
#   'speechiness': 0.0611,
#   'tempo': 99.078,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3tvMa5NqaI4DIHTUcHQZW4',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3tvMa5NqaI4DIHTUcHQZW4',
#   'valence': 0.632},
#  "Beach Ballin' (feat. blackbear) - Yung Pinch": {'Track': "Beach Ballin' (feat. blackbear) - Yung Pinch",
#   'acousticness': 0.0643,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0W9E3s2G4szLUwXsE17x5E',
#   'danceability': 0.689,
#   'duration_ms': 204275,
#   'energy': 0.586,
#   'id': '0W9E3s2G4szLUwXsE17x5E',
#   'instrumentalness': 0,
#   'key': 1,
#   'liveness': 0.12,
#   'loudness': -6.522,
#   'mode': 0,
#   'speechiness': 0.141,
#   'tempo': 160.037,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0W9E3s2G4szLUwXsE17x5E',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0W9E3s2G4szLUwXsE17x5E',
#   'valence': 0.49},
#  'Beachside - Bazanji': {'Track': 'Beachside - Bazanji',
#   'acousticness': 0.0627,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7tld8T5xAPfOtMDYJ0GpdO',
#   'danceability': 0.711,
#   'duration_ms': 227004,
#   'energy': 0.69,
#   'id': '7tld8T5xAPfOtMDYJ0GpdO',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.263,
#   'loudness': -4.948,
#   'mode': 0,
#   'speechiness': 0.0579,
#   'tempo': 77.179,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7tld8T5xAPfOtMDYJ0GpdO',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7tld8T5xAPfOtMDYJ0GpdO',
#   'valence': 0.194},
#  'Beast Mode (feat. PnB Rock & YoungBoy Never Broke Again) - PnB Rock': {'Track': 'Beast Mode (feat. PnB Rock & YoungBoy Never Broke Again) - PnB Rock',
#   'acousticness': 0.035,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1AH60dMaEfNjzDoUIFwIQi',
#   'danceability': 0.611,
#   'duration_ms': 258158,
#   'energy': 0.478,
#   'id': '1AH60dMaEfNjzDoUIFwIQi',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.107,
#   'loudness': -5.839,
#   'mode': 1,
#   'speechiness': 0.107,
#   'tempo': 172.076,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1AH60dMaEfNjzDoUIFwIQi',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1AH60dMaEfNjzDoUIFwIQi',
#   'valence': 0.138},
#  'Beautiful (feat. Camila Cabello) - Bazzi': {'Track': 'Beautiful (feat. Camila Cabello) - Bazzi',
#   'acousticness': 0.346,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VUwkH455At9kENOfzTqmF',
#   'danceability': 0.638,
#   'duration_ms': 180000,
#   'energy': 0.717,
#   'id': '4VUwkH455At9kENOfzTqmF',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.105,
#   'loudness': -4.722,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'tempo': 100.027,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4VUwkH455At9kENOfzTqmF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4VUwkH455At9kENOfzTqmF',
#   'valence': 0.249},
#  'Beautiful (feat. Camila Cabello) - Camila Cabello': {'Track': 'Beautiful (feat. Camila Cabello) - Camila Cabello',
#   'acousticness': 0.346,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4VUwkH455At9kENOfzTqmF',
#   'danceability': 0.638,
#   'duration_ms': 180000,
#   'energy': 0.717,
#   'id': '4VUwkH455At9kENOfzTqmF',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.105,
#   'loudness': -4.722,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'tempo': 100.027,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4VUwkH455At9kENOfzTqmF',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4VUwkH455At9kENOfzTqmF',
#   'valence': 0.249},
#  'Beautiful People (feat. Khalid) - Ed Sheeran': {'Track': 'Beautiful People (feat. Khalid) - Ed Sheeran',
#   'acousticness': 0.124,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97',
#   'danceability': 0.64,
#   'duration_ms': 197867,
#   'energy': 0.648,
#   'id': '4evmHXcjt3bTUHD1cvny97',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.0802,
#   'loudness': -8.113,
#   'mode': 0,
#   'speechiness': 0.187,
#   'tempo': 92.977,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97',
#   'valence': 0.548},
#  'Beautiful People (feat. Khalid) - Khalid': {'Track': 'Beautiful People (feat. Khalid) - Khalid',
#   'acousticness': 0.124,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97',
#   'danceability': 0.64,
#   'duration_ms': 197867,
#   'energy': 0.648,
#   'id': '4evmHXcjt3bTUHD1cvny97',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.0802,
#   'loudness': -8.113,
#   'mode': 0,
#   'speechiness': 0.187,
#   'tempo': 92.977,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97',
#   'valence': 0.548},
#  'Belong to You (feat. 6LACK) - Sabrina Claudio': {'Track': 'Belong to You (feat. 6LACK) - Sabrina Claudio',
#   'acousticness': 0.274,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2I88NEWpKrAPZuapXNV5G6',
#   'danceability': 0.605,
#   'duration_ms': 185617,
#   'energy': 0.553,
#   'id': '2I88NEWpKrAPZuapXNV5G6',
#   'instrumentalness': 0.0152,
#   'key': 10,
#   'liveness': 0.184,
#   'loudness': -10.845,
#   'mode': 0,
#   'speechiness': 0.101,
#   'tempo': 152.076,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2I88NEWpKrAPZuapXNV5G6',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2I88NEWpKrAPZuapXNV5G6',
#   'valence': 0.62},
#  'Beside You (feat. Georgia Ku) - Matoma': {'Track': 'Beside You (feat. Georgia Ku) - Matoma',
#   'acousticness': 0.0801,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Tdy6tOHVEyBmlObZpGJJc',
#   'danceability': 0.634,
#   'duration_ms': 176640,
#   'energy': 0.794,
#   'id': '6Tdy6tOHVEyBmlObZpGJJc',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.0664,
#   'loudness': -6.363,
#   'mode': 1,
#   'speechiness': 0.0945,
#   'tempo': 123.02,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6Tdy6tOHVEyBmlObZpGJJc',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6Tdy6tOHVEyBmlObZpGJJc',
#   'valence': 0.67},
#  'Best Friend - Yelawolf': {'Track': 'Best Friend - Yelawolf',
#   'acousticness': 0.0174,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/069VGijrAsQVSY9ihFv1Px',
#   'danceability': 0.75,
#   'duration_ms': 314280,
#   'energy': 0.906,
#   'id': '069VGijrAsQVSY9ihFv1Px',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.0551,
#   'loudness': -5.028,
#   'mode': 1,
#   'speechiness': 0.0477,
#   'tempo': 135.96,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/069VGijrAsQVSY9ihFv1Px',
#   'type': 'audio_features',
#   'uri': 'spotify:track:069VGijrAsQVSY9ihFv1Px',
#   'valence': 0.562},
#  'Best Part (feat. Daniel Caesar) - H.E.R.': {'Track': 'Best Part (feat. Daniel Caesar) - H.E.R.',
#   'acousticness': 0.795,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4OBZT9EnhYIV17t4pGw7ig',
#   'danceability': 0.473,
#   'duration_ms': 209400,
#   'energy': 0.371,
#   'id': '4OBZT9EnhYIV17t4pGw7ig',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.109,
#   'loudness': -10.219,
#   'mode': 0,
#   'speechiness': 0.0405,
#   'tempo': 75.208,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4OBZT9EnhYIV17t4pGw7ig',
#   'type': 'audio_features',
# ...
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2fnwiUU3LEvEy7xByzzaDV',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2fnwiUU3LEvEy7xByzzaDV',
#   'valence': 0.665},
#  'Wonder What She Thinks of Me - Chloe x Halle': {'Track': 'Wonder What She Thinks of Me - Chloe x Halle',
#   'acousticness': 0.331,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4keqQBiftWkXbPOSsjK7EH',
#   'danceability': 0.562,
#   'duration_ms': 211587,
#   'energy': 0.536,
#   'id': '4keqQBiftWkXbPOSsjK7EH',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.0893,
#   'loudness': -7.052,
#   'mode': 1,
#   'speechiness': 0.0746,
#   'tempo': 125.308,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4keqQBiftWkXbPOSsjK7EH',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4keqQBiftWkXbPOSsjK7EH',
#   'valence': 0.278},
#  'Woosah - Jeremih': {'Track': 'Woosah - Jeremih',
#   'acousticness': 0.406,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LkLJhskz3IJZFQHAbmgmt',
#   'danceability': 0.624,
#   'duration_ms': 329507,
#   'energy': 0.322,
#   'id': '2LkLJhskz3IJZFQHAbmgmt',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.103,
#   'loudness': -11.794,
#   'mode': 0,
#   'speechiness': 0.679,
#   'tempo': 79.988,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/2LkLJhskz3IJZFQHAbmgmt',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2LkLJhskz3IJZFQHAbmgmt',
#   'valence': 0.341},
#  'Work Out - J. Cole': {'Track': 'Work Out - J. Cole',
#   'acousticness': 0.0531,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2wAJTrFhCnQyNSD3oUgTZO',
#   'danceability': 0.831,
#   'duration_ms': 235320,
#   'energy': 0.427,
#   'id': '2wAJTrFhCnQyNSD3oUgTZO',
#   'instrumentalness': 0,
#   'key': 2,
#   'liveness': 0.307,
#   'loudness': -6.903,
#   'mode': 1,
#   'speechiness': 0.106,
#   'tempo': 93.004,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2wAJTrFhCnQyNSD3oUgTZO',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2wAJTrFhCnQyNSD3oUgTZO',
#   'valence': 0.216},
#  'World On Fire - 12 Inch Mix (Mixed) - Above & Beyond': {'Track': 'World On Fire - 12 Inch Mix (Mixed) - Above & Beyond',
#   'acousticness': 0.000669,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BbdmqMsNFzi7bUoRQZoDw',
#   'danceability': 0.534,
#   'duration_ms': 322334,
#   'energy': 0.995,
#   'id': '0BbdmqMsNFzi7bUoRQZoDw',
#   'instrumentalness': 0.0166,
#   'key': 4,
#   'liveness': 0.304,
#   'loudness': -5.235,
#   'mode': 0,
#   'speechiness': 0.0716,
#   'tempo': 137.009,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0BbdmqMsNFzi7bUoRQZoDw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0BbdmqMsNFzi7bUoRQZoDw',
#   'valence': 0.268},
#  'Worth It (feat. Kid Ink) - Fifth Harmony': {'Track': 'Worth It (feat. Kid Ink) - Fifth Harmony',
#   'acousticness': 0.063,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/41Fflg7qHiVOD6dEPvsCzO',
#   'danceability': 0.884,
#   'duration_ms': 224573,
#   'energy': 0.765,
#   'id': '41Fflg7qHiVOD6dEPvsCzO',
#   'instrumentalness': 7.04e-06,
#   'key': 8,
#   'liveness': 0.118,
#   'loudness': -3.865,
#   'mode': 1,
#   'speechiness': 0.0882,
#   'tempo': 99.987,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/41Fflg7qHiVOD6dEPvsCzO',
#   'type': 'audio_features',
#   'uri': 'spotify:track:41Fflg7qHiVOD6dEPvsCzO',
#   'valence': 0.594},
#  'Worth It - Remix - YK Osiris': {'Track': 'Worth It - Remix - YK Osiris',
#   'acousticness': 0.404,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21zr9IucVstq6J3gf9VaqX',
#   'danceability': 0.675,
#   'duration_ms': 227960,
#   'energy': 0.629,
#   'id': '21zr9IucVstq6J3gf9VaqX',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.0916,
#   'loudness': -3.132,
#   'mode': 0,
#   'speechiness': 0.0553,
#   'tempo': 123.994,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/21zr9IucVstq6J3gf9VaqX',
#   'type': 'audio_features',
#   'uri': 'spotify:track:21zr9IucVstq6J3gf9VaqX',
#   'valence': 0.576},
#  'Worth It - YK Osiris': {'Track': 'Worth It - YK Osiris',
#   'acousticness': 0.517,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PQoUlzP7ILdcrzpajHXc0',
#   'danceability': 0.749,
#   'duration_ms': 189253,
#   'energy': 0.535,
#   'id': '0PQoUlzP7ILdcrzpajHXc0',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.0942,
#   'loudness': -4.054,
#   'mode': 0,
#   'speechiness': 0.0638,
#   'tempo': 124.008,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/0PQoUlzP7ILdcrzpajHXc0',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0PQoUlzP7ILdcrzpajHXc0',
#   'valence': 0.459},
#  'Wrong Places (from Songland) - H.E.R.': {'Track': 'Wrong Places (from Songland) - H.E.R.',
#   'acousticness': 0.224,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mtLGVN6xZm93wDG9nvviS',
#   'danceability': 0.548,
#   'duration_ms': 197727,
#   'energy': 0.457,
#   'id': '2mtLGVN6xZm93wDG9nvviS',
#   'instrumentalness': 8.32e-05,
#   'key': 4,
#   'liveness': 0.11,
#   'loudness': -7.626,
#   'mode': 1,
#   'speechiness': 0.0691,
#   'tempo': 175.659,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2mtLGVN6xZm93wDG9nvviS',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2mtLGVN6xZm93wDG9nvviS',
#   'valence': 0.494},
#  'YOUTH - Troye Sivan': {'Track': 'YOUTH - Troye Sivan',
#   'acousticness': 0.0625,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cOyWWUr3oXJIxY0AjJEx9',
#   'danceability': 0.628,
#   'duration_ms': 185194,
#   'energy': 0.737,
#   'id': '1cOyWWUr3oXJIxY0AjJEx9',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.0777,
#   'loudness': -4.437,
#   'mode': 1,
#   'speechiness': 0.041,
#   'tempo': 91.507,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1cOyWWUr3oXJIxY0AjJEx9',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1cOyWWUr3oXJIxY0AjJEx9',
#   'valence': 0.592},
#  'Yacht Club (feat. Juice WRLD) - Lil Yachty': {'Track': 'Yacht Club (feat. Juice WRLD) - Lil Yachty',
#   'acousticness': 0.317,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5R2rsbwCDXORX2tLfprRmM',
#   'danceability': 0.721,
#   'duration_ms': 166343,
#   'energy': 0.508,
#   'id': '5R2rsbwCDXORX2tLfprRmM',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.153,
#   'loudness': -7.496,
#   'mode': 1,
#   'speechiness': 0.394,
#   'tempo': 159.911,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5R2rsbwCDXORX2tLfprRmM',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5R2rsbwCDXORX2tLfprRmM',
#   'valence': 0.457},
#  'You & Me - James TW': {'Track': 'You & Me - James TW',
#   'acousticness': 0.203,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bQhZOoXYqjXs7u7rFXo0h',
#   'danceability': 0.714,
#   'duration_ms': 231653,
#   'energy': 0.686,
#   'id': '1bQhZOoXYqjXs7u7rFXo0h',
#   'instrumentalness': 7.76e-06,
#   'key': 11,
#   'liveness': 0.102,
#   'loudness': -6.333,
#   'mode': 1,
#   'speechiness': 0.0445,
#   'tempo': 127.015,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1bQhZOoXYqjXs7u7rFXo0h',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1bQhZOoXYqjXs7u7rFXo0h',
#   'valence': 0.828},
#  "You Should've Known - Hopsin": {'Track': "You Should've Known - Hopsin",
#   'acousticness': 0.182,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6FV7RivrHzOwu6SkLRRYmY',
#   'danceability': 0.766,
#   'duration_ms': 194231,
#   'energy': 0.525,
#   'id': '6FV7RivrHzOwu6SkLRRYmY',
#   'instrumentalness': 3.56e-06,
#   'key': 1,
#   'liveness': 0.106,
#   'loudness': -10.217,
#   'mode': 1,
#   'speechiness': 0.192,
#   'tempo': 137.077,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6FV7RivrHzOwu6SkLRRYmY',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6FV7RivrHzOwu6SkLRRYmY',
#   'valence': 0.324},
#  'You and Me - Yelawolf': {'Track': 'You and Me - Yelawolf',
#   'acousticness': 0.109,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53QA7j4pHWAtbE3D0Glh7Q',
#   'danceability': 0.598,
#   'duration_ms': 242001,
#   'energy': 0.448,
#   'id': '53QA7j4pHWAtbE3D0Glh7Q',
#   'instrumentalness': 0.00105,
#   'key': 1,
#   'liveness': 0.123,
#   'loudness': -8.525,
#   'mode': 0,
#   'speechiness': 0.0342,
#   'tempo': 140.97,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/53QA7j4pHWAtbE3D0Glh7Q',
#   'type': 'audio_features',
#   'uri': 'spotify:track:53QA7j4pHWAtbE3D0Glh7Q',
#   'valence': 0.0727},
#  'Young & Alive - Bazzi': {'Track': 'Young & Alive - Bazzi',
#   'acousticness': 0.326,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RsKelNxucrDxgMbZ3vd3W',
#   'danceability': 0.716,
#   'duration_ms': 160465,
#   'energy': 0.563,
#   'id': '5RsKelNxucrDxgMbZ3vd3W',
#   'instrumentalness': 0,
#   'key': 3,
#   'liveness': 0.119,
#   'loudness': -5.486,
#   'mode': 1,
#   'speechiness': 0.0425,
#   'tempo': 86.005,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5RsKelNxucrDxgMbZ3vd3W',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5RsKelNxucrDxgMbZ3vd3W',
#   'valence': 0.495},
#  'ZEZE (feat. Travis Scott & Offset) - Kodak Black': {'Track': 'ZEZE (feat. Travis Scott & Offset) - Kodak Black',
#   'acousticness': 0.0521,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FZ4Dmg8jJJAPJnvBIzD9z',
#   'danceability': 0.861,
#   'duration_ms': 228760,
#   'energy': 0.603,
#   'id': '0FZ4Dmg8jJJAPJnvBIzD9z',
#   'instrumentalness': 0,
#   'key': 8,
#   'liveness': 0.0924,
#   'loudness': -5.788,
#   'mode': 0,
#   'speechiness': 0.176,
#   'tempo': 98.043,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0FZ4Dmg8jJJAPJnvBIzD9z',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0FZ4Dmg8jJJAPJnvBIzD9z',
#   'valence': 0.504},
#  'Zeppelin - Edit - Michael Cassette': {'Track': 'Zeppelin - Edit - Michael Cassette',
#   'acousticness': 0.00288,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ygiIAkitisuHf7guzwoWu',
#   'danceability': 0.562,
#   'duration_ms': 262016,
#   'energy': 0.726,
#   'id': '7ygiIAkitisuHf7guzwoWu',
#   'instrumentalness': 0.813,
#   'key': 8,
#   'liveness': 0.257,
#   'loudness': -9.054,
#   'mode': 1,
#   'speechiness': 0.0345,
#   'tempo': 123.995,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/7ygiIAkitisuHf7guzwoWu',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7ygiIAkitisuHf7guzwoWu',
#   'valence': 0.383},
#  'Zeppelin - Mixed - Michael Cassette': {'Track': 'Zeppelin - Mixed - Michael Cassette',
#   'acousticness': 0.00144,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2t2Jme4jdRDtjw9wwHVt2l',
#   'danceability': 0.617,
#   'duration_ms': 453750,
#   'energy': 0.749,
#   'id': '2t2Jme4jdRDtjw9wwHVt2l',
#   'instrumentalness': 0.817,
#   'key': 6,
#   'liveness': 0.158,
#   'loudness': -8.297,
#   'mode': 0,
#   'speechiness': 0.0509,
#   'tempo': 128.007,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/2t2Jme4jdRDtjw9wwHVt2l',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2t2Jme4jdRDtjw9wwHVt2l',
#   'valence': 0.548},
#  'Zone 6 (Remix) (feat. Future & 6LACK) - Young Nudy': {'Track': 'Zone 6 (Remix) (feat. Future & 6LACK) - Young Nudy',
#   'acousticness': 0.128,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tbIldU1Cfdpat40wyJKkn',
#   'danceability': 0.858,
#   'duration_ms': 236947,
#   'energy': 0.406,
#   'id': '2tbIldU1Cfdpat40wyJKkn',
#   'instrumentalness': 0,
#   'key': 9,
#   'liveness': 0.375,
#   'loudness': -9.404,
#   'mode': 1,
#   'speechiness': 0.649,
#   'tempo': 155.918,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2tbIldU1Cfdpat40wyJKkn',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2tbIldU1Cfdpat40wyJKkn',
#   'valence': 0.596},
#  'feel something - Bea Miller': {'Track': 'feel something - Bea Miller',
#   'acousticness': 0.242,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7JDWhC422Gtk1Bq0mL3OTC',
#   'danceability': 0.74,
#   'duration_ms': 180161,
#   'energy': 0.415,
#   'id': '7JDWhC422Gtk1Bq0mL3OTC',
#   'instrumentalness': 0.000156,
#   'key': 0,
#   'liveness': 0.319,
#   'loudness': -8.914,
#   'mode': 1,
#   'speechiness': 0.0707,
#   'tempo': 136.029,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7JDWhC422Gtk1Bq0mL3OTC',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7JDWhC422Gtk1Bq0mL3OTC',
#   'valence': 0.156},
#  "i can't breathe - Bea Miller": {'Track': "i can't breathe - Bea Miller",
#   'acousticness': 0.893,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qFMIjTe9esCDiytqUY19t',
#   'danceability': 0.347,
#   'duration_ms': 213987,
#   'energy': 0.209,
#   'id': '1qFMIjTe9esCDiytqUY19t',
#   'instrumentalness': 0.00287,
#   'key': 11,
#   'liveness': 0.138,
#   'loudness': -11.152,
#   'mode': 1,
#   'speechiness': 0.0273,
#   'tempo': 82.878,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1qFMIjTe9esCDiytqUY19t',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1qFMIjTe9esCDiytqUY19t',
#   'valence': 0.0735},
#  "it's not u it's me - Bea Miller": {'Track': "it's not u it's me - Bea Miller",
#   'acousticness': 0.0204,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7cLm450e9XaPrEZTSTsfwU',
#   'danceability': 0.776,
#   'duration_ms': 194526,
#   'energy': 0.568,
#   'id': '7cLm450e9XaPrEZTSTsfwU',
#   'instrumentalness': 1.69e-05,
#   'key': 0,
#   'liveness': 0.078,
#   'loudness': -6.419,
#   'mode': 0,
#   'speechiness': 0.125,
#   'tempo': 150.901,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7cLm450e9XaPrEZTSTsfwU',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7cLm450e9XaPrEZTSTsfwU',
#   'valence': 0.749},
#  'like that - Bea Miller': {'Track': 'like that - Bea Miller',
#   'acousticness': 0.186,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6E37j4b44JGpdk297urpKM',
#   'danceability': 0.573,
#   'duration_ms': 185547,
#   'energy': 0.441,
#   'id': '6E37j4b44JGpdk297urpKM',
#   'instrumentalness': 0,
#   'key': 6,
#   'liveness': 0.61,
#   'loudness': -5.799,
#   'mode': 0,
#   'speechiness': 0.0758,
#   'tempo': 61.657,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6E37j4b44JGpdk297urpKM',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6E37j4b44JGpdk297urpKM',
#   'valence': 0.389},
#  'lovely (with Khalid) - Khalid': {'Track': 'lovely (with Khalid) - Khalid',
#   'acousticness': 0.934,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0u2P5u6lvoDfwTYjAADbn4',
#   'danceability': 0.351,
#   'duration_ms': 200186,
#   'energy': 0.296,
#   'id': '0u2P5u6lvoDfwTYjAADbn4',
#   'instrumentalness': 0,
#   'key': 4,
#   'liveness': 0.095,
#   'loudness': -10.109,
#   'mode': 0,
#   'speechiness': 0.0333,
#   'tempo': 115.284,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0u2P5u6lvoDfwTYjAADbn4',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0u2P5u6lvoDfwTYjAADbn4',
#   'valence': 0.12},
#  'oui - Jeremih': {'Track': 'oui - Jeremih',
#   'acousticness': 0.213,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PJIbOdMs3bd5AT8liULMQ',
#   'danceability': 0.418,
#   'duration_ms': 238320,
#   'energy': 0.724,
#   'id': '0PJIbOdMs3bd5AT8liULMQ',
#   'instrumentalness': 0,
#   'key': 5,
#   'liveness': 0.112,
#   'loudness': -3.724,
#   'mode': 1,
#   'speechiness': 0.0964,
#   'tempo': 78.521,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/0PJIbOdMs3bd5AT8liULMQ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0PJIbOdMs3bd5AT8liULMQ',
#   'valence': 0.604},
#  'waves - Tame Impala Remix - Miguel': {'Track': 'waves - Tame Impala Remix - Miguel',
#   'acousticness': 0.308,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3lB0GMiI5KxDbTOG8V3bOx',
#   'danceability': 0.529,
#   'duration_ms': 253347,
#   'energy': 0.894,
#   'id': '3lB0GMiI5KxDbTOG8V3bOx',
#   'instrumentalness': 5.38e-06,
#   'key': 2,
#   'liveness': 0.254,
#   'loudness': -3.599,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'tempo': 108.024,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3lB0GMiI5KxDbTOG8V3bOx',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3lB0GMiI5KxDbTOG8V3bOx',
#   'valence': 0.543}}

# %% [markdown]
# Now, we have a cleaned dataset to dump into mongo... this part took a while... now for the easy bit

# %%
#now time to start dumping my personal data into MongoDB
import pymongo
from pymongo import MongoClient
client = MongoClient()

# %%
#makes spotify database
spotify_db = client.spotify

# %%
#database for data from my library
library_collection = spotify_db.library

# %%
library_vals_list = list(songdata_dict.values())

# %%
#inserts my library
library_collection.insert_many(library_vals_list)

# %%
#now time to insert all potential recommendations
#make a new collection for that to keep things separate
recommendation_collection = spotify_db.recs

# %%
recs_list = list(potential_recs_songdata_dict.values())

# %%
#dumps in collection
recommendation_collection.insert_many(recs_list)

# %%
#Now I need to gather data for music that i dislike
#found a kaggle dataset of hits and flops will use some of that
import pandas as pd
import numpy as np

hits2000 = pd.read_csv("dataset-of-00s.csv")
hits2010 = pd.read_csv("dataset-of-10s.csv")

# %%
#this dataset was found on kaggle where the target is whether or not a song was a hit 0 means flop so i will only get 
#the flopped songs


hits = hits2000.append(hits2010)
hits = hits[hits["target"]==0]
hits=hits.drop(columns=['chorus_hit', 'sections'])
#now one fo the limitations of this is that the song is good but have never heard it, i cant perfectly
#gather data for that, but i will filter out all songs that have an artist that i have in my library
for index,row in hits.iterrows():
    if row["artist"] in artist_names:
        hits.drop(index, inplace=True)

hits = hits.drop(columns=["target"])
hits["Track"] = hits["track"] + " - " + hits["artist"]
hits = hits.drop(columns=["track", "artist"])

hits
# Out:
#                                        uri  danceability  energy  key  \
# 2     spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9
# 3     spotify:track:2IjBPp2vMeX7LggzRN3iSX         0.188   0.994    4
# 5     spotify:track:5Z3nrC0JbJmXaOGiXTuNFk         0.726   0.837   11
# 6     spotify:track:0iAdSLiQBIizTAiLUP7p5E         0.365   0.922    1
# 9     spotify:track:3pjnCLIHbRczUjenWOEo56         0.647   0.324    7
# ...                                    ...           ...     ...  ...
# 6384  spotify:track:6Yk1qYbmPKdoqNrHYRFc9c         0.395   0.927    4
# 6386  spotify:track:6RSamYe6vPBz7mGHe5Qj1q         0.396   0.044    9
# 6393  spotify:track:4t1TljQWJ6ZuoSY67zVvBI         0.172   0.358    9
# 6396  spotify:track:4o9npmYHrOF1rUxxTVH8h4         0.600   0.177    7
# 6397  spotify:track:2khIaVUkbMmDHB596lyMG3         0.121   0.123    4
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 2       -3.009     1       0.0473      0.000111           0.00457    0.1740
# 3       -3.745     1       0.1660      0.000007           0.07840    0.1920
# 5       -7.223     0       0.0965      0.373000           0.26800    0.1360
# 6       -2.644     1       0.0710      0.002850           0.00000    0.3210
# 9       -9.679     1       0.0377      0.354000           0.00000    0.1150
# ...        ...   ...          ...           ...               ...       ...
# 6384    -4.418     1       0.1650      0.116000           0.00000    0.4410
# 6386   -25.088     0       0.0370      0.984000           0.94700    0.0802
# 6393   -14.430     1       0.0342      0.886000           0.96600    0.3140
# 6396   -16.070     1       0.0561      0.989000           0.86800    0.1490
# 6397   -23.025     0       0.0443      0.964000           0.69600    0.1030
#
#       valence    tempo  duration_ms  time_signature  \
# 2      0.3000   86.964       338893               4
# 3      0.3330  148.440       255667               4
# 5      0.9690  135.347       192720               4
# 6      0.2900   77.250        89427               4
# 9      0.3440  124.213       314286               3
# ...       ...      ...          ...             ...
# 6384   0.9410  188.384       191905               3
# 6386   0.0898   71.200       224636               5
# 6393   0.0361   72.272       150857               4
# 6396   0.5600  120.030       213387               4
# 6397   0.0297   95.182       341396               4
#
#                                             Track
# 2                 Clouds Of Dementia - Candlemass
# 3        Heavy Metal, Raise Hell! - Zwartketterij
# 5                  Dantzig Station - State Of Art
# 6                          Divorced - Blacklisted
# 9        I Want to Know Your Plans - Say Anything
# ...                                           ...
# 6384  Gimme D' Road - Carnival Mix - Calypso Rose
# 6386                      Vast Changes - Regentum
# 6393                        Lotus Flowers - Yolta
# 6396              Stormy Weather - Oscar Peterson
# 6397                           Dust - Hans Zimmer
#
# [6053 rows x 15 columns]

# %%
#keep a list of Tracks for keys

# dump all of this in mongo as well
bad_songs_collection = spotify_db.bad_songs
#inserting the data
for row in hits.to_dict(orient="row"):
    bad_songs_collection.insert_one(row)

# %%
#will save hits in mongo as well
good_songs_collection=spotify_db.good_songs

hits2000 = pd.read_csv("dataset-of-00s.csv")
hits2010 = pd.read_csv("dataset-of-10s.csv")

hits = hits2000.append(hits2010)
hits = hits[hits["target"]==1]
hits=hits.drop(columns=['chorus_hit', 'sections'])
hits["Track"] = hits["track"] + " - " + hits["artist"]
hits = hits.drop(columns=["track", "artist"])

for row in hits.to_dict(orient="row"):
    good_songs_collection.insert_one(row)
